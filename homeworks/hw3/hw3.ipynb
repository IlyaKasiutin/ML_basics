# %%
import nltk
import re
import pymorphy2
from collections import Counter
nltk.download('stopwords')
import pandas as pd
import numpy as np
import gensim
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from tqdm import tqdm_notebook
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing  import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, SGDClassifier, RidgeClassifierCV, RidgeClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.metrics import f1_score
from IPython.core.display import HTML, display
from unidecode import unidecode
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\User\AppData\Local\Temp\ipykernel_6012\2102828800.py:23: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display

# %%
train_df = pd.read_csv("train.csv")

train_df.head()
# Out:
#    id              url                                              title
# 0   0          m.kp.md  Экс-министр экономики Молдовы - главе МИДЭИ, ц...  \
# 1   1        www.kp.by  Эта песня стала известна многим телезрителям б...
# 2   2    fanserials.tv  Банши 4 сезон 2 серия Бремя красоты смотреть о...
# 3   3  colorbox.spb.ru                              Не Беси Меня Картинки
# 4   4    tula-sport.ru  В Новомосковске сыграют следж-хоккеисты алекси...
#
#    target
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False

# %%
test_df = pd.read_csv("test.csv")

test_df.head()
# Out:
#        id                url
# 0  135309  www.kommersant.ru  \
# 1  135310    urexpert.online
# 2  135311      imperimeha.ru
# 3  135312  national-porn.com
# 4  135313            2gis.ru
#
#                                                title
# 0  Шестой кассационный суд в Самаре начнет работу...
# 1  Что такое индексация алиментов, кем и в каких ...
# 2                  Женщинам | Империя Меха - Part 12
# 3  Небритые, волосатые киски: Порно всех стран и ...
# 4                                                 67

# %%
len(test_df)
# Out:
# 165378

# %%
train_df["target"].value_counts()
# Out:
# target
# False    118594
# True      16715
# Name: count, dtype: int64

# %%
from sklearn.metrics import f1_score

# %%
X_train = train_df[["url", "title"]]
X_test = test_df[["url", "title"]]
y_train = train_df["target"].astype(int).values

# %% [markdown]
# # Препроцессинг данных

# %% [markdown]
# ## Токенизация

# %%
TOKEN_PATTERN = "[a-zа-яё]+"

def tokenize(text):
    return re.findall(TOKEN_PATTERN, text.lower())

docs_url = [tokenize((str(text))) for text in X_train["url"]]
docs_title = [tokenize(str(text)) for text in X_train["title"]]

# %%
docs_url
# Out:
# [['m', 'kp', 'md'],
#  ['www', 'kp', 'by'],
#  ['fanserials', 'tv'],
#  ['colorbox', 'spb', 'ru'],
#  ['tula', 'sport', 'ru'],
#  ['beregifiguru', 'ru'],
#  ['ekb', 'vseinstrumenti', 'ru'],
#  ['mirtabaka', 'org'],
#  ['xlecx', 'com'],
#  ['bus', 'biletyplus', 'ua'],
#  ['otvet', 'gotov', 'ru'],
#  ['mail', 'ru'],
#  ['pornmult', 'info'],
#  ['libking', 'ru'],
#  ['www', 'idealmedia', 'io'],
#  ['mail', 'ru'],
#  ['zaycev', 'net'],
#  ['kazan', 'ucheba', 'ru'],
#  ['mail', 'ru'],
#  ['eropixel', 'net'],
#  ['royallib', 'com'],
#  ['gdespaces', 'com'],
#  ['ulyanovsk', 'beeline', 'ru'],
#  ['xorazm', 'net'],
#  ['mail', 'ru'],
#  ['www', 'gismeteo', 'ua'],
#  ['corel', 'ru'],
#  ['www', 'mvideo', 'ru'],
#  ['apteka', 'ru'],
#  ['norma', 'org', 'ua'],
#  ['mychords', 'net'],
#  ['deal', 'by'],
#  ['www', 'farpost', 'ru'],
#  ['www', 'mvideo', 'ru'],
#  ['m', 'auto', 'n', 'ru'],
#  ['vtk', 'moscow', 'ru'],
#  ['tengrinews', 'kz'],
#  ['mail', 'ru'],
#  ['www', 'lamnia', 'com'],
#  ['mmag', 'ru'],
#  ['otzovik', 'com'],
#  ['hdxclub', 'com'],
#  ['infourok', 'ru'],
#  ['tass', 'ru'],
#  ['viasun', 'ru'],
#  ['drivemusic', 'me'],
#  ['tddomovoy', 'ru'],
#  ['jrfzdohkntmopulam',
#   'ayigseqr',
#   'ghplfa',
#   'l',
#   'uo',
#   'gcnmcsq',
#   'cdn',
#   'ampproject',
#   'org'],
#  ['www', 'olx', 'ua'],
#  ['spinfields', 'narod', 'ru'],
#  ['irecommend', 'ru'],
#  ['mail', 'ru'],
#  ['desixxxtube', 'pro'],
#  ['ipad', 'perfektdamen', 'co'],
#  ['centerdeti', 'ru'],
#  ['daftsex', 'com'],
#  ['topdevka', 'com'],
#  ['dohera', 'porno', 'net'],
#  ['mail', 'ru'],
#  ['www', 'superjob', 'ru'],
#  ['utorrentfilmi', 'ru'],
#  ['spb', 'hh', 'ru'],
#  ['www', 'epochtimes', 'ru'],
#  ['watchskino', 'ru'],
#  ['zonasporta', 'com'],
#  ['postupi', 'online'],
#  ['fotokto', 'ru'],
#  ['d', 'dzenkino', 'kz'],
#  ['bukvi', 'ru'],
#  ['xuping', 'rv', 'ua'],
#  ['www', 'yaplakal', 'com'],
#  ['www', 'consultant', 'ru'],
#  ['kinoprey', 'net'],
#  ['hdkinomir', 'cc'],
#  ['www', 'vokrug', 'tv'],
#  ['tubedoc', 'ru'],
#  ['eu', 'ru', 'net'],
#  ['mail', 'ru'],
#  ['tsn', 'ua', 'cdn', 'ampproject', 'org'],
#  ['litlife', 'club'],
#  ['manga', 'online', 'biz'],
#  ['manga', 'online', 'biz'],
#  ['old', 'kabar', 'kg'],
#  ['www', 'lylagames', 'com'],
#  ['babiki', 'ru'],
#  ['vkys', 'info'],
#  ['hdrezka', 'ag', 'com'],
#  ['supervayzer', 'ru'],
#  ['ru', 'iherb', 'com'],
#  ['kosmoprof', 'com'],
#  ['www', 'bolshoyvopros', 'ru'],
#  ['animebest', 'org'],
#  ['zakupki', 'kontur', 'ru'],
#  ['www', 'stormo', 'tv'],
#  ['mail', 'ru'],
#  ['www', 'pravda', 'com', 'ua'],
#  ['povar', 'ru'],
#  ['elcos', 'design', 'ru'],
#  ['w', 'kassa', 'rambler', 'ru'],
#  ['devkis', 'org'],
#  ['mail', 'ru'],
#  ['baniomsk', 'ru'],
#  ['www', 'kodges', 'ru'],
#  ['nppekonom', 'm', 'energoportal', 'ru'],
#  ['forum', 'guns', 'ru'],
#  ['kianmsk', 'korsgroup', 'ru'],
#  ['indexmap', 'ru'],
#  ['belgorod', 'antfarms', 'ru'],
#  ['www', 'brighthouse', 'am'],
#  ['volna', 'org'],
#  ['mail', 'ru'],
#  ['daftsex', 'com'],
#  ['dk', 'kstovo', 'ru'],
#  ['www', 'holmadmin', 'net'],
#  ['chelyabinsk', 'bezformata', 'com'],
#  ['www', 'zvuk', 'top'],
#  ['vkysno', 'vcem', 'ru'],
#  ['moscow', 'site', 'com'],
#  ['www', 'delfin', 'tour', 'ru'],
#  ['www', 'mvideo', 'ru'],
#  ['svetislama', 'ru'],
#  ['cyberleninka', 'ru'],
#  ['sexoo', 'me'],
#  ['sitegallery', 'ru'],
#  ['eva', 'ru'],
#  ['porntube', 'cc'],
#  ['www', 'frenglish', 'ru'],
#  ['m', 'baby', 'ru'],
#  ['mail', 'ru'],
#  ['mir', 'knigi', 'org'],
#  ['torrent', 'plump', 'ru'],
#  ['flower', 'mir', 'ru'],
#  ['mail', 'ru'],
#  ['www', 'segodnya', 'ua', 'cdn', 'ampproject', 'org'],
#  ['kinoklikhd', 'ru'],
#  ['www', 'moyareklama', 'by'],
#  ['lenin', 'cap', 'ru'],
#  ['mixmuz', 'ru'],
#  ['www', 'kinokadr', 'ru'],
#  ['posleurokov', 'ru'],
#  ['v', 's', 'mobi'],
#  ['mail', 'ru'],
#  ['ru', 'iherb', 'com'],
#  ['youla', 'ru'],
#  ['answear', 'ua'],
#  ['solikamsk', 'restate', 'ru'],
#  ['www', 'perfectgirls', 'net'],
#  ['www', 'msk', 'kp', 'ru'],
#  ['booksbunker', 'com'],
#  ['ogosex', 'net'],
#  ['m', 'chitai', 'gorod', 'ru'],
#  ['manga', 'online', 'biz'],
#  ['baza', 'drom', 'ru'],
#  ['promo', 'akcii', 'ru'],
#  ['www', 'vsekolledzhi', 'ru'],
#  ['instabazza', 'com'],
#  ['www', 'domani', 'ru'],
#  ['hdmax', 'in'],
#  ['stilefon', 'ru'],
#  ['www', 'cossa', 'ru'],
#  ['xn', 'e', 'afprfv', 'org'],
#  ['daftsex', 'com'],
#  ['mail', 'ru'],
#  ['www', 'mitsubishi', 'motors', 'com', 'ru'],
#  ['rutube', 'ru'],
#  ['www', 'kolesa', 'ru'],
#  ['burjauto', 'com'],
#  ['www', 'pornktube', 'porn'],
#  ['macros', 'vba', 'ru'],
#  ['ukr', 'lb', 'ua'],
#  ['kr', 'isuo', 'org'],
#  ['www', 'poly', 'pack', 'com', 'ua'],
#  ['xn', 'kckegeaw', 'apdfn', 'd', 'a', 'j', 'xn', 'p', 'ai'],
#  ['krasnoyarsk', 'postupi', 'online'],
#  ['poisk', 'firm', 'ru'],
#  ['gdz', 'ru'],
#  ['pda', 'schmax', 'litres', 'ru'],
#  ['www', 'sunhome', 'ru'],
#  ['blackterminal', 'ru'],
#  ['app', 'smart', 'com'],
#  ['xxxmshel', 'org'],
#  ['photos', 'com'],
#  ['rutube', 'ru'],
#  ['bobs', 'tube', 'com'],
#  ['pnzn', 'wikiotzyv', 'org'],
#  ['xn', 'sbbskz', 'aarel', 'c', 'xn', 'p', 'ai'],
#  ['myshows', 'me'],
#  ['www', 'eg', 'ru'],
#  ['cheese', 'home', 'com'],
#  ['regionyonsport', 'ch'],
#  ['mir', 'knigi', 'org'],
#  ['devstvennici', 'porno', 'ru'],
#  ['antijob', 'net'],
#  ['aif', 'ru'],
#  ['studizba', 'com'],
#  ['infourok', 'ru'],
#  ['docs', 'cntd', 'ru'],
#  ['onlinegdz', 'net'],
#  ['libcat', 'ru'],
#  ['xn', 'kc', 'a', 'akkdff', 'c', 'xn', 'p', 'ai'],
#  ['lolzteam', 'net'],
#  ['m', 'blablacar', 'ru'],
#  ['ogea', 'nichost', 'ru'],
#  ['moiinterier', 'com'],
#  ['imagineradio', 'podfm', 'ru'],
#  ['ilibrary', 'ru'],
#  ['en', 'erkiss', 'live'],
#  ['biqle', 'ru'],
#  ['zakupki', 'kontur', 'ru'],
#  ['www', 'liveinternet', 'ru'],
#  ['sinoptik', 'ua'],
#  ['www', 'mamba', 'ru'],
#  ['absolutavto', 'com', 'ua'],
#  ['deti', 'e', 'papa', 'com', 'ua'],
#  ['pda', 'litres', 'ru'],
#  ['meporno', 'net'],
#  ['kinohold', 'club'],
#  ['somon', 'tj'],
#  ['www', 'facebook', 'com'],
#  ['mail', 'ru'],
#  ['tl', 'rulate', 'ru'],
#  ['archive', 'is'],
#  ['www', 'lamoda', 'ru'],
#  ['russian', 'rt', 'com'],
#  ['menak', 'ru'],
#  ['betoncentr', 'ru'],
#  ['aptekirls', 'ru'],
#  ['seks', 'besplatno', 'org'],
#  ['gametarget', 'ru'],
#  ['darudar', 'org'],
#  ['lurkmore', 'net'],
#  ['www', 'pufikhomes', 'com'],
#  ['mail', 'ru'],
#  ['mail', 'ru'],
#  ['www', 'farpost', 'ru'],
#  ['spb', 'vseinstrumenti', 'ru'],
#  ['ebuxa', 'ru'],
#  ['bookfi', 'net'],
#  ['manga', 'online', 'biz'],
#  ['pikabu', 'ru'],
#  ['www', 'stranamam', 'ru'],
#  ['teleprogramma', 'pro'],
#  ['trubkom', 'ru'],
#  ['paris', 'taxi', 'money', 'info'],
#  ['ru', 'sputnik', 'kg'],
#  ['wp', 'scn', 'ru'],
#  ['rbook', 'me'],
#  ['m', 'yves', 'rocher', 'ru'],
#  ['www', 'olx', 'ua'],
#  ['abcbiznes', 'ru'],
#  ['www', 'pornktube', 'porn'],
#  ['resheba', 'me'],
#  ['novamods', 'ru'],
#  ['starmedia', 'kg'],
#  ['datarozhdenia', 'ru'],
#  ['www', 'metadoc', 'ru'],
#  ['novocherkassk', 'net'],
#  ['jorgensentrio', 'co', 'uk'],
#  ['ru', 'esosedi', 'org'],
#  ['pda', 'litres', 'ru'],
#  ['fotostrana', 'ru'],
#  ['www', 'stranamam', 'ru'],
#  ['pikabu', 'ru'],
#  ['www', 'sit', 'trans', 'com'],
#  ['tubsexer', 'com'],
#  ['prom', 'ua'],
#  ['azjio', 'ucoz', 'ru'],
#  ['porno', 'club'],
#  ['bio', 'learn', 'com'],
#  ['oxy', 'cloud'],
#  ['tver', 'gorodrabot', 'ru'],
#  ['tubeglory', 'net'],
#  ['nichese', 'ru'],
#  ['selogni', 'ru'],
#  ['www', 'film', 'ru'],
#  ['www', 'ecotour', 'by'],
#  ['nyam', 'ru'],
#  ['znatokkids', 'com', 'ua'],
#  ['erowall', 'com'],
#  ['weburg', 'net'],
#  ['www', 'rusporno', 'sexy'],
#  ['make', 'd', 'ru'],
#  ['cyberleninka', 'ru'],
#  ['fotostrana', 'ru'],
#  ['www', 'moscowmap', 'ru'],
#  ['eropixel', 'net'],
#  ['gigporno', 'top'],
#  ['www', 'jumpboobs', 'info'],
#  ['www', 'hfe', 'hfe', 'ru'],
#  ['games', 'answers', 'net'],
#  ['mywed', 'com'],
#  ['amp', 'tsargrad', 'tv'],
#  ['manga', 'online', 'biz'],
#  ['mail', 'ru'],
#  ['archive', 'is'],
#  ['prom', 'ua'],
#  ['m', 'babyblog', 'ru'],
#  ['rus', 'drivemusic', 'cc'],
#  ['www', 'idealmedia', 'io'],
#  ['bezbukv', 'ru'],
#  ['mail', 'ru'],
#  ['pickfilm', 'pro'],
#  ['obetone', 'com'],
#  ['vseobankah', 'ru'],
#  ['manga', 'online', 'biz'],
#  ['daftsex', 'com'],
#  ['hdzzo', 'ru'],
#  ['krepej', 'metiz', 'ru'],
#  ['aptekamos', 'ru'],
#  ['www', 'najox', 'com'],
#  ['mota', 'ru'],
#  ['www', 'olx', 'ua'],
#  ['www', 'sp', 'ru'],
#  ['mail', 'ru'],
#  ['rus', 'drivemusic', 'cc'],
#  ['docdoc', 'ru'],
#  ['pornoslon', 'me'],
#  ['vbkfyf', 'www', 'nn', 'ru'],
#  ['m', 'babyblog', 'ru'],
#  ['severouralsk', 'org'],
#  ['www', 'myshared', 'ru'],
#  ['ndv', 'ru'],
#  ['moskva', 'gorodrabot', 'ru'],
#  ['mp', 'cc', 'biz'],
#  ['baza', 'drom', 'ru'],
#  ['www', 'povarenok', 'ru'],
#  ['irecommend', 'ru'],
#  ['up', 'ru'],
#  ['hh', 'ru'],
#  ['tehcovet', 'ru'],
#  ['www', 'artfile', 'ru'],
#  ['kakzovut', 'ru'],
#  ['jobs', 'tut', 'by'],
#  ['ugdz', 'ru'],
#  ['xn', 'btbgivilhdbb', 'a', 'd', 'xn', 'p', 'ai'],
#  ['etu', 'ru'],
#  ['spb', 'tiu', 'ru'],
#  ['nudecelebvideo', 'net'],
#  ['ste', 'pashka', 'ru'],
#  ['klaksona', 'net'],
#  ['asmodei', 'org'],
#  ['tula', 'hh', 'ru'],
#  ['evg', 'crystal', 'ru'],
#  ['joyreactor', 'cc'],
#  ['www', 'erofullsets', 'com'],
#  ['www', 'graycell', 'ru'],
#  ['tvmoon', 'ru'],
#  ['archive', 'fo'],
#  ['ekburg', 'travelata', 'ru'],
#  ['habarovsk', 'cian', 'ru'],
#  ['demotos', 'ru'],
#  ['omanual', 'ru'],
#  ['daftsex', 'com'],
#  ['innocentdolll', 'info'],
#  ['otzovik', 'com'],
#  ['dic', 'academic', 'ru'],
#  ['www', 'enbek', 'kz'],
#  ['mail', 'ru'],
#  ['mail', 'ru'],
#  ['photogoroda', 'com'],
#  ['mod', 'land', 'ru'],
#  ['booksonline', 'com', 'ua'],
#  ['m', 'stoloto', 'ru'],
#  ['mail', 'ru'],
#  ['pornobomba', 'cc'],
#  ['xn', 'b', 'aaefabsd', 'cwaon', 'xn', 'p', 'ai'],
#  ['vseseriipodriad', 'ru'],
#  ['www', 'patisaray', 'org'],
#  ['fullxxxmovies', 'net'],
#  ['infourok', 'ru'],
#  ['topsto', 'crimea', 'ru'],
#  ['cocaporn', 'com'],
#  ['ftopx', 'com'],
#  ['youla', 'ru'],
#  ['burjauto', 'com'],
#  ['m', 'sports', 'ru'],
#  ['rootgame', 'org'],
#  ['clipart', 'library', 'com'],
#  ['target', 'my', 'com'],
#  ['tralolo', 'com'],
#  ['mamontenok', 'online', 'ru'],
#  ['myley', 'info'],
#  ['online', 'zakon', 'kz'],
#  ['felomena', 'com'],
#  ['amp', 'znaj', 'ua', 'cdn', 'ampproject', 'org'],
#  ['www', 'akceleratorbiznesu', 'eu'],
#  ['mail', 'ru'],
#  ['gt', 'diamant', 'ru'],
#  ['oilcapital', 'ru'],
#  ['virtualgameinfo', 'ru'],
#  ['saratov', 'ucheba', 'ru'],
#  ['apkua', 'net'],
#  ['www', 'perfectgirls', 'net'],
#  ['m', 'sportmaster', 'ru'],
#  ['infourok', 'ru'],
#  ['mtlarena', 'ru'],
#  ['geographyoftourism', 'ru'],
#  ['mail', 'ru'],
#  ['kartaslov', 'ru'],
#  ['manga', 'online', 'biz'],
#  ['savoir', 'news'],
#  ['kupuk', 'net'],
#  ['www', 'rabota', 'ru'],
#  ['www', 'perfectgirls', 'net'],
#  ['m', 'tralolo', 'com'],
#  ['www', 'vokrug', 'tv'],
#  ['gidfilm', 'ru'],
#  ['www', 'slonsneakers', 'ru'],
#  ['www', 'nn', 'ru'],
#  ['nanegative', 'ru'],
#  ['legalacts', 'ru'],
#  ['www', 'vseinstrumenti', 'ru'],
#  ['knigid', 'ru'],
#  ['www', 'liveinternet', 'ru'],
#  ['videobox', 'tv'],
#  ['kino', 'rambler', 'ru'],
#  ['www', 'cian', 'ru'],
#  ['sentyabr', 'meteogu', 'ru'],
#  ['www', 'designonstop', 'com'],
#  ['www', 'citilink', 'ru'],
#  ['mail', 'ru'],
#  ['adult', 'tv', 'com'],
#  ['kuponinaskidku', 'ru'],
#  ['bessporno', 'tv'],
#  ['asilmedia', 'net'],
#  ['mail', 'ru'],
#  ['tubegoal', 'ru'],
#  ['m', 'ru', 'xvideos', 'tv'],
#  ['www', 'techcult', 'ru'],
#  ['med', 'books', 'by'],
#  ['kz', 'orgpage', 'ru'],
#  ['www', 'koleso', 'razmer', 'ru'],
#  ['e', 'libra', 'ru'],
#  ['logopedprofiportal', 'ru'],
#  ['sud', 'praktika', 'ru'],
#  ['www', 'sweetzagar', 'ru'],
#  ['smotret', 'anime', 'ru'],
#  ['chelyabinsk', 'yp', 'ru'],
#  ['biqle', 'ru'],
#  ['mp', 'goo', 'ru'],
#  ['m', 'z', 'fm'],
#  ['pozdrawlyai', 'ru'],
#  ['www', 'lala', 'style', 'ru'],
#  ['it', 'ancensored', 'com'],
#  ['aquariumistika', 'ru'],
#  ['surgut', 'cian', 'ru'],
#  ['amp', 'kp', 'ru'],
#  ['online', 'tusa', 'com'],
#  ['www', 'dom', 'by'],
#  ['biznes', 'prost', 'ru'],
#  ['referatbank', 'ru'],
#  ['ural', 'prom', 'com'],
#  ['v', 'trifon', 'io', 'ua'],
#  ['parvanova', 'eu'],
#  ['www', 'gtaall', 'com', 'br'],
#  ['shop', 'npravdina', 'ru'],
#  ['www', 'chaskor', 'ru'],
#  ['kenhtruyen', 'com'],
#  ['craft', 'ru'],
#  ['love', 'neolove', 'ru'],
#  ['muz', 'xyz'],
#  ['faberlic', 'com'],
#  ['mail', 'ru'],
#  ['uniondht', 'org'],
#  ['hghltd', 'yandex', 'net'],
#  ['kuler', 'tv', 'net'],
#  ['www', 'masterinvest', 'info'],
#  ['samara', 'hh', 'ru'],
#  ['tvzvezda', 'ru'],
#  ['perm', 'vseinstrumenti', 'ru'],
#  ['m', 'stoloto', 'ru'],
#  ['rostov', 'hh', 'ru'],
#  ['tekstovoi', 'ru'],
#  ['rutube', 'ru'],
#  ['www', 'motorpage', 'ru'],
#  ['m', 'baby', 'ru', 'cdn', 'ampproject', 'org'],
#  ['medbrowse', 'com', 'ua'],
#  ['alloshow', 'ru'],
#  ['yar', 'repetitory', 'online'],
#  ['www', 'eroxxvideos', 'tv'],
#  ['mp', 'pesni', 'site'],
#  ['polymax', 'yaroslavl', 'blizko', 'ru'],
#  ['sunlight', 'net'],
#  ['www', 'mamba', 'ru'],
#  ['clinica', 'ideal', 'ru'],
#  ['mail', 'ru'],
#  ['busters', 'porn'],
#  ['www', 'picture', 'russia', 'com'],
#  ['prom', 'ua'],
#  ['terrikon', 'com'],
#  ['oose', 'ru'],
#  ['aviata', 'kz'],
#  ['www', 'ivi', 'ru'],
#  ['vse', 'audioknigi', 'ru'],
#  ['www', 'cyberforum', 'ru'],
#  ['ideymnogo', 'ru'],
#  ['tophotels', 'ru'],
#  ['offset', 'moscow'],
#  ['internetopros', 'ru'],
#  ['biqle', 'ru'],
#  ['vunivere', 'ru'],
#  ['www', 'kontest', 'ru'],
#  ['ati', 'su'],
#  ['pro', 'ford', 'com'],
#  ['wearesovereign', 'org'],
#  ['it', 'all', 'biz'],
#  ['teremok', 'sad', 'ucoz', 'ru'],
#  ['mail', 'ru'],
#  ['luxeryshop', 'ru'],
#  ['iknigi', 'net'],
#  ['mail', 'ru'],
#  ['samara', 'diold', 'ru'],
#  ['vgtimes', 'ru'],
#  ['www', 'muzcards', 'com'],
#  ['findfood', 'ru'],
#  ['nn', 'pulscen', 'ru'],
#  ['m', 'babyblog', 'ru'],
#  ['mail', 'ru'],
#  ['poezdato', 'net'],
#  ['cent', 'emails', 'com'],
#  ['forum', 'pushkino', 'org'],
#  ['ru', 'clip', 'net'],
#  ['etp', 'armtek', 'by'],
#  ['videoglaz', 'ru'],
#  ['onlymult', 'com'],
#  ['www', 'rusprofile', 'ru'],
#  ['ydoo', 'info'],
#  ['www', 'laredoute', 'ru'],
#  ['mail', 'ru'],
#  ['www', 'super', 'kg'],
#  ['anime', 'free', 'net'],
#  ['doxysexy', 'com'],
#  ['igr', 'net'],
#  ['author', 'ru'],
#  ['www', 'air', 'gun', 'ru'],
#  ['sbis', 'ru'],
#  ['ingush', 'empire', 'com'],
#  ['fastpic', 'ru'],
#  ['gameground', 'ru'],
#  ['index', 'kodifikant', 'ru'],
#  ['www', 'citatyonas', 'ru'],
#  ['mingkh', 'ru'],
#  ['v', 'tope', 'com'],
#  ['mail', 'ru'],
#  ['www', 'chitalkino', 'ru'],
#  ['remont', 'aud', 'net'],
#  ['www', 'civilniy', 'org', 'ua'],
#  ['booksonline', 'com', 'ua'],
#  ['shop', 'odintattoo', 'ru'],
#  ['jobs', 'tut', 'by'],
#  ['sozdik', 'kz'],
#  ['m', 'trulolo', 'com'],
#  ['www', 'infoflot', 'com'],
#  ['tabaksale', 'com'],
#  ['m', 'tabor', 'ru'],
#  ['at', 'reactor', 'cc'],
#  ['kartami', 'ru'],
#  ['botsman', 'info'],
#  ['biqle', 'ru'],
#  ['xn', 'adbj', 'cckt', 'xn', 'p', 'ai'],
#  ['worldthoughts', 'ru'],
#  ['www', 'arms', 'expo', 'ru'],
#  ['www', 'chipdip', 'ru'],
#  ['www', 'politforums', 'net'],
#  ['mail', 'ru'],
#  ['spb', 'hh', 'ru'],
#  ['kinogoo', 'cc'],
#  ['www', 'vimore', 'org'],
#  ['jacsdergisi', 'com'],
#  ['adizesbaku', 'com'],
#  ['market', 'kz'],
#  ['mail', 'ru'],
#  ['kinash', 'ru'],
#  ['love', 'amyr', 'ru'],
#  ['spirk', 'ru'],
#  ['etp', 'armtek', 'ru'],
#  ['testwww', 'nalog', 'ru'],
#  ['kodeksy', 'kz', 'com'],
#  ['teksty', 'pesenok', 'ru'],
#  ['sportlink', 'by'],
#  ['fisting', 'blog', 'org'],
#  ['mail', 'ru'],
#  ['ekipirovka', 'ru'],
#  ['botsman', 'info'],
#  ['www', 'blablacar', 'ru'],
#  ['onrealt', 'ru'],
#  ['gala', 'co', 'ru'],
#  ['zaycev', 'net'],
#  ['dateandtime', 'info'],
#  ['m', 'rusex', 'club', 'me'],
#  ['pornotut', 'name'],
#  ['sprotiv', 'org'],
#  ['www', 'ahtubinsk', 'ru'],
#  ['v', 's', 'mobi'],
#  ['dacha', 'expert'],
#  ['mail', 'ru'],
#  ['chernayamagiya', 'com'],
#  ['manga', 'online', 'biz'],
#  ['reform', 'by'],
#  ['mail', 'ru'],
#  ['dip', 'su'],
#  ['m', 'tutu', 'ru'],
#  ['vklipe', 'net'],
#  ['poezdato', 'net'],
#  ['www', 'yoox', 'com'],
#  ['profinapup', 'dip', 'jp'],
#  ['www', 'aviasales', 'ru'],
#  ['www', 'vkonline', 'ru'],
#  ['karaopa', 'ru'],
#  ['www', 'mockupdownload', 'ru'],
#  ['playgame', 'com'],
#  ['youla', 'ru'],
#  ['mail', 'ru'],
#  ['baza', 'drom', 'ru'],
#  ['www', 'samaraphone', 'ru'],
#  ['baraholka', 'onliner', 'by'],
#  ['www', 'regtalon', 'ru'],
#  ['mail', 'ru'],
#  ['kaspi', 'kz'],
#  ['pluggedin', 'ru'],
#  ['www', 'mamba', 'ru'],
#  ['vnnews', 'ru'],
#  ['www', 'pornhat', 'com'],
#  ['torrentfilm', 'me'],
#  ['n', 'torrents', 'org'],
#  ['www', 'hibiny', 'com'],
#  ['news', 'rambler', 'ru'],
#  ['xlecx', 'com'],
#  ['kings', 'ru'],
#  ['www', 'neolink', 'by'],
#  ['citaty', 'info'],
#  ['dle', 'faq', 'ru'],
#  ['www', 'ekaterinburgphone', 'ru'],
#  ['goodcookbook', 'ru'],
#  ['android', 'firmware', 'pro'],
#  ['www', 'petergid', 'ru'],
#  ['www', 'elekont', 'ru'],
#  ['leroy', 'merlin', 'catalog', 'ru'],
#  ['spb', 'kolesa', 'darom', 'ru'],
#  ['appwarm', 'com'],
#  ['angarsk', 'drom', 'ru'],
#  ['cool', 'dj'],
#  ['biqle', 'ru'],
#  ['gunsbroker', 'ru'],
#  ['www', 'princess', 'sport', 'ru'],
#  ['instascan', 'live'],
#  ['cinemaxx', 'cc'],
#  ['fastpic', 'ru'],
#  ['usatiki', 'ru'],
#  ['hot', 'comix', 'com'],
#  ['spec', 'drom', 'ru'],
#  ['www', 'labirint', 'ru'],
#  ['www', 'euroki', 'org'],
#  ['www', 'vseinstrumenti', 'ru'],
#  ['www', 'mamba', 'ru'],
#  ['pikabu', 'ru'],
#  ['ipleer', 'fm'],
#  ['webcamsbabe', 'com'],
#  ['meduniver', 'com'],
#  ['fotores', 'ru'],
#  ['beautynews', 'ru'],
#  ['m', 'stoloto', 'ru'],
#  ['playerslife', 'ru'],
#  ['nelikvid', 'com'],
#  ['news', 'milli', 'az'],
#  ['lifehacker', 'ru'],
#  ['flocktory', 'com'],
#  ['www', 'mvideo', 'ru'],
#  ['mp', 'party', 'net'],
#  ['m', 'realt', 'by'],
#  ['www', 'gismeteo', 'ru'],
#  ['womanmirror', 'ru'],
#  ['letidor', 'ru'],
#  ['www', 'liveinternet', 'ru'],
#  ['onesong', 'ru'],
#  ['www', 'mamba', 'ru'],
#  ['rusfolder', 'com'],
#  ['stolichki', 'ru'],
#  ['petropavlovsk', 'kamchatskiy', 'drom', 'ru'],
#  ['pesniclub', 'com'],
#  ['shopozz', 'ru'],
#  ['nazya', 'com'],
#  ['love', 'wab', 'ru'],
#  ['top', 'dshop', 'ru'],
#  ['avto', 'cvet', 'ru'],
#  ['tambov', 'blizko', 'ru'],
#  ['mail', 'ru'],
#  ['strana', 'ua'],
#  ['new', 'optica', 'ru'],
#  ['www', 'segodnya', 'ua', 'cdn', 'ampproject', 'org'],
#  ['myzcloud', 'me'],
#  ['mail', 'ru'],
#  ['gohome', 'by'],
#  ['omsk', 'drom', 'ru'],
#  ['www', 'utkonos', 'ru'],
#  ['recepta', 'com'],
#  ['paint', 'dot', 'net', 'narod', 'ru'],
#  ['files', 'stroyinf', 'ru'],
#  ['www', 'liveinternet', 'ru'],
#  ['vkus', 'mp', 'ru'],
#  ['infourok', 'ru'],
#  ['www', 'palitra', 'ru'],
#  ['www', 'drive', 'ru'],
#  ['vmeste', 'opredelim', 'com'],
#  ['awards', 'com'],
#  ['ftopx', 'com'],
#  ['biqle', 'ru'],
#  ['zapatos', 'ru'],
#  ['irecommend', 'ru'],
#  ['mail', 'ru'],
#  ['www', 'farpost', 'ru'],
#  ['sudact', 'ru'],
#  ['studopedia', 'ru'],
#  ['mail', 'ru'],
#  ['uniondht', 'org'],
#  ['navechno', 'com'],
#  ['zipzapas', 'ru'],
#  ['topreading', 'ru'],
#  ['www', 'materik', 'm', 'ru'],
#  ['vitebsk', 'deal', 'by'],
#  ['mp', 'party', 'net'],
#  ['mail', 'ru'],
#  ['www', 'hausdorf', 'ru'],
#  ['ps', 'ds', 'info'],
#  ['mail', 'ru'],
#  ['baza', 'drom', 'ru'],
#  ['eropiks', 'com'],
#  ['kinomoov', 'fun'],
#  ['erkiss', 'live'],
#  ['kudago', 'com'],
#  ['www', 'aif', 'by'],
#  ['rokoko', 'samaragid', 'ru'],
#  ['rutube', 'ru'],
#  ['komsomolsk', 'na', 'amure', 'superjob', 'ru'],
#  ['www', 'consultant', 'ru'],
#  ['www', 'vokrug', 'tv'],
#  ['zapozdravleniem', 'ru'],
#  ['rutube', 'ru'],
#  ['dojkihd', 'mobi'],
#  ['www', 'drive', 'ru'],
#  ['mail', 'ru'],
#  ['tv', 'ru', 'cdn', 'ampproject', 'org'],
#  ['m', 'stoloto', 'ru'],
#  ['infopedia', 'su'],
#  ['soccerlife', 'ru'],
#  ['samara', 'goplace', 'ru'],
#  ['mail', 'ru'],
#  ['knigibesplatno', 'you', 'ru'],
#  ['dom', 'mingkh', 'ru'],
#  ['mail', 'ru'],
#  ['mp', 'party', 'net'],
#  ['videouroki', 'net'],
#  ['www', 'ds', 'ru'],
#  ['uazpatriotsib', 'ru'],
#  ['forum', 'guns', 'ru'],
#  ['hcsokol', 'n', 'eb', 'net'],
#  ['m', 'keng', 'ru'],
#  ['mail', 'ru'],
#  ['hithdrezka', 'com'],
#  ['www', 'izden', 'kz'],
#  ['urok', 'sept', 'ru'],
#  ['interesno', 'co'],
#  ['fotostrana', 'ru'],
#  ['mail', 'ru'],
#  ['www', 'livelib', 'ru'],
#  ['m', 'babyblog', 'ru'],
#  ['rusactors', 'ru'],
#  ['zaycev', 'net'],
#  ['cinemate', 'cc'],
#  ['bcm', 'ru'],
#  ['pskov', 'bizly', 'ru'],
#  ['goodserials', 'tv'],
#  ['jobs', 'tut', 'by'],
#  ['pozdravok', 'ru'],
#  ['xn', 'j', 'ahfl', 'xn', 'p', 'ai'],
#  ['mail', 'ru'],
#  ['talantiz', 'com'],
#  ['taggsm', 'ru'],
#  ['forum', 'zakon', 'kz'],
#  ['laradiofm', 'ru'],
#  ['www', 'yaplakal', 'com'],
#  ['sergnechaev', 'usite', 'pro'],
#  ['tr', 'bestinsectkiller', 'com'],
#  ['www', 'prima', 'inform', 'ru'],
#  ['videocelebs', 'net'],
#  ['elantra', 'club', 'ru'],
#  ['zdr', 'ru'],
#  ['zooclub', 'ru'],
#  ['www', 'chocotravel', 'com'],
#  ['mp', 'xa', 'me'],
#  ['fotostrana', 'ru'],
#  ['mail', 'ru'],
#  ['deal', 'by'],
#  ['www', 'farfetch', 'com'],
#  ['myfialka', 'ru'],
#  ['bessporno', 'tv'],
#  ['factor', 'vendeo', 'ru'],
#  ['cyberleninka', 'ru'],
#  ['zaycev', 'net'],
#  ['m', 'lamoda', 'ru'],
#  ['permnews', 'ru'],
#  ['dic', 'academic', 'ru'],
#  ['livnysportschool', 'ru'],
#  ['kulinarnayakarusel', 'ru'],
#  ['www', 'rosteco', 'ru'],
#  ['xn', 'mlcgdfdonz', 'h', 'b', 'xn', 'p', 'ai'],
#  ['phone', 'k', 'by'],
#  ['neagent', 'info'],
#  ['m', 'hh', 'ru'],
#  ['mosaica', 'ru'],
#  ['igr', 'net'],
#  ['allestate', 'ru'],
#  ['zombie', 'film', 'com'],
#  ['regionyonsport', 'ch'],
#  ['www', 'liveinternet', 'ru'],
#  ['mail', 'ru'],
#  ['moviestape', 'net'],
#  ['libking', 'ru'],
#  ['www', 'kino', 'teatr', 'ru'],
#  ['knijky', 'ru'],
#  ['prom', 'ua'],
#  ['www', 'labirint', 'ru'],
#  ['www', 'drive', 'ru'],
#  ['es', 'flowergardennews', 'com'],
#  ['vodoroslionline', 'ru'],
#  ['www', 'bolshoyvopros', 'ru'],
#  ['tutomath', 'ru'],
#  ['fotostrana', 'ru'],
#  ['yuridicheskaya', 'konsultatsiya', 'moskva', 'ru'],
#  ['trupornolabs', 'org'],
#  ['kinokrad', 'co'],
#  ['www', 'eg', 'ru'],
#  ['m', 'olx', 'kz'],
#  ['pesnimp', 'ru'],
#  ['rubasket', 'com'],
#  ['www', 'rusprofile', 'ru'],
#  ['hdlkazakhstan', 'kz'],
#  ['m', 'lamoda', 'ru'],
#  ['www', 'astrotoys', 'ru'],
#  ['novosti', 'dny', 'ru'],
#  ['sudact', 'ru'],
#  ['porn', 'flix', 'club'],
#  ['no', 'vermin', 'club', 'org'],
#  ['incest', 'porn', 'me'],
#  ['sims', 'pack', 'ru'],
#  ['ingalyator', 'online'],
#  ['m', 'blablacar', 'ru'],
#  ['www', 'asos', 'com'],
#  ['forum', 'dollplanet', 'ru'],
#  ['folksland', 'net'],
#  ['www', 'telejob', 'ru'],
#  ['polnaja', 'vagina', 'spermy', 'onl', 'titsallglobalschools', 'com'],
#  ['nn', 'tiu', 'ru'],
#  ['www', 'banki', 'ru'],
#  ['pornozak', 'live'],
#  ['reshalka', 'com'],
#  ['www', 'allmonarchs', 'net'],
#  ['hunting', 'movie', 'ru'],
#  ['loveplanet', 'ru'],
#  ['dating', 'ru'],
#  ['zvooq', 'pro'],
#  ['www', 'olx', 'ua'],
#  ['agroserver', 'ru'],
#  ['m', 'realt', 'by'],
#  ['porno', 'name'],
#  ['ljubimyj', 'detskij', 'ru'],
#  ['sodosopa', 'co'],
#  ['ru'],
#  ['pikabu', 'ru'],
#  ['spb', 'hh', 'ru'],
#  ['www', 'rusprofile', 'ru'],
#  ['libking', 'ru'],
#  ['pornsexer', 'com'],
#  ['daftsex', 'com'],
#  ['www', 'medicinalplants', 'ru'],
#  ['manga', 'online', 'biz'],
#  ['tomsk', 'drom', 'ru'],
#  ['etp', 'armtek', 'by'],
#  ['m', 'ikea', 'com'],
#  ['manga', 'chan', 'me'],
#  ['www', 'olx', 'ua'],
#  ['ru', 'maps', 'me'],
#  ['serov', 'superjob', 'ru'],
#  ['eva', 'ru'],
#  ['vaginke', 'tv'],
#  ['ww', 'torrented', 'xyz'],
#  ['reshak', 'ru'],
#  ['tabor', 'ru'],
#  ['good', 'looks', 'info'],
#  ['www', 'olx', 'ua'],
#  ['familyguy', 'fox', 'fan', 'tv'],
#  ['zobo', 'ghabdi', 'gq'],
#  ['pornotwix', 'com'],
#  ['flagma', 'ru'],
#  ['mp', 'cc', 'biz'],
#  ['kazan', 'tiu', 'ru'],
#  ['www', 'sunhome', 'ru'],
#  ['n', 'torrents', 'org'],
#  ['www', 'bonprix', 'ru'],
#  ['www', 'olx', 'kz'],
#  ['myzcloud', 'me'],
#  ['cyberleninka', 'ru'],
#  ['old', 'fishki', 'net'],
#  ['daftsex', 'com'],
#  ['v', 'olschan', 'ru'],
#  ['m', 'ru'],
#  ['surak', 'baribar', 'kz'],
#  ['www', 'zadomikom', 'ru'],
#  ['xobi', 'com', 'ua'],
#  ['pornozadrot', 'com'],
#  ['podmel', 'ru'],
#  ['www', 'liveinternet', 'ru'],
#  ['rajwap', 'xyz'],
#  ['dalnoboyshiki', 'eu'],
#  ['www', 'drive', 'ru'],
#  ['otzovik', 'com'],
#  ['www', 'farpost', 'ru'],
#  ['mail', 'ru'],
#  ['www', 'santex', 'lux', 'ru'],
#  ['photosight', 'ru'],
#  ['n', 'torrents', 'org'],
#  ['www', 'ziyo', 'music', 'com'],
#  ['www', 'tubidycepindir', 'co'],
#  ['sudact', 'ru'],
#  ['pornovideo', 'net'],
#  ['millionstatusov', 'ru'],
#  ['privat', 'zapisi', 'biz'],
#  ['www', 'farpost', 'ru'],
#  ['zoon', 'ru'],
#  ['milaha', 'www', 'nn', 'ru'],
#  ['mirmam', 'pro'],
#  ['spec', 'drom', 'ru'],
#  ['www', 'perfectgirls', 'net'],
#  ['surprisse', 'com'],
#  ['sxshentai', 'com'],
#  ['mail', 'ru'],
#  ['mosgortur', 'ru'],
#  ['incest', 'porno', 'pro'],
#  ['www', 'litlib', 'net'],
#  ['slavia', 'by'],
#  ['felomena', 'com'],
#  ['mail', 'ru'],
#  ['forum', 'hiddencam', 'tv'],
#  ['rabota', 'vo', 'ru'],
#  ['m', 'sobaka', 'ru'],
#  ['texartel', 'ru'],
#  ['mail', 'ru'],
#  ['popgun', 'ru'],
#  ['rg', 'ru'],
#  ['shuri', 'muri', 'com'],
#  ['vodomotorika', 'ru'],
#  ['jobs', 'tut', 'by'],
#  ['smysh', 'shop', 'ru'],
#  ['mail', 'ru'],
#  ['fishki', 'net'],
#  ['en', 'kartaslov', 'ru'],
#  ['nkkf', 'ru'],
#  ['novinkino', 'com'],
#  ['mail', 'ru'],
#  ['www', 'moyareklama', 'ru'],
#  ['rifornekb', 'blizko', 'ru'],
#  ['krasnodar', 'zarplata', 'ru'],
#  ['www', 'softportal', 'com'],
#  ['magya', 'online', 'ru'],
#  ['oepress', 'ru'],
#  ['ecocomanda', 'ru'],
#  ['dotaunderlords', 'ru'],
#  ['print', 'ru'],
#  ['jewish', 'ru'],
#  ['phone', 'cinema', 'ru'],
#  ['zyrsskaf', 'ccleaner', 'tech'],
#  ['v', 's', 'mobi'],
#  ['mail', 'ru'],
#  ['all', 'detal', 'ru'],
#  ['omegasound', 'ru'],
#  ['www', 'sop', 'com', 'ua'],
#  ['tonkiimir', 'ru'],
#  ['amital', 'ru'],
#  ['ishim', 'nezaberete', 'ru'],
#  ['mail', 'ru'],
#  ['blacktyres', 'ru'],
#  ['www', 'aup', 'ru'],
#  ['mail', 'ru'],
#  ['www', 'perfectgirls', 'net'],
#  ['transphoto', 'ru'],
#  ['hh', 'kz'],
#  ['mail', 'ru'],
#  ['gtalogo', 'com'],
#  ['ipad', 'perfectgirls', 'net'],
#  ['tomsk', 'blizko', 'ru'],
#  ['www', 'roof', 'n', 'roll', 'ru'],
#  ['porno', 'blog'],
#  ['b', 'mirkino', 'club'],
#  ['m', 'trulolo', 'com'],
#  ['xvideosx', 'mobi'],
#  ['liveanimal', 'ru'],
#  ['mobi', 'dating', 'ru'],
#  ['sextorrent', 'net'],
#  ['zaycev', 'net'],
#  ['rusex', 'club', 'me'],
#  ...]

# %%
docs_title
# Out:
# [['экс',
#   'министр',
#   'экономики',
#   'молдовы',
#   'главе',
#   'мидэи',
#   'цель',
#   'которого',
#   'сделать',
#   'из',
#   'республики',
#   'не',
#   'просителя',
#   'а',
#   'донора',
#   'надо',
#   'избегать',
#   'долгого',
#   'нахождения',
#   'н'],
#  ['эта',
#   'песня',
#   'стала',
#   'известна',
#   'многим',
#   'телезрителям',
#   'благодаря',
#   'сериалу',
#   'диверсант'],
#  ['банши', 'сезон', 'серия', 'бремя', 'красоты', 'смотреть', 'онлайн'],
#  ['не', 'беси', 'меня', 'картинки'],
#  ['в',
#   'новомосковске',
#   'сыграют',
#   'следж',
#   'хоккеисты',
#   'алексинской',
#   'звезды',
#   'и',
#   'сборной',
#   'китая',
#   'т'],
#  ['салат',
#   'корейская',
#   'морковь',
#   'копченая',
#   'курица',
#   'кукуруза',
#   'сухарики',
#   'мой',
#   'калорийность',
#   'белки',
#   'жиры',
#   'углеводы'],
#  ['угловой',
#   'пневмогайковерт',
#   'fubag',
#   'rwc',
#   'в',
#   'екатеринбурге',
#   'купить',
#   'цены',
#   'отзывы',
#   'характеристики',
#   'фото',
#   'инструкция'],
#  ['табачный',
#   'магазин',
#   'мир',
#   'табака',
#   'курительные',
#   'трубки',
#   'stanwell',
#   'курительная',
#   'труб'],
#  ['league', 'of', 'legends', 'page', 'porn', 'comics', 'free', 'online'],
#  ['р', 'одесса', 'ростов', 'на', 'дону', 'сентября', 'фаворит', 'чп'],
#  ['огэ', 'математика', 'функции', 'задача', 'fb', 'ответ', 'готов'],
#  ['мировая',
#   'экономика',
#   'в',
#   'схемах',
#   'и',
#   'таблицах',
#   'млн',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['кримпай',
#   'мать',
#   'и',
#   'сын',
#   'страница',
#   'смотреть',
#   'порно',
#   'мультики',
#   'порно',
#   'комиксы',
#   'хентай',
#   'онлайн',
#   'бесплатно'],
#  ['мария',
#   'шорох',
#   'без',
#   'права',
#   'выбора',
#   'академия',
#   'си',
#   'читать',
#   'онлайн'],
#  ['в', 'днепре', 'нашли', 'пропавшую', 'летнюю', 'девушку'],
#  ['мой', 'мир', 'mail', 'ru'],
#  ['слава', 'медяник', 'стучат', 'колёса'],
#  ['инженерный',
#   'институт',
#   'казанского',
#   'приволжского',
#   'федерального',
#   'университета',
#   'учёба',
#   'ру'],
#  ['каковы',
#   'основные',
#   'черты',
#   'размещения',
#   'отраслей',
#   'топливной',
#   'промышленности',
#   'на',
#   'территорий',
#   'россии',
#   'млн',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['мужик',
#   'поставил',
#   'блондинку',
#   'раком',
#   'и',
#   'отодрал',
#   'ее',
#   'тугое',
#   'очко',
#   'порно',
#   'видео',
#   'на',
#   'eropixel',
#   'net'],
#  ['портер',
#   'джейн',
#   'под',
#   'звездным',
#   'дождем',
#   'скачать',
#   'бесплатно',
#   'книгу',
#   'в',
#   'формате',
#   'fb',
#   'doc',
#   'rtf',
#   'html',
#   'txt'],
#  ['порно', 'которое', 'ты', 'искал', 'видео', 'spaces', 'ru', 'spcs', 'me'],
#  ['услуга',
#   'городской',
#   'номер',
#   'как',
#   'подключить',
#   'мобильный',
#   'билайн',
#   'ульяновск'],
#  ['murodbek', 'qilichev', 'bilmiram', 'xorazm', 'net'],
#  ['погода',
#   'в',
#   'сочи',
#   'в',
#   'сентябре',
#   'тыс',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['gismeteo',
#   'погода',
#   'у',
#   'гостомел',
#   'на',
#   'дн',
#   'в',
#   'прогноз',
#   'погоди',
#   'на',
#   'дн',
#   'в',
#   'рп',
#   'нь',
#   'ки',
#   'вська',
#   'область',
#   'укра',
#   'на'],
#  ['службы', 'поддержки'],
#  ['моя', 'учетная', 'запись', 'нальчик'],
#  ['кожа', 'волосы', 'ногти', 'результаты', 'поиска'],
#  ['форма',
#   'наряда',
#   'допуска',
#   'на',
#   'производство',
#   'работ',
#   'в',
#   'местах',
#   'действия',
#   'опасных',
#   'или',
#   'вредных',
#   'факторов',
#   'снип',
#   'безопасность',
#   'труда',
#   'в',
#   'строительстве',
#   'часть',
#   'первая'],
#  ['the', 'retuses', 'ласточка', 'аккорды', 'текст', 'mp', 'видео'],
#  ['школьная',
#   'форма',
#   'солнце',
#   'мод',
#   'черного',
#   'цвета',
#   'цена',
#   'руб',
#   'купить',
#   'в',
#   'гомеле',
#   'deal',
#   'by',
#   'id'],
#  ['диалог'],
#  ['купить',
#   'встраив',
#   'газовая',
#   'панель',
#   'hotpoint',
#   'ariston',
#   'tqg',
#   'ha',
#   'bk',
#   'в',
#   'каталоге',
#   'интернет',
#   'магазина',
#   'м',
#   'видео',
#   'по',
#   'выгодной',
#   'цене',
#   'с',
#   'доставкой',
#   'отзывы',
#   'фотографии',
#   'вел'],
#  ['auto', 'n'],
#  ['форма', 'для', 'леденцов', 'и', 'шоколада', 'курочка', 'ряба', 'купить'],
#  ['какой',
#   'будет',
#   'погода',
#   'в',
#   'ноябре',
#   'новости',
#   'казахстана',
#   'tengrinews'],
#  ['видео',
#   'dio',
#   'don',
#   't',
#   'talk',
#   'to',
#   'strangers',
#   'irina',
#   'gern',
#   'видео',
#   'mail',
#   'ru'],
#  ['tactical', 'job', 'shirt', 'zip', 'xxl', 'fire', 'navy', 'lamnia'],
#  ['ohm', 'cs'],
#  ['отзыв',
#   'о',
#   'домкрат',
#   'подкатной',
#   'гидравлический',
#   'ombra',
#   'онт',
#   'удобный',
#   'но',
#   'тяжелый',
#   'домкрат'],
#  ['лесбийский',
#   'секс',
#   'с',
#   'кунилингусом',
#   'двух',
#   'стройных',
#   'студенток',
#   'высококачественное',
#   'порно',
#   'видео',
#   'с',
#   'участием',
#   'эмили',
#   'блум'],
#  ['презентация',
#   'на',
#   'тему',
#   'приближенное',
#   'значение',
#   'абсолютная',
#   'и',
#   'относительная',
#   'погрешнос'],
#  ['горбачев',
#   'октября',
#   'намерен',
#   'участвовать',
#   'в',
#   'заседании',
#   'по',
#   'иску',
#   'жириновского',
#   'политика',
#   'тасс'],
#  ['москва', 'марокко', 'на', 'ночей', 'руб'],
#  ['гоша',
#   'матарадзе',
#   'два',
#   'сердца',
#   'dj',
#   'movskii',
#   'dj',
#   'karasev',
#   'remix',
#   'слушать',
#   'бесплатно',
#   'онлайн'],
#  ['миски', 'салатники', 'страница'],
#  ['lesbians',
#   'monique',
#   'alexander',
#   'and',
#   'violet',
#   'starr',
#   'fuck',
#   'on',
#   'the',
#   'table',
#   'porn',
#   'video'],
#  ['мельница',
#   'крупорушка',
#   'заводского',
#   'изготовления',
#   'квт',
#   'в',
#   'срочно',
#   'грн',
#   'оборудование',
#   'кременчуг',
#   'на',
#   'olx'],
#  ['na'],
#  ['avon',
#   'scent',
#   'essence',
#   'lime',
#   'verbena',
#   'ни',
#   'изюминки',
#   'тебе',
#   'ни',
#   'лимончика',
#   'обычная',
#   'и'],
#  ['как',
#   'снять',
#   'быстросъем',
#   'с',
#   'печки',
#   'фокус',
#   'тыс',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['indian',
#   'aunty',
#   'bjowjob',
#   'and',
#   'fucking',
#   'with',
#   'her',
#   'partner',
#   'indians',
#   'get',
#   'fucked'],
#  ['sweet',
#   'russian',
#   'honey',
#   'angelika',
#   'got',
#   'down',
#   'and',
#   'dirty',
#   'with',
#   'her',
#   'roommate',
#   'because',
#   'she',
#   'was',
#   'horny',
#   'ipad',
#   'porn',
#   'at',
#   'perfect',
#   'girls'],
#  ['маленькие',
#   'с',
#   'характером',
#   'частный',
#   'детский',
#   'сад',
#   'детский',
#   'центр',
#   'в',
#   'хорошево',
#   'мневниках'],
#  ['playlist', 'lesbian', 'daftsex'],
#  ['фото',
#   'голых',
#   'девочек',
#   'и',
#   'бесплатная',
#   'эротика',
#   'на',
#   'topdevka',
#   'com'],
#  ['порно',
#   'видео',
#   'эротические',
#   'фильмы',
#   'с',
#   'малолетками',
#   'на',
#   'dohera',
#   'porno',
#   'net'],
#  ['света',
#   'света',
#   'оренбург',
#   'оренбургская',
#   'обл',
#   'россия',
#   'лет',
#   'на',
#   'мой',
#   'мир',
#   'mail',
#   'ru'],
#  ['вакансии',
#   'микролаб',
#   'системс',
#   'в',
#   'москве',
#   'работа',
#   'в',
#   'микролаб',
#   'системс',
#   'на',
#   'superjob'],
#  ['ассасинавт', 'скачать', 'торрент', 'в', 'хорошем', 'качестве'],
#  ['ведущий', 'специалист', 'по', 'закупкам'],
#  ['дима', 'билан', 'снимется', 'в', 'фильме', 'андрея', 'кончаловского'],
#  ['русская',
#   'наследница',
#   'сезон',
#   'смотреть',
#   'онлайн',
#   'в',
#   'хорошем',
#   'качестве',
#   'hd'],
#  ['купить',
#   'беговую',
#   'дорожку',
#   'в',
#   'квартиру',
#   'в',
#   'интернет',
#   'магазине',
#   'зона',
#   'спорта',
#   'интернет',
#   'м'],
#  ['профессия',
#   'стыковщик',
#   'текстиля',
#   'на',
#   'прессе',
#   'описание',
#   'суть',
#   'какая',
#   'зарплата'],
#  ['фото',
#   'пейзаж',
#   'пейзажные',
#   'фотографии',
#   'страница',
#   'социальная',
#   'сеть',
#   'фотокто'],
#  ['бишунму',
#   'танцующие',
#   'в',
#   'небесах',
#   'серия',
#   'сезон',
#   'смотреть',
#   'онлайн',
#   'dzen',
#   'kino'],
#  ['характеристика',
#   'различных',
#   'видов',
#   'перевозки',
#   'грузов',
#   'буквы',
#   'ру',
#   'научно',
#   'популярный',
#   'портал',
#   'script',
#   'async',
#   'custom',
#   'element',
#   'amp',
#   'auto',
#   'ads',
#   'src',
#   'https',
#   'cdn',
#   'ampproject',
#   'org',
#   'v',
#   'amp',
#   'auto',
#   'ads',
#   'js'],
#  ['кольцо',
#   'в',
#   'инкрустация',
#   'цирконием',
#   'р',
#   'р',
#   'р',
#   'позолота',
#   'xuping',
#   'продажа',
#   'цена',
#   'в',
#   'ровно',
#   'кольца',
#   'и',
#   'перстни',
#   'от',
#   'оптовый',
#   'интернет',
#   'магазин',
#   'позолоченной',
#   'бижутерии',
#   'xuping',
#   'rv',
#   'ua'],
#  ['в',
#   'судаке',
#   'затонул',
#   'прогулочный',
#   'катер',
#   'с',
#   'туристами',
#   'одна',
#   'пассажирка',
#   'погибла',
#   'яплакалъ'],
#  ['общие', 'положения', 'консультантплюс'],
#  ['фильм',
#   'смешная',
#   'девчонка',
#   'смотреть',
#   'онлайн',
#   'полностью',
#   'в',
#   'hd',
#   'качестве',
#   'бесплатно'],
#  ['начало', 'смотреть', 'онлайн', 'бесплатно', 'в', 'хорошем', 'качестве'],
#  ['фильм', 'артек', 'фото', 'видео', 'список', 'актеров', 'вокруг', 'тв'],
#  ['разбираем',
#   'принтер',
#   'l',
#   'l',
#   'xp',
#   'xp',
#   'замятие',
#   'бумаги',
#   'и',
#   'аналогичные',
#   'принтеры',
#   'смотреть',
#   'видео',
#   'онлайн',
#   'tubedoc',
#   'ru'],
#  ['воровайки', 'мурки', 'воровайки', 'клип', 'смотреть', 'онлайн'],
#  ['восход',
#   'и',
#   'заход',
#   'солнца',
#   'в',
#   'астане',
#   'тыс',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['блокування',
#   'мосту',
#   'метро',
#   'кличко',
#   'розпов',
#   'в',
#   'що',
#   'м',
#   'нувальник',
#   'мав',
#   'серйозн',
#   'нам',
#   'ри',
#   'та',
#   'перебував',
#   'у',
#   'стан',
#   'сп',
#   'ян',
#   'ння',
#   'новини',
#   'ки',
#   'ва',
#   'ки',
#   'в',
#   'tch',
#   'ua'],
#  ['книга',
#   'магия',
#   'поцелуев',
#   'мори',
#   'триш',
#   'литлайф',
#   'книги',
#   'читать',
#   'онлайн',
#   'скачать',
#   'бесплатно',
#   'полные',
#   'книги'],
#  ['читать',
#   'мангу',
#   'крутой',
#   'учитель',
#   'онидзука',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['читать',
#   'мангу',
#   'в',
#   'другом',
#   'мире',
#   'моё',
#   'имя',
#   'чёрный',
#   'целитель',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['кр',
#   'улуттук',
#   'банкынын',
#   'нарын',
#   'облустук',
#   'башкармалыгынын',
#   'филиалынын',
#   'улук',
#   'бухгалтери',
#   'а',
#   'токтакунова',
#   'кызматынан',
#   'негизсиз',
#   'четтетилген',
#   'кабар',
#   'кыргыз',
#   'улуттук',
#   'маалымат',
#   'агенттиги'],
#  ['candy', 'perfect', 'make', 'up', 'on', 'lylagames'],
#  ['изумрудные',
#   'сказки',
#   'эсми',
#   'никс',
#   'ямогу',
#   'каталог',
#   'мастеров',
#   'и',
#   'авторов',
#   'кукол',
#   'игрушек',
#   'кукольной',
#   'одежды',
#   'и',
#   'аксессуаров',
#   'бэйбики',
#   'куклы',
#   'фото',
#   'одежда',
#   'для',
#   'кук'],
#  ['рисовая', 'каша', 'на', 'воде', 'рецепт', 'с', 'фото'],
#  ['горная', 'болезнь'],
#  ['супервайзер',
#   'книга',
#   'супервайзера',
#   'как',
#   'увеличить',
#   'объем',
#   'продаж'],
#  ['solaray',
#   'cat',
#   's',
#   'claw',
#   'mg',
#   'vegcaps',
#   'iherb',
#   'com',
#   'checkoutarrow',
#   'checkoutarrow'],
#  ['mood', 'curl', 'wave', 'для', 'натуральных', 'волос', 'mood'],
#  ['как',
#   'вы',
#   'назовете',
#   'человека',
#   'думающего',
#   'о',
#   'других',
#   'больше',
#   'чем',
#   'о',
#   'себе'],
#  ['фильтр', 'страница'],
#  ['пол',
#   'полы',
#   'полов',
#   'закупки',
#   'на',
#   'этапе',
#   'подача',
#   'заявок',
#   'пермь',
#   'пермский',
#   'край',
#   'пермский',
#   'р',
#   'н'],
#  ['zq', 'м', 'ф', 'ромео', 'с', 'обочины', 'индия', 'mp'],
#  ['росфинмониторинг', 'почта', 'mail', 'ru'],
#  ['порошенко',
#   'п',
#   'дписав',
#   'антирейдерський',
#   'земельний',
#   'закон',
#   'укра',
#   'нська',
#   'правда'],
#  ['морковные', 'палочки'],
#  ['государственный', 'музей', 'л', 'н', 'толстого', 'гмт', 'элкос', 'дизайн'],
#  ['рамблер', 'касса'],
#  ['шикарная',
#   'молодая',
#   'женщина',
#   'с',
#   'обнаженными',
#   'сосками',
#   'эротика',
#   'фото',
#   'и',
#   'голые',
#   'целующиеся',
#   'девушки',
#   'раздетые',
#   'женщины'],
#  ['фото', 'со', 'мной', 'фото', 'фотографии', 'олеся', 'швецова'],
#  ['строительство', 'коттеджей', 'из', 'пенобетона', 'под', 'ключ', 'омскдом'],
#  ['военная',
#   'тематика',
#   'страница',
#   'скачать',
#   'книги',
#   'в',
#   'форматах',
#   'txt',
#   'fb',
#   'pdf',
#   'бесплатн'],
#  ['магазин',
#   'электронных',
#   'компонентов',
#   'электронщик',
#   'продажа',
#   'электронных',
#   'компонентов',
#   'радиодеталей',
#   'измерительной',
#   'техники',
#   'светотехнических',
#   'и'],
#  ['сушка', 'дерева', 'в', 'вакуумной', 'камере', 'guns', 'ru', 'talks'],
#  ['picanto',
#   'срок',
#   'поставки',
#   'киа',
#   'пиканто',
#   'субкомпактный',
#   'автомобиль'],
#  ['почтовый',
#   'индекс',
#   'улицы',
#   'льва',
#   'толстого',
#   'санкт',
#   'петербурга',
#   'с',
#   'номерами',
#   'домов',
#   'indexmap',
#   'ru'],
#  ['комплект',
#   'муравьиной',
#   'фермы',
#   'smart',
#   'горный',
#   'мох',
#   'купить',
#   'в',
#   'белгороде',
#   'в',
#   'интернет',
#   'магазине',
#   'antfarms',
#   'ru'],
#  ['tinko', 'h'],
#  ['презентац', 'я', 'сутн', 'сть', 'маркетингу', 'та', 'його', 'визначення'],
#  ['марсель',
#   'муратов',
#   'казань',
#   'татарстан',
#   'россия',
#   'года',
#   'на',
#   'мой',
#   'мир',
#   'mail',
#   'ru'],
#  ['charlie', 'red', 'anal', 'daftsex'],
#  ['администрация', 'дк'],
#  ['город', 'холм'],
#  ['в',
#   'челябинской',
#   'области',
#   'появится',
#   'еще',
#   'три',
#   'виртуальных',
#   'концертных',
#   'зала'],
#  ['анжелика',
#   'агурбаш',
#   'мне',
#   'любви',
#   'твоей',
#   'мало',
#   'музыка',
#   'в',
#   'mp',
#   'скачать',
#   'бесплатно',
#   'слушать',
#   'музыку',
#   'анжелика',
#   'агурбаш',
#   'мне',
#   'любви',
#   'твоей',
#   'мало',
#   'песен',
#   'песни',
#   'онлайн',
#   'на'],
#  ['необычные', 'рецепты', 'вкусные', 'идеи', 'каждый', 'день'],
#  ['девчат',
#   'с',
#   'радостью',
#   'бы',
#   'пописали',
#   'в',
#   'таких',
#   'туалетах',
#   'сообщение',
#   'москва'],
#  ['гостиница',
#   'авс',
#   'отель',
#   'россия',
#   'свердловская',
#   'область',
#   'екатеринбург',
#   'цены'],
#  ['купить',
#   'кронштейн',
#   'для',
#   'тв',
#   'наклонно',
#   'поворотный',
#   'vogel',
#   's',
#   'thin',
#   'black',
#   'в',
#   'каталоге',
#   'интернет',
#   'магазина',
#   'м',
#   'видео',
#   'по',
#   'выгодной',
#   'цене',
#   'с',
#   'доставкой',
#   'отзывы',
#   'фотогра'],
#  ['flora', 'by', 'gucci', 'ml', 'al', 'rayan'],
#  ['технические',
#   'и',
#   'функциональные',
#   'возможности',
#   'интерактивной',
#   'доски',
#   'тема',
#   'научной',
#   'статьи',
#   'по',
#   'общим',
#   'и',
#   'комплексным',
#   'проблемам',
#   'естественных',
#   'и',
#   'точн'],
#  ['секс',
#   'знакомства',
#   'обмен',
#   'интим',
#   'фото',
#   'без',
#   'регистрации',
#   'бесплатно',
#   'без',
#   'смс'],
#  ['jebug', 'obok', 'obok', 'susu', 'смотреть', 'онлайн'],
#  ['подскажите',
#   'как',
#   'ваши',
#   'дети',
#   'написали',
#   'централизованную',
#   'работу',
#   'по',
#   'геометрии',
#   'которая',
#   'была',
#   'наш',
#   'класс',
#   'походу',
#   'не',
#   'очень'],
#  ['teenfidelity',
#   'com',
#   'tf',
#   's',
#   'real',
#   'life',
#   'ryan',
#   'madison',
#   'jennifer',
#   'bliss',
#   'small',
#   'tits',
#   'porntube'],
#  ['millie',
#   'азарова',
#   'английский',
#   'язык',
#   'для',
#   'младшей',
#   'школы',
#   'скачать',
#   'беслатно',
#   'учебники',
#   'тетради',
#   'аудио',
#   'карточки',
#   'для',
#   'всех',
#   'классов',
#   'pdf'],
#  ['у',
#   'ребенка',
#   'красные',
#   'глаза',
#   'и',
#   'гноятся',
#   'у',
#   'ребенка',
#   'красные',
#   'глаза',
#   'и',
#   'гной'],
#  ['на',
#   'урале',
#   'играют',
#   'в',
#   'кёрлинг',
#   'автомобилями',
#   'ока',
#   'смотреть',
#   'видео',
#   'онлайн',
#   'в',
#   'моем',
#   'мире',
#   'олег',
#   'фролов'],
#  ['читать', 'книгу', 'оригинал', 'си', 'страница', 'библиотека', 'книг'],
#  ['игры',
#   'на',
#   'ps',
#   'скачать',
#   'торрент',
#   'бесплатно',
#   'и',
#   'без',
#   'регистрации'],
#  ['бархатцы', 'махровые', 'гиганты', 'гр', 'цп', 'семена', 'алтая'],
#  ['arilara',
#   'soyle',
#   'trsub',
#   'filmizlevip',
#   'смотреть',
#   'видео',
#   'онлайн',
#   'в',
#   'моем',
#   'мире',
#   'ahmet',
#   'bulut'],
#  ['собаки',
#   'в',
#   'поездах',
#   'укрзализныця',
#   'объяснила',
#   'правила',
#   'перевозки',
#   'животных',
#   'сегодня'],
#  ['фильмы', 'жанра', 'комедия', 'смотреть', 'онлайн', 'бесплатно'],
#  ['моя', 'реклама'],
#  ['ленинский',
#   'район',
#   'сентября',
#   'состоится',
#   'очередное',
#   'заседание',
#   'комиссии',
#   'по',
#   'профилактике',
#   'правонарушений'],
#  ['побег',
#   'из',
#   'лос',
#   'анджелеса',
#   'слушать',
#   'и',
#   'скачать',
#   'на',
#   'mixmuz'],
#  ['таинственный', 'лес', 'тайна', 'покрытая', 'мраком', 'отзывы'],
#  ['танцевальный', 'клуб', 'импульс', 'в', 'белгороде', 'для', 'детей', 'лет'],
#  ['скачать',
#   'клуб',
#   'винкс',
#   'сезон',
#   'серия',
#   'обратно',
#   'в',
#   'средние',
#   'века',
#   'русский',
#   'никелодеон',
#   'hd',
#   'смотреть',
#   'онлайн'],
#  ['мой', 'мир', 'mail', 'ru'],
#  ['против', 'язвы', 'iherb', 'com'],
#  ['большой',
#   'шар',
#   'с',
#   'куклами',
#   'lol',
#   'купить',
#   'в',
#   'краснодаре',
#   'цена',
#   'руб',
#   'дата',
#   'размещения',
#   'игрушки',
#   'и',
#   'игры'],
#  ['answear',
#   'ua',
#   'интернет',
#   'магазин',
#   'женской',
#   'мужской',
#   'и',
#   'детской',
#   'одежды',
#   'обуви',
#   'и',
#   'аксессуаров',
#   'онлайн',
#   'доставка',
#   'за',
#   'дня',
#   'бесплатная',
#   'отправка',
#   'заказа',
#   'от'],
#  ['соликамск',
#   'база',
#   'данных',
#   'недвижимости',
#   'соликамска',
#   'сайт',
#   'объявлений',
#   'о',
#   'продаже',
#   'и',
#   'аренде',
#   'объявления'],
#  ['big',
#   'titted',
#   'milf',
#   'with',
#   'glasses',
#   'is',
#   'rubbing',
#   'her',
#   'lover',
#   's',
#   'dick',
#   'in',
#   'front',
#   'of',
#   'a',
#   'hidden',
#   'camera',
#   'perfect',
#   'girls'],
#  ['водителя',
#   'элитного',
#   'мерседеса',
#   'убийцы',
#   'который',
#   'насмерть',
#   'сбил',
#   'парня',
#   'на',
#   'бауманской',
#   'экстрадировали',
#   'из',
#   'мюнхена',
#   'в',
#   'москву'],
#  ['тайная',
#   'война',
#   'воздушного',
#   'штрафбата',
#   'война',
#   'художественная',
#   'литература',
#   'читать',
#   'онлайн',
#   'booksbunker'],
#  ['отправление', 'ответа', 'на', 'объявление', 'огосекс', 'ру'],
#  ['результаты',
#   'поиска',
#   'по',
#   'запросу',
#   'секреты',
#   'пластилина',
#   'интернет',
#   'магазин',
#   'читай',
#   'город'],
#  ['читать', 'мангу', 'скала', 'кен', 'глава', 'на', 'русском', 'онлайн'],
#  ['крыло',
#   'toyota',
#   'caldina',
#   'правое',
#   'переднее',
#   'st',
#   'автозапчасти',
#   'в',
#   'горно',
#   'алтайске'],
#  ['акция',
#   'myllyn',
#   'paras',
#   'в',
#   'пятерочке',
#   'на',
#   'завтрак',
#   'каша',
#   'и',
#   'машина',
#   'ваша'],
#  ['колледжи',
#   'красноярска',
#   'со',
#   'специальностью',
#   'преподавание',
#   'в',
#   'начальных',
#   'классах'],
#  ['натали', 'natali', 'инстаграм', 'фотографии'],
#  ['кожаная',
#   'сумка',
#   'delgamo',
#   'купить',
#   'от',
#   'интернет',
#   'магазина',
#   'домани'],
#  ['фильтр', 'поиска'],
#  ['купить',
#   'кабель',
#   'aux',
#   'jack',
#   'rock',
#   'multifunctional',
#   'audio',
#   'cable',
#   'с',
#   'пультом',
#   'и',
#   'микрофоном',
#   'по',
#   'цене',
#   'руб'],
#  ['event', 'show', 'full', 'immersion', 'читайте', 'на', 'cossa', 'ru'],
#  ['cherie',
#   'deville',
#   'порно',
#   'видео',
#   'скачать',
#   'и',
#   'смотреть',
#   'фильмы',
#   'с',
#   'cherie',
#   'deville',
#   'в',
#   'hd'],
#  ['kayla', 'kayden', 'anal', 'daftsex'],
#  ['у',
#   'меня',
#   'на',
#   'great',
#   'wall',
#   'sailor',
#   'постоянно',
#   'горит',
#   'h',
#   'l',
#   'и',
#   'rew',
#   'lock',
#   'ответов',
#   'ремонт',
#   'и',
#   'эксплуатация',
#   'форум',
#   'авто',
#   'mail',
#   'ru'],
#  ['передняя', 'энциклопедия', 'pickupclub', 'ru'],
#  ['песни',
#   'say',
#   'mo',
#   'и',
#   'slame',
#   'номад',
#   'сезон',
#   'выпуск',
#   'фрагмент',
#   'из',
#   'песни',
#   'смотреть',
#   'онлайн',
#   'видео',
#   'бесплатно',
#   'видеохостинг',
#   'rutube'],
#  ['взрыв',
#   'на',
#   'заводе',
#   'поставщика',
#   'тойоты',
#   'не',
#   'скажется',
#   'на',
#   'производстве',
#   'компании',
#   'в',
#   'россии'],
#  ['лучшие',
#   'цены',
#   'для',
#   'ford',
#   'деталь',
#   'лучшие',
#   'цены',
#   'поставщиков',
#   'для',
#   'деталь',
#   'ford',
#   'burjauto'],
#  ['search', 'videos', 'for', 'threesome', 'docot', 'movies', 'page'],
#  ['inputbox',
#   'оператор',
#   'vba',
#   'для',
#   'получения',
#   'входных',
#   'данных',
#   'от',
#   'пользователя',
#   'процедуры'],
#  ['студент',
#   'який',
#   'кинув',
#   'яйце',
#   'в',
#   'януковича',
#   'у',
#   'роц',
#   'дор',
#   'с',
#   'до',
#   'директора',
#   'департаменту',
#   'ода',
#   'портал',
#   'новин',
#   'lb',
#   'ua'],
#  ['бережинський',
#   'ззсо',
#   'ступен',
#   'в',
#   'к',
#   'ровоградська',
#   'область',
#   'суо'],
#  ['луга', 'фреш', 'синюга', 'poly', 'pack'],
#  ['whaff',
#   'locker',
#   'скачать',
#   'на',
#   'андроид',
#   'и',
#   'ios',
#   'отзывы',
#   'и',
#   'промокод',
#   'деньги',
#   'на',
#   'телефон',
#   'рф'],
#  ['специальности',
#   'сибгу',
#   'им',
#   'м',
#   'ф',
#   'решетнева',
#   'направления',
#   'образования',
#   'бакалавриата',
#   'языкознание',
#   'и',
#   'литературоведение',
#   'в',
#   'красноярске'],
#  ['атлантис',
#   'тв',
#   'кабельное',
#   'телевидение',
#   'гай',
#   'адрес',
#   'описание',
#   'отзывы'],
#  ['гдз',
#   'номер',
#   'математика',
#   'класс',
#   'рабочая',
#   'тетрадь',
#   'а',
#   'г',
#   'мерзляк',
#   'в',
#   'б',
#   'полонский'],
#  ['результаты', 'поиска', 'по', 'запросу', 'гарри', 'потер'],
#  ['девочки', 'самое', 'интересное', 'фото', 'дом', 'солнца'],
#  ['портфель', 'blackterminal'],
#  ['whatsapp',
#   'messenger',
#   'pour',
#   'htc',
#   'wildfire',
#   's',
#   'tйlйchargement',
#   'gratuit',
#   'programmes',
#   'pour'],
#  ['image', 'hosting', 'script'],
#  ['hot', 'beauty', 'undressing', 'gallery'],
#  ['смотрите', 'видео', 'онлайн', 'бесплатно'],
#  ['porn',
#   'albums',
#   'with',
#   'alex',
#   'coal',
#   'jay',
#   's',
#   'pov',
#   'hd',
#   'porn',
#   'videos',
#   'sex',
#   'movies',
#   'porn',
#   'tube'],
#  ['общественные',
#   'и',
#   'политические',
#   'организации',
#   'в',
#   'пензе',
#   'на',
#   'ул',
#   'титова',
#   'организации'],
#  ['горячие', 'закуски', 'банкетный', 'зал', 'шартрез'],
#  ['офис',
#   'the',
#   'office',
#   'сезон',
#   'серия',
#   'смотреть',
#   'онлайн',
#   'в',
#   'высоком',
#   'качестве',
#   'pilot'],
#  ['танк',
#   'армата',
#   'и',
#   'с',
#   'никогда',
#   'не',
#   'поступят',
#   'в',
#   'армию',
#   'экспресс',
#   'газета'],
#  ['сырный', 'дом', 'все', 'о', 'домашнем', 'сыроделии'],
#  ['sodomie',
#   'a',
#   'repetition',
#   'xvideos',
#   'videoclipuri',
#   'porno',
#   'gratuite',
#   'xhamster',
#   'animal'],
#  ['читать',
#   'книгу',
#   'спящая',
#   'красавица',
#   'лп',
#   'страница',
#   'библиотека',
#   'книг'],
#  ['после', 'ролевых', 'игр', 'жестко', 'ебёт', 'в', 'д', 'жену'],
#  ['отзыв',
#   'о',
#   'работе',
#   'в',
#   'сеть',
#   'кафе',
#   'столовых',
#   'подсолнухи',
#   'город',
#   'новосибирск',
#   'черный',
#   'сп'],
#  ['девичья', 'стройность', 'почему', 'француженки', 'не', 'толстеют'],
#  ['сопр', 'вариант', 'дз', 'часть', 'студизба'],
#  ['класс', 'тест', 'доказательства', 'эволюции'],
#  ['об',
#   'утверждении',
#   'перечня',
#   'государственных',
#   'работ',
#   'выполняемых',
#   'государственными',
#   'учреждениями',
#   'владимирской',
#   'области',
#   'в',
#   'отношении',
#   'которых',
#   'государственная',
#   'инспекция',
#   'по',
#   'охране',
#   'и',
#   'использованию',
#   'животного',
#   'мира',
#   'администрации',
#   'области',
#   'осуществляет',
#   'функции',
#   'и',
#   'полномочия'],
#  ['задание',
#   'решение',
#   'русский',
#   'язык',
#   'класс',
#   'ладыженская',
#   'onlinegdz'],
#  ['эбби',
#   'глайнс',
#   'не',
#   'для',
#   'тебя',
#   'читать',
#   'книгу',
#   'онлайн',
#   'бесплатно'],
#  ['услуги',
#   'трубочиста',
#   'в',
#   'спб',
#   'прочистка',
#   'дымоходов',
#   'и',
#   'вентканалов'],
#  ['слив',
#   'обучения',
#   'plastik',
#   'за',
#   'k',
#   'форум',
#   'социальной',
#   'инженерии',
#   'lolzteam',
#   'net'],
#  ['поездка', 'с', 'попутчиками', 'и', 'данные', 'водителя', 'blablacar'],
#  ['газэнергоавтоматика'],
#  ['идей', 'для', 'создания', 'новогоднего', 'уюта', 'в', 'доме'],
#  ['великая',
#   'северная',
#   'война',
#   'программа',
#   'виват',
#   'история',
#   'виват',
#   'история',
#   'подкаст',
#   'на'],
#  ['м',
#   'и',
#   'цветаева',
#   'никто',
#   'ничего',
#   'не',
#   'отнял',
#   'текст',
#   'произведения'],
#  ['morning',
#   'sex',
#   'two',
#   'chicks',
#   'and',
#   'a',
#   'hot',
#   'male',
#   'porn',
#   'video'],
#  ['casey',
#   'calvert',
#   'порно',
#   'porno',
#   'русский',
#   'секс',
#   'домашнее',
#   'гей',
#   'видео',
#   'biqle',
#   'видео'],
#  ['закупки',
#   'моуо',
#   'отдел',
#   'образования',
#   'администрации',
#   'куртамышского',
#   'района'],
#  ['корова',
#   'из',
#   'цветов',
#   'обсуждение',
#   'на',
#   'liveinternet',
#   'российский',
#   'сервис',
#   'онлайн',
#   'дневник'],
#  ['sinoptik',
#   'погода',
#   'в',
#   'тужаре',
#   'прогноз',
#   'погоды',
#   'тужар',
#   'в',
#   'черниговской',
#   'области',
#   'козелецком',
#   'районе',
#   'на',
#   'неделю',
#   'украина'],
#  ['альбом',
#   'это',
#   'я',
#   'екатерина',
#   'года',
#   'россия',
#   'екатеринбург',
#   'сеть',
#   'знакомств',
#   'мамба'],
#  ['ремкомплект',
#   'суппорта',
#   'skoda',
#   'octavia',
#   'шкода',
#   'октавия',
#   'комплект',
#   'направляющей',
#   'гильзы',
#   'st',
#   'st',
#   'купить',
#   'в',
#   'киеве',
#   'цена',
#   'в',
#   'киеве',
#   'автозапчасти',
#   'абсолют',
#   'авто',
#   'абсолютное',
#   'качество',
#   'absolutavto',
#   'com',
#   'ua'],
#  ['зозуля', 'дитяч', 'п', 'сн', 'укра', 'нськ', 'дитяч', 'п', 'сн'],
#  ['результаты', 'поиска', 'по', 'запросу', 'железная', 'хватка'],
#  ['скачать',
#   'порно',
#   'на',
#   'телефон',
#   'дама',
#   'на',
#   'цепи',
#   'была',
#   'трахнута',
#   'ебальной',
#   'машиной',
#   'своего',
#   'друга',
#   'в',
#   'gp',
#   'и',
#   'mp'],
#  ['капернаум', 'фильм', 'онлайн', 'бесплатно', 'кинохолд'],
#  ['туника',
#   'c',
#   'в',
#   'г',
#   'душанбе',
#   'блузки',
#   'somon',
#   'tj',
#   'бесплатные',
#   'объявления',
#   'куплю',
#   'продам',
#   'б',
#   'у'],
#  ['необходима', 'проверка', 'безопасности'],
#  ['фотографии', 'бр', 'фото', 'в', 'моем', 'мире'],
#  ['готовый',
#   'перевод',
#   'i',
#   'm',
#   'really',
#   'a',
#   'superstar',
#   'я',
#   'стану',
#   'суперзвездой',
#   'глава',
#   'tl',
#   'rulate',
#   'ru'],
#  ['powered', 'by', 'line'],
#  ['куртка',
#   'утепленная',
#   'baon',
#   'купить',
#   'за',
#   'руб',
#   'ba',
#   'ewfzew',
#   'в',
#   'интернет',
#   'магазине',
#   'lamoda',
#   'ru'],
#  ['два',
#   'овертайма',
#   'и',
#   'новый',
#   'подвиг',
#   'летнего',
#   'сколы',
#   'как',
#   'сборные',
#   'испании',
#   'и',
#   'аргентины',
#   'вышли',
#   'в',
#   'финал',
#   'км',
#   'по',
#   'баскетболу',
#   'рт',
#   'на',
#   'русском'],
#  ['училка', 'в', 'стрингах', 'молодая', 'порно', 'фото'],
#  ['технология', 'производства', 'жби', 'колец', 'бетон', 'центр'],
#  ['aptekirls',
#   'ru',
#   'артрозилен',
#   'гель',
#   'г',
#   'заказать',
#   'онлайн',
#   'и',
#   'купить',
#   'в',
#   'ближайшей',
#   'аптеке',
#   'по',
#   'выгодным',
#   'ценам'],
#  ['секс',
#   'бесплатно',
#   'wicked',
#   'guy',
#   'gets',
#   'undressed',
#   'to',
#   'fuck',
#   'sexy',
#   'nice',
#   'looking',
#   'girl',
#   'бесплатное',
#   'секс',
#   'видео',
#   'онлайн',
#   'каждый',
#   'день'],
#  ['new',
#   'life',
#   'скачать',
#   'онлайн',
#   'игру',
#   'обзор',
#   'официальный',
#   'сайт',
#   'и',
#   'видео',
#   'new',
#   'life'],
#  ['плакат', 'кипелов', 'в', 'дар', 'москва', 'дарудар'],
#  ['файтеры', 'lurkmore'],
#  ['дом',
#   'интерьеры',
#   'красивых',
#   'домов',
#   'и',
#   'квартир',
#   'со',
#   'всего',
#   'мира',
#   'пуфик',
#   'блог',
#   'о',
#   'дизайне',
#   'интерьера'],
#  ['lemon', 'delfi', 'тыс', 'результатов', 'поиск', 'mail', 'ru'],
#  ['фотографии', 'юлиана', 'тугалова', 'фото', 'в', 'моем', 'мире'],
#  ['гранитная',
#   'мойка',
#   'для',
#   'кухни',
#   'u',
#   'цвет',
#   'песочный',
#   'сантехника',
#   'и',
#   'водоснабжение',
#   'во',
#   'в'],
#  ['защита',
#   'от',
#   'обратной',
#   'тяги',
#   'мм',
#   'era',
#   'ок',
#   'в',
#   'санкт',
#   'петербурге',
#   'купить',
#   'по',
#   'низкой',
#   'цене',
#   'отзывы',
#   'характеристики',
#   'фото',
#   'инструкция'],
#  ['два',
#   'аборигена',
#   'отдерут',
#   'шикарную',
#   'девицу',
#   'в',
#   'половую',
#   'оральную',
#   'и',
#   'анальную',
#   'щель',
#   'отборное',
#   'порно',
#   'на',
#   'ебухе'],
#  ['eaec',
#   'e',
#   'a',
#   'e',
#   'b',
#   'e',
#   'c',
#   'fae',
#   'скачать',
#   'бесплатно',
#   'электронная',
#   'библиотека',
#   'поиск',
#   'книг',
#   'bookfi'],
#  ['читать',
#   'мангу',
#   'месть',
#   'масамуне',
#   'куна',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['cosplay', 'caveira'],
#  ['немного',
#   'из',
#   'обычаев',
#   'и',
#   'нравов',
#   'рая',
#   'под',
#   'названием',
#   'доминикана',
#   'страна',
#   'мам'],
#  ['сергей',
#   'жорин',
#   'александр',
#   'толмацкий',
#   'не',
#   'собирается',
#   'забирать',
#   'ребенка',
#   'у',
#   'вдовы',
#   'децла'],
#  ['соединение',
#   'труб',
#   'корсис',
#   'с',
#   'трубами',
#   'других',
#   'систем',
#   'и',
#   'установка',
#   'колодцев'],
#  ['взять', 'заказ', 'taxi', 'money'],
#  ['ежедневно',
#   'кыргызстанцев',
#   'умирают',
#   'от',
#   'болезней',
#   'сердца',
#   'эксперт'],
#  ['wings', 'palette', 'lockheed', 'p', 'lightning', 'france'],
#  ['де',
#   'ла',
#   'круз',
#   'мелисса',
#   'маскарад',
#   'страница',
#   'читать',
#   'онлайн',
#   'rbook'],
#  ['поиск', 'скраб', 'для', 'тела', 'yves', 'rocher'],
#  ['розбираю',
#   'в',
#   'то',
#   'грн',
#   'транспорт',
#   'на',
#   'запчасти',
#   'рава',
#   'русская',
#   'на',
#   'olx'],
#  ['прокат',
#   'квадроциклов',
#   'как',
#   'бизнес',
#   'в',
#   'с',
#   'чего',
#   'начать',
#   'и',
#   'сколько',
#   'можно',
#   'заработать'],
#  ['search', 'videos', 'for', 'mom', 'porn', 'com', 'page'],
#  ['гдз',
#   'по',
#   'английскому',
#   'языку',
#   'для',
#   'класса',
#   'баранова',
#   'к',
#   'м',
#   'страница'],
#  ['мод', 'war', 'on', 'terror', 'pack', 'для', 'ravenfield'],
#  ['кыргызча', 'жаны', 'ырлар', 'скачать', 'бесплатно', 'текст'],
#  ['нумерология', 'data', 'rozhdenya'],
#  ['вредность',
#   'вредничество',
#   'непокорность',
#   'язвительство',
#   'новое',
#   'естественное',
#   'лечение'],
#  ['свадебные',
#   'и',
#   'вечерние',
#   'платья',
#   'в',
#   'новочеркасске',
#   'салон',
#   'скарлетт',
#   'новочеркасск',
#   'net'],
#  ['zuspitze',
#   'xvideos',
#   'bedava',
#   'porno',
#   'videolar',
#   'tan',
#   've',
#   'serseri',
#   'k',
#   'zlar',
#   'becer'],
#  ['светодинамический',
#   'фонтан',
#   'средний',
#   'нижний',
#   'царицынский',
#   'пруд',
#   'бирюлево',
#   'восточное'],
#  ['кент',
#   'а',
#   'кил',
#   'психопаты',
#   'достоверный',
#   'рассказ',
#   'о',
#   'людях',
#   'без',
#   'жалости',
#   'без',
#   'совести',
#   'без',
#   'раскаяния',
#   'читать',
#   'онлайн',
#   'полностью',
#   'литрес'],
#  ['маруся',
#   'если',
#   'человек',
#   'боится',
#   'показать',
#   'как',
#   'ты',
#   'ему',
#   'нужен',
#   'отпусти',
#   'его',
#   'пусть',
#   'боится',
#   'дальше'],
#  ['свитер', 'мэйбл', 'со', 'звездой', 'вязание', 'страна', 'мам'],
#  ['к', 'за', 'снеговика'],
#  ['птуп',
#   'мартин',
#   'бел',
#   'предлагает',
#   'грузы',
#   'для',
#   'перевозки',
#   'по',
#   'беларуси',
#   'sit',
#   'trans'],
#  ['new', 'videos', 'free', 'porn', 'sex', 'xxx', 'movies', 'page'],
#  ['бассейн',
#   'каркасный',
#   'прямоугольный',
#   'bestway',
#   'x',
#   'x',
#   'см',
#   'цена',
#   'грн',
#   'купить',
#   'в',
#   'киеве',
#   'prom',
#   'ua',
#   'id'],
#  ['buttonbar',
#   'скомпилированные',
#   'скрипты',
#   'autoit',
#   'каталог',
#   'файлов',
#   'cайт',
#   'azjio'],
#  ['женатый',
#   'парень',
#   'отжарил',
#   'молодую',
#   'соседку',
#   'втихаря',
#   'от',
#   'своей',
#   'жены'],
#  ['экологические',
#   'пирамиды',
#   'биомассы',
#   'и',
#   'численности',
#   'bio',
#   'learn',
#   'com'],
#  ['скачать',
#   'файл',
#   'alper',
#   'e',
#   'ri',
#   'bom',
#   'bom',
#   'mp',
#   'на',
#   'oxy',
#   'cloud'],
#  ['вакансии',
#   'и',
#   'работа',
#   'нормировщик',
#   'участка',
#   'в',
#   'твери',
#   'поиск',
#   'работы',
#   'с',
#   'городработ',
#   'ру'],
#  ['hussy',
#   'slut',
#   'mckenzee',
#   'miles',
#   'gets',
#   'her',
#   'asshole',
#   'stretched',
#   'hard',
#   'streaming',
#   'porn'],
#  [],
#  ['повышенное',
#   'выделение',
#   'слизи',
#   'у',
#   'женщин',
#   'виды',
#   'прозрачных',
#   'выделений',
#   'при',
#   'заболеваниях'],
#  ['танки',
#   'всё',
#   'о',
#   'фильме',
#   'отзывы',
#   'рецензии',
#   'смотреть',
#   'видео',
#   'онлайн',
#   'на',
#   'film',
#   'ru'],
#  ['автобусные', 'туры', 'в', 'бельгию', 'из', 'минска', 'цены'],
#  ['курица',
#   'с',
#   'кабачками',
#   'по',
#   'китайски',
#   'рецепт',
#   'с',
#   'пошаговыми',
#   'фотографиями'],
#  ['хореография', 'для', 'детей', 'направления', 'центра', 'знаток'],
#  ['photo', 'oiled', 'big', 'tits', 'boobs', 'topless', 'wallpaper'],
#  ['разрушители', 'легенд', 'mythbusters', 'сша', 'сериалы', 'вебург'],
#  ['мамка',
#   'в',
#   'белом',
#   'нижнем',
#   'белье',
#   'удовлетворяет',
#   'бородатого',
#   'парня',
#   'в',
#   'спальне'],
#  ['нож', 'бабочка', 'на', 'd', 'принтере'],
#  ['автоматические', 'установки', 'пожарной', 'сигнализации'],
#  ['николай', 'запорожье', 'лет', 'фото', 'и', 'страница'],
#  ['большой', 'козловский', 'переулок', 'д', 'на', 'карте', 'москвы'],
#  ['немолодая',
#   'женщина',
#   'показала',
#   'волосатую',
#   'вагину',
#   'порно',
#   'и',
#   'секс',
#   'фото',
#   'с',
#   'зрелыми',
#   'дамочками'],
#  ['русское',
#   'порно',
#   'смотреть',
#   'российскую',
#   'порнуху',
#   'бесплатно',
#   'онлайн',
#   'страница'],
#  ['порно',
#   'видео',
#   'с',
#   'каролина',
#   'свитс',
#   'carolina',
#   'sweets',
#   'jumpboobs',
#   'info'],
#  ['рассрочка', 'на', 'трансплантацию', 'волос'],
#  ['codycross', 'a', 'alogia', 'й', 'a', 'ausкncia', 'dela', 'respostas'],
#  ['наташа',
#   'мищенко',
#   'natashazabava',
#   'свадебный',
#   'фотограф',
#   'ставрополь',
#   'россия'],
#  ['в',
#   'россии',
#   'ужесточили',
#   'контроль',
#   'за',
#   'перевод',
#   'с',
#   'карты',
#   'на',
#   'карту'],
#  ['читать', 'мангу', 'опасная', 'любовь', 'глава', 'на', 'русском', 'онлайн'],
#  ['людмила',
#   'баснак',
#   'алма',
#   'ата',
#   'казахстан',
#   'на',
#   'мой',
#   'мир',
#   'mail',
#   'ru'],
#  ['twitter'],
#  ['кран',
#   'для',
#   'кулера',
#   'в',
#   'укра',
#   'н',
#   'пор',
#   'вняти',
#   'ц',
#   'ни',
#   'придбати',
#   'споживч',
#   'товари',
#   'на',
#   'маркетплейс',
#   'prom',
#   'ua'],
#  ['альбомы',
#   'по',
#   'развитию',
#   'речи',
#   'запись',
#   'пользователя',
#   'василиса',
#   'vasilisaart',
#   'в',
#   'сообществе',
#   'детские',
#   'книги',
#   'в',
#   'категории',
#   'для',
#   'самых',
#   'маленьких',
#   'babyblog',
#   'ru'],
#  ['макс', 'барских', 'займёмся', 'любовью', 'слушать', 'бесплатно', 'онлайн'],
#  ['не', 'могу', 'бегать', 'из', 'за', 'одышки', 'рассказываем', 'как', 'быть'],
#  ['просклонять', 'слово', 'кроватка', 'по', 'падежам', 'безбукв', 'ру'],
#  ['фотографии', 'анастасия', 'соломонова', 'фото', 'в', 'моем', 'мире'],
#  ['анданте',
#   'сезон',
#   'торрент',
#   'сериал',
#   'скачать',
#   'бесплатно',
#   'или',
#   'смотреть',
#   'онлайн'],
#  ['технология', 'покраски', 'бетона'],
#  ['ставка',
#   'рефинансирования',
#   'ключевая',
#   'ставка',
#   'цб',
#   'рф',
#   'на',
#   'год',
#   'таблица'],
#  ['читать',
#   'мангу',
#   'восьмой',
#   'сын',
#   'я',
#   'не',
#   'могу',
#   'этого',
#   'принять',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['new', 'lisa', 'ann', 'daftsex'],
#  ['фильм',
#   'операция',
#   'тушенка',
#   'смотреть',
#   'онлайн',
#   'бесплатно',
#   'в',
#   'хорошем',
#   'качестве',
#   'p',
#   'hd'],
#  ['купить',
#   'туалетная',
#   'кабина',
#   'х',
#   'х',
#   'м',
#   'в',
#   'невинномысске',
#   'в',
#   'невинномысске',
#   'от',
#   'производителя'],
#  ['купить',
#   'тонометр',
#   'механический',
#   'иад',
#   'со',
#   'стетоскопом',
#   'комплект',
#   'в',
#   'аптеках',
#   'московского',
#   'региона',
#   'с',
#   'доставкой',
#   'сравнение',
#   'цен',
#   'аптекамос'],
#  ['play',
#   'subway',
#   'surfers',
#   'world',
#   'tour',
#   'mexico',
#   'city',
#   'on',
#   'najox',
#   'com'],
#  ['обои', 'природа', 'обои', 'для', 'рабочего', 'стола', 'фото'],
#  ['трансформатор', 'грн', 'прочая', 'электроника', 'запорожье', 'на', 'olx'],
#  ['худи',
#   'спортивное',
#   'худи',
#   'с',
#   'капюшоном',
#   'и',
#   'большим',
#   'наклданым',
#   'карманом',
#   'кенгуру',
#   'ткань',
#   'одежда',
#   'для',
#   'женщин'],
#  ['дорама',
#   'цветочки',
#   'после',
#   'ягодок',
#   'смотреть',
#   'онлайн',
#   'русская',
#   'озвучка',
#   'результата',
#   'поиск',
#   'mail',
#   'ru'],
#  ['icon',
#   'pedro',
#   'capo',
#   'feat',
#   'reykon',
#   'como',
#   'lo',
#   'hiciste',
#   'ayer',
#   'скачать',
#   'бесплатно',
#   'песню',
#   'в',
#   'mp'],
#  ['рожанец',
#   'александр',
#   'робертович',
#   'физиотерапевт',
#   'отзывы',
#   'запись',
#   'на',
#   'прием',
#   'docdoc',
#   'ru'],
#  ['shemale', 'cam', 'show', 'videos', 'with', 'amateur', 'models', 'strictly'],
#  ['фото', 'топ', 'р', 'новая', 'цена', 'р'],
#  ['такой',
#   'разный',
#   'магний',
#   'стр',
#   'запись',
#   'пользователя',
#   'марина',
#   'id',
#   'в',
#   'сообществе',
#   'благополучная',
#   'беременность',
#   'в',
#   'категории',
#   'медикаменты',
#   'витамины',
#   'процедуры',
#   'babyblog',
#   'ru'],
#  ['черемухово', 'сайт', 'города', 'североуральска'],
#  ['презентация',
#   'на',
#   'тему',
#   'построение',
#   'курса',
#   'математики',
#   'умк',
#   'перспективная',
#   'начальная',
#   'ш'],
#  ['сдается',
#   'двухкомнатная',
#   'квартира',
#   'кв',
#   'м',
#   'в',
#   'екатеринбурге',
#   'вторчермет',
#   'эскадронная',
#   'ул',
#   'руб',
#   'месяц'],
#  ['вакансии',
#   'и',
#   'работа',
#   'дворник',
#   'разнорабочий',
#   'у',
#   'прямого',
#   'работодателя',
#   'в',
#   'москве',
#   'поиск',
#   'работы',
#   'с',
#   'городработ',
#   'ру'],
#  ['скачать',
#   'песню',
#   'kreayshawn',
#   'hey',
#   'bitch',
#   'do',
#   'you',
#   'really',
#   'wanna',
#   'go',
#   'hard',
#   'trap',
#   'mix',
#   'бесплатно',
#   'и',
#   'слушать',
#   'онлайн',
#   'mp',
#   'cc',
#   'biz'],
#  ['дроссельную',
#   'заслонку',
#   'gaz',
#   'газель',
#   'купить',
#   'в',
#   'барнауле',
#   'цены',
#   'на',
#   'новые',
#   'бу',
#   'и',
#   'контрактные',
#   'запчасти',
#   'для',
#   'авто',
#   'газ',
#   'газель'],
#  ['заготовки', 'рецепты'],
#  ['biolage', 'отзывы', 'покупателей'],
#  ['наталья', 'москва'],
#  ['администратор'],
#  ['лучшие', 'светодиодные', 'ленты', 'года', 'топ', 'рейтинг', 'лучших'],
#  ['обои',
#   'видео',
#   'игры',
#   'mass',
#   'effect',
#   'обои',
#   'для',
#   'рабочего',
#   'стола',
#   'фотографии',
#   'видео',
#   'игры',
#   'm'],
#  ['значение', 'имени', 'иннокентий', 'кеша'],
#  ['tut',
#   'by',
#   'работа',
#   'тут',
#   'поиск',
#   'работы',
#   'в',
#   'минске',
#   'и',
#   'беларуси'],
#  ['гдз',
#   'по',
#   'русскому',
#   'языку',
#   'за',
#   'класс',
#   'решебники',
#   'ответы',
#   'онлайн'],
#  ['комплексный',
#   'центр',
#   'социального',
#   'обслуживания',
#   'населения',
#   'бологовского',
#   'района',
#   'структура',
#   'центра'],
#  ['документы', 'для', 'учебы'],
#  ['подсветка',
#   'салона',
#   'vw',
#   'skoda',
#   'передний',
#   'плафон',
#   'цена',
#   'руб',
#   'купить',
#   'в',
#   'санкт',
#   'петербурге',
#   'tiu',
#   'ru',
#   'id'],
#  ['watch', 'online', 'dyan', 'cannon', 'doctors', 'wives', 'hd', 'p'],
#  ['профессор', 'карапуз', 'музична', 'пригода', 'dvd', 'бесплатно', 'скачать'],
#  ['продам',
#   'volkswagen',
#   'bora',
#   'г',
#   'в',
#   'пмр',
#   'авторынок',
#   'пмр',
#   'и',
#   'молдовы',
#   'клаксона'],
#  ['визиты',
#   'осенние',
#   'визиты',
#   'спектр',
#   'кредо',
#   'электронная',
#   'библиотека',
#   'асмодея'],
#  ['вакансия',
#   'слесарь',
#   'механосборочных',
#   'работ',
#   'в',
#   'туле',
#   'работа',
#   'в',
#   'витра'],
#  ['рукоделие',
#   'картины',
#   'образы',
#   'рукодельниц',
#   'в',
#   'живописи',
#   'картин',
#   'современных',
#   'художников'],
#  ['joyreactor',
#   'смешные',
#   'картинки',
#   'и',
#   'другие',
#   'приколы',
#   'комиксы',
#   'гиф',
#   'анимация',
#   'видео',
#   'лучший',
#   'интеллектуальный',
#   'юмор'],
#  ['art', 'lingerie', 'ero', 'full', 'sets', 'page'],
#  ['нахальный', 'пронырливый', 'человек', 'букв'],
#  ['charles',
#   'perrot',
#   'hood',
#   'little',
#   'riding',
#   'red',
#   'ringkasan',
#   'pelajaran',
#   'tentang',
#   'bacaan',
#   'sastera',
#   'mengenai',
#   'tema',
#   'charles',
#   'perrot',
#   'little',
#   'red',
#   'riding',
#   'hood'],
#  ['powered', 'by', 'ameba'],
#  ['туры',
#   'в',
#   'отель',
#   'alara',
#   'star',
#   'турция',
#   'аланья',
#   'цены',
#   'и',
#   'отзывы'],
#  ['объявление',
#   'снять',
#   'комнатную',
#   'квартиру',
#   'в',
#   'районе',
#   'центральный',
#   'в',
#   'городе',
#   'хабаровск',
#   'аренда',
#   'трехкомнатных',
#   'квартир',
#   'на',
#   'длительный',
#   'срок',
#   'найти',
#   'ж'],
#  ['стоматология',
#   'до',
#   'и',
#   'после',
#   'улыбка',
#   'всевластия',
#   'стоматолог',
#   'улыбка',
#   'зубы',
#   'властел'],
#  ['перечень',
#   'предохранителей',
#   'для',
#   'компонетов',
#   'блок',
#   'реле',
#   'и',
#   'предохранителей',
#   'расположенный',
#   'под',
#   'панелью',
#   'управления',
#   'руководство',
#   'по',
#   'обслуживанию',
#   'и',
#   'ремонту',
#   'honda',
#   'fr',
#   'v',
#   'sjd',
#   'e',
#   'j',
#   'cbrt'],
#  ['new',
#   'best',
#   'of',
#   'deep',
#   'house',
#   'the',
#   'best',
#   'of',
#   'sexy',
#   'party',
#   'deep',
#   'house',
#   'nu',
#   'disco',
#   'music',
#   'girls',
#   'music',
#   'video',
#   'daftsex'],
#  ['una',
#   'buena',
#   'follada',
#   'para',
#   'marta',
#   'croft',
#   'rica',
#   'follada',
#   'con',
#   'una',
#   'joven',
#   'reina'],
#  ['отзывы',
#   'о',
#   'моделирующая',
#   'паста',
#   'для',
#   'тела',
#   'organic',
#   'shop',
#   'похудение',
#   'экспресс',
#   'греческое',
#   'талассо'],
#  ['дестабилизировать', 'это', 'что', 'такое', 'дестабилизировать'],
#  ['стр',
#   'работа',
#   'нур',
#   'султан',
#   'объявлений',
#   'на',
#   'вакансий',
#   'www',
#   'enbek',
#   'kz'],
#  ['мой', 'мир', 'mail', 'ru'],
#  ['streptococcus',
#   'pneumonia',
#   'в',
#   'горле',
#   'отоларингология',
#   'здоровье',
#   'mail',
#   'ru'],
#  ['фото', 'города', 'бетлица', 'россия', 'фотографий'],
#  ['route',
#   'advisor',
#   'small',
#   'mirrors',
#   'версия',
#   'для',
#   'american',
#   'truck',
#   'simulator',
#   'v'],
#  ['читать',
#   'книгу',
#   'поцелуй',
#   'горца',
#   'автор',
#   'монинг',
#   'карен',
#   'онлайн',
#   'страница',
#   'читать',
#   'книгу',
#   'без',
#   'регистрации'],
#  ['спасибо', 'за', 'покупку'],
#  ['надежда', 'псков'],
#  ['оргия',
#   'на',
#   'яхте',
#   'в',
#   'море',
#   'порно',
#   'видео',
#   'онлайн',
#   'смотреть',
#   'бесплатно'],
#  ['проверка', 'и', 'отзывы', 'о', 'сайте', 'prezika', 'net'],
#  ['аладдин',
#   'мультфильм',
#   'смотреть',
#   'онлайн',
#   'в',
#   'хорошем',
#   'качестве',
#   'бесплатно'],
#  ['kedi', 'lerde', 'hi', 'perti', 'roi', 'di', 'pati', 'saray'],
#  ['taboo', 'heat', 'full', 'xxx', 'movies'],
#  ['преддипломная', 'практика', 'в', 'начальной', 'школе'],
#  ['сковороды',
#   'сотейники',
#   'scovo',
#   'купить',
#   'в',
#   'крыму',
#   'севастополе',
#   'симферополе',
#   'керчи',
#   'феодосии',
#   'ялте',
#   'topsto',
#   'страница'],
#  ['workout', 'archives', 'coca', 'porn'],
#  ['download',
#   'photo',
#   'x',
#   'jeans',
#   'skirt',
#   'ass',
#   'asshole',
#   'pussy',
#   'henessy',
#   'meaty',
#   'pussy',
#   'nice',
#   'ass',
#   'hamburger',
#   'pussy',
#   'plump',
#   'pussy',
#   'puffy',
#   'pussy',
#   'thighs',
#   'id'],
#  ['конструктор',
#   'строительная',
#   'площадка',
#   'купить',
#   'в',
#   'тольятти',
#   'цена',
#   'руб',
#   'дата',
#   'размещения',
#   'игрушки',
#   'и',
#   'игры'],
#  ['лучшие',
#   'цены',
#   'для',
#   'toyota',
#   'трос',
#   'стояночного',
#   'тормоза',
#   'лучшие',
#   'цены',
#   'поставщиков',
#   'для',
#   'трос',
#   'стояночного',
#   'тормоза',
#   'toyota',
#   'burjauto'],
#  ['некоторые',
#   'думают',
#   'что',
#   'футбол',
#   'это',
#   'дело',
#   'жизни',
#   'и',
#   'смерти',
#   'я',
#   'совершенно',
#   'разочарован',
#   'их',
#   'позицией',
#   'футбол',
#   'намного',
#   'важнее',
#   'свободное',
#   'мнение',
#   'бло'],
#  ['what',
#   'remains',
#   'of',
#   'edith',
#   'finch',
#   'pc',
#   'repack',
#   'от',
#   'xatab',
#   'скачать',
#   'через',
#   'торрент',
#   'на',
#   'pc'],
#  ['secure', 'monitor', 'clip', 'art', 'clip', 'art', 'library'],
#  ['target', 'my', 'com'],
#  ['знакомства',
#   'с',
#   'парнями',
#   'краснодарский',
#   'край',
#   'новороссийск',
#   'результаты',
#   'поиска',
#   'сайт',
#   'знакомств',
#   'тралоло'],
#  ['сказка',
#   'о',
#   'попе',
#   'и',
#   'работнике',
#   'его',
#   'балде',
#   'а',
#   'с',
#   'пушкин',
#   'читать',
#   'онлайн'],
#  ['baleja', 'na', 'd', 'ugich', 'w', 'osach'],
#  ['ылым',
#   'саласында',
#   'ы',
#   'сыйлы',
#   'тар',
#   'мен',
#   'мемлекетт',
#   'к',
#   'ылыми',
#   'стипендиялар',
#   'туралы',
#   'аза',
#   'стан',
#   'республикасы',
#   'к',
#   'мет',
#   'н',
#   'жыл',
#   'ы',
#   'ш',
#   'лдедег',
#   'аулысы'],
#  ['сонник',
#   'новые',
#   'отношения',
#   'приснились',
#   'к',
#   'чему',
#   'снятся',
#   'новые',
#   'отношения',
#   'во',
#   'сне',
#   'видеть'],
#  ['куркума',
#   'при',
#   'ваг',
#   'тност',
#   'експерти',
#   'назвали',
#   'неспод',
#   'вану',
#   'користь',
#   'але',
#   'нюанси',
#   'znaj',
#   'ua'],
#  ['tamil', 'actress', 'sona', 'nude', 'hairy', 'pussy', 'sex', 'photo'],
#  ['фото',
#   'альбом',
#   'фото',
#   'группы',
#   'фото',
#   'фотографии',
#   'будь',
#   'в',
#   'тренде'],
#  ['кондиционеры',
#   'balea',
#   'для',
#   'волос',
#   'заказать',
#   'из',
#   'германии',
#   'доставка'],
#  ['харампурнефтегаз',
#   'получил',
#   'права',
#   'на',
#   'строительство',
#   'объектов',
#   'на',
#   'харампурском',
#   'месторождении',
#   'oilcapital'],
#  ['остров',
#   'миагани',
#   'последняя',
#   'бомба',
#   'местонахождение',
#   'virtualgameinfo',
#   'ru'],
#  ['архитектурные',
#   'вузы',
#   'университеты',
#   'институты',
#   'академии',
#   'и',
#   'факультеты',
#   'саратовской',
#   'области',
#   'вузы',
#   'для',
#   'архитекторов',
#   'учёба',
#   'ру'],
#  ['авторизац', 'я', 'на', 'портал', 'apkua', 'net'],
#  ['blue',
#   'eyed',
#   'babe',
#   'is',
#   'gently',
#   'licking',
#   'the',
#   'tip',
#   'of',
#   'her',
#   'lover',
#   's',
#   'dick',
#   'to',
#   'make',
#   'him',
#   'cum',
#   'perfect',
#   'girls'],
#  ['спортмастер',
#   'г',
#   'санкт',
#   'петербург',
#   'трк',
#   'жемчужная',
#   'плаза',
#   'петергофское',
#   'шоссе',
#   'д',
#   'в',
#   'г',
#   'санкт',
#   'петербург'],
#  ['урок', 'по', 'музыке', 'главный', 'кит', 'песня', 'класс', 'урок'],
#  ['извадете',
#   'електричеството',
#   'както',
#   'сте',
#   'избрали',
#   'електрически',
#   'длето',
#   'универсален',
#   'инструмент',
#   'за',
#   'работилница',
#   'за',
#   'домашен',
#   'фурнир'],
#  ['александры', 'с', 'загран', 'паспортами', 'помогите'],
#  ['pavloolesya', 'yandex', 'ru', 'почта', 'mail', 'ru'],
#  ['синонимы', 'к', 'слову', 'удержать', 'в', 'вертикальном', 'положении'],
#  ['читать',
#   'мангу',
#   'макрофаг',
#   'ломая',
#   'каноны',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['l',
#   'incroyable',
#   'histoire',
#   'de',
#   'la',
#   'chirurgie',
#   'plastique',
#   'la',
#   'plus',
#   'effrayante',
#   'au',
#   'monde',
#   'savoir'],
#  ['начальный', 'уровень', 'гдз', 'решебник', 'по', 'физике', 'классов'],
#  ['работа',
#   'в',
#   'сфере',
#   'транспорт',
#   'автобизнес',
#   'автосервис',
#   'от',
#   'руб',
#   'в',
#   'москве'],
#  ['shawna', 'lenee', 'porn', 'videos', 'perfect', 'girls'],
#  ['tralolo',
#   'com',
#   'социальная',
#   'сеть',
#   'позволяющая',
#   'знакомится',
#   'и',
#   'общятся',
#   'с',
#   'людьми',
#   'отправляю',
#   'смс',
#   'и',
#   'еще',
#   'много',
#   'другое'],
#  ['фильм',
#   'закон',
#   'каменных',
#   'джунглей',
#   'фильм',
#   'фото',
#   'видео',
#   'список',
#   'актеров',
#   'вокруг',
#   'тв'],
#  ['бедная',
#   'настя',
#   'серия',
#   'смотреть',
#   'онлайн',
#   'сериал',
#   'gidfilm',
#   'ru',
#   'красвью'],
#  ['обувь', 'shop', 'страница', 'slon', 'sneakers'],
#  ['мотоциклист',
#   'погиб',
#   'из',
#   'за',
#   'столкновения',
#   'с',
#   'иномаркой',
#   'на',
#   'улице',
#   'землячки',
#   'в',
#   'сормовском',
#   'районе',
#   'нижнего',
#   'новгорода',
#   'сентября',
#   'года',
#   'новости',
#   'nn',
#   'ru'],
#  ['плохие',
#   'отзывы',
#   'о',
#   'bfgoodrich',
#   'g',
#   'force',
#   'winter',
#   'r',
#   't',
#   'я',
#   'прочитал',
#   'здесь'],
#  ['приказ', 'минобразования', 'рф', 'от', 'n'],
#  ['электротриммер', 'p', 'i', 't', 'ptr', 'el'],
#  ['страница',
#   'моя',
#   'любимая',
#   'с',
#   'нежность',
#   'читать',
#   'онлайн',
#   'юлия',
#   'шкутова',
#   'полно',
#   'книг'],
#  ['схемка',
#   'осенняя',
#   'красота',
#   'листьев',
#   'от',
#   'мариэлла',
#   'обсуждение',
#   'на',
#   'liveinternet'],
#  ['особенности',
#   'межнациональных',
#   'сношений',
#   'dvdrip',
#   'hd',
#   'в',
#   'хорошем',
#   'качестве',
#   'вид'],
#  ['фильмов', 'о', 'подвиге', 'и', 'силе', 'духа', 'рамблер', 'кино'],
#  ['аренда',
#   'cклада',
#   'м',
#   'сигнальный',
#   'проезд',
#   'с',
#   'москва',
#   'свао',
#   'р',
#   'н',
#   'отрадное',
#   'м',
#   'владыкино',
#   'база',
#   'циан',
#   'объявление'],
#  ['погода',
#   'в',
#   'актаныш',
#   'на',
#   'сентябрь',
#   'самый',
#   'tочный',
#   'прогноз',
#   'на',
#   'сентябрь',
#   'от',
#   'гидрометцентра',
#   'актаныш'],
#  ['разнообразие',
#   'стилей',
#   'в',
#   'творчестве',
#   'художника',
#   'казимира',
#   'малевича',
#   'designonstop',
#   'о'],
#  ['блендеры',
#   'bosch',
#   'купить',
#   'блендер',
#   'бош',
#   'цены',
#   'и',
#   'отзывы',
#   'в',
#   'интернет',
#   'магазине',
#   'ситилинк',
#   'таганрог'],
#  ['мой', 'мир', 'mail', 'ru'],
#  ['порно',
#   'телеканал',
#   'o',
#   'la',
#   'la',
#   'tv',
#   'смотреть',
#   'онлайн',
#   'бесплатно'],
#  ['беру',
#   'скидка',
#   'на',
#   'все',
#   'промокод',
#   'по',
#   'ваш',
#   'промокод',
#   'kuponinaskidku',
#   'купоны',
#   'на',
#   'скидку'],
#  ['мужик', 'развел', 'чужую', 'жену', 'с', 'большими', 'сиськами'],
#  ['pes',
#   'pro',
#   'evolution',
#   'soccer',
#   'skachat',
#   'tas',
#   'ix',
#   'скачать',
#   'без',
#   'steam',
#   'asilmedia',
#   'net',
#   'тас',
#   'икс',
#   'tas',
#   'ix',
#   'фильмы',
#   'сериалы',
#   'игры',
#   'клипы',
#   'музыка',
#   'програм'],
#  ['слушать',
#   'аудиои',
#   'книгу',
#   'выжми',
#   'из',
#   'бизнеса',
#   'все',
#   'млн',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['миля', 'трейлер', 'на', 'русском'],
#  ['фистинг', 'девушки', 'в', 'латексе'],
#  ['китайская',
#   'биокомпания',
#   'создала',
#   'своего',
#   'первого',
#   'клонированного',
#   'котенка',
#   'техкульт'],
#  ['наглядная',
#   'биохимия',
#   'я',
#   'кольман',
#   'к',
#   'г',
#   'рем',
#   'год',
#   'библиотека',
#   'медицинской',
#   'л'],
#  ['orgpage'],
#  ['размер', 'колес', 'на', 'toyota', 'verossa', 'размер', 'колес'],
#  ['читать',
#   'онлайн',
#   'бартш',
#   'карина',
#   'бирюзовая',
#   'зима',
#   'электронная',
#   'библиотека',
#   'e',
#   'libra',
#   'ru'],
#  ['алалия', 'методика', 'работы', 'с', 'безречевыми', 'детьми'],
#  ['приговор', 'суда', 'по', 'ч', 'ст', 'ук', 'рф', 'судебная', 'практика'],
#  ['масло',
#   'для',
#   'загара',
#   'в',
#   'солярии',
#   'ultra',
#   'x',
#   'oil',
#   'capsule',
#   'power',
#   'tan',
#   'ultra',
#   'x'],
#  ['серия',
#   'аниме',
#   'покорение',
#   'горизонта',
#   'log',
#   'horizon',
#   'озвучка',
#   'от',
#   'anidub',
#   'ancord',
#   'balfor',
#   'cuba',
#   'inspector',
#   'gadjet',
#   'jam',
#   'nika',
#   'lenina',
#   'oslikt',
#   'shina',
#   'trina',
#   'd',
#   'смотреть',
#   'онлайн',
#   'anime'],
#  ['арсенал',
#   'частное',
#   'охранное',
#   'предприятие',
# ...
#  ['manyvids', 'page', 'incest', 'porn', 'videos', 'family', 'extreme', 'sex'],
#  ['сим', 'таррэн', 'феррис', 'от', 'аканехиде'],
#  ['декасан',
#   'состав',
#   'препарата',
#   'от',
#   'чего',
#   'помогает',
#   'в',
#   'стомалогории',
#   'при',
#   'бронхите',
#   'ангине',
#   'как',
#   'применять',
#   'при',
#   'беременности',
#   'для',
#   'детей',
#   'цена',
#   'аналоги'],
#  ['в', 'дорогу', 'с', 'попутчиками', 'без', 'хлопот', 'blablacar', 'ru'],
#  ['черные', 'босоножки', 'на', 'блочном', 'каблуке', 'glamorous', 'asos'],
#  ['declan', 'wake', 'форум', 'о', 'куклах', 'dp'],
#  ['как',
#   'грамотно',
#   'расставить',
#   'мебель',
#   'в',
#   'маленькой',
#   'кухне',
#   'чтобы',
#   'использовать',
#   'все',
#   'пространство'],
#  ['вакансия',
#   'для',
#   'студентов',
#   'в',
#   'городе',
#   'санкт',
#   'петербург',
#   'работа',
#   'в',
#   'coach',
#   'institute',
#   'гибкий',
#   'график'],
#  ['полная',
#   'вагина',
#   'спермы',
#   'онлайн',
#   'смотреть',
#   'бесплатно',
#   'порно',
#   'видео',
#   'онлайн'],
#  ['developpe',
#   'sex',
#   'цена',
#   'руб',
#   'купить',
#   'в',
#   'москве',
#   'tiu',
#   'ru',
#   'id'],
#  ['отзывы',
#   'о',
#   'сбербанке',
#   'россии',
#   'двойное',
#   'списание',
#   'средств',
#   'за',
#   'мобильный',
#   'банк',
#   'банки',
#   'ру'],
#  ['телка',
#   'из',
#   'питера',
#   'после',
#   'знакомства',
#   'с',
#   'новым',
#   'другом',
#   'снимается',
#   'в',
#   'крутом',
#   'домашнем',
#   'порн'],
#  ['русский',
#   'язык',
#   'класс',
#   'т',
#   'а',
#   'ладыженская',
#   'м',
#   'т',
#   'баранов',
#   'в',
#   'ч',
#   'номер'],
#  ['иерусалимское', 'королевство', 'все', 'монархии', 'мира'],
#  ['как',
#   'отучить',
#   'лайку',
#   'поедать',
#   'или',
#   'трепать',
#   'битую',
#   'дичь',
#   'зверька'],
#  ['сайт', 'знакомств', 'loveplanet', 'ru'],
#  ['blowyourbrain',
#   'россия',
#   'санкт',
#   'петербург',
#   'м',
#   'лесная',
#   'dating',
#   'ru'],
#  ['сервис', 'не', 'доступен'],
#  ['термо',
#   'комбинезон',
#   'на',
#   'мальчика',
#   'французский',
#   'peak',
#   'mountain',
#   'грн',
#   'одежда',
#   'для',
#   'мальчиков',
#   'киев',
#   'на',
#   'olx'],
#  ['редактировать', 'товар', 'личный', 'кабинет', 'agroserver', 'ru'],
#  ['коттеджи', 'дома', 'участки', 'realt', 'by'],
#  ['порно', 'видео', 'онлайн', 'мин'],
#  ['стихи', 'детям', 'как', 'зимуют', 'животные'],
#  ['уайат',
#   'сенак',
#   'разрулит',
#   'сезон',
#   'серия',
#   'смотреть',
#   'онлайн',
#   'hd',
#   'беспла'],
#  ['тюменский',
#   'дизайнер',
#   'алена',
#   'дубровина',
#   'получила',
#   'гран',
#   'при',
#   'в',
#   'москве',
#   'ru',
#   'новости',
#   'тюмени'],
#  ['коты', 'мордой', 'вниз'],
#  ['администратор', 'отеля'],
#  ['ооо',
#   'группа',
#   'компаний',
#   'михайлов',
#   'и',
#   'партнеры',
#   'москва',
#   'инн',
#   'огрн'],
#  ['сергей', 'скрипаль', 'контингент', 'книга', 'афган', 'читать', 'онлайн'],
#  ['beautiful',
#   'teen',
#   'softcore',
#   'free',
#   'porn',
#   'sex',
#   'videos',
#   'xxx',
#   'movies',
#   'hd',
#   'home',
#   'of',
#   'videos',
#   'porno'],
#  ['team', 'nonfiction', 'aimi', 'yoshikawa', 'daftsex'],
#  ['кислоты', 'в', 'фармакологии'],
#  ['читать',
#   'мангу',
#   'боевой',
#   'континент',
#   'страна',
#   'душ',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['продаётся',
#   'ссангйонг',
#   'рекстон',
#   'года',
#   'в',
#   'томске',
#   'собственник',
#   'владею',
#   'лет',
#   'литра',
#   'бензин',
#   'акпп'],
#  ['armtek',
#   'запчасти',
#   'для',
#   'грузовых',
#   'и',
#   'легковых',
#   'автомобилей',
#   'оборудование',
#   'для',
#   'сто'],
#  ['нордрута', 'пододеяльник', 'и', 'наволочка', 'серый', 'синий', 'ikea'],
#  ['манга', 'the', 'promised', 'neverland', 'онлайн'],
#  ['продам', 'батареи', 'грн', 'отопление', 'харьков', 'на', 'olx'],
#  ['автозапчасти',
#   'в',
#   'городе',
#   'дюссельдорф',
#   'германия',
#   'каталог',
#   'магазинов',
#   'автозапчастей',
#   'адреса',
#   'телефоны',
#   'время',
#   'работы',
#   'сайт'],
#  ['вакансия',
#   'инженер',
#   'видеонаблюдения',
#   'в',
#   'серове',
#   'работа',
#   'в',
#   'компании',
#   'угмк',
#   'холдинг',
#   'полный',
#   'рабочий',
#   'день'],
#  ['секс', 'на', 'выпускном', 'вечере'],
#  ['скачать', 'порно', 'длинноволосых', 'красоток', 'на', 'телефон'],
#  ['мег', 'монстр', 'глубины', 'скачать', 'торрент', 'файл', 'бесплатно'],
#  ['решено',
#   'упр',
#   'урок',
#   'unit',
#   'гдз',
#   'english',
#   'кузовлев',
#   'класс',
#   'с',
#   'переводом',
#   'заданий'],
#  ['анатоли',
#   'лет',
#   'лев',
#   'плещеницы',
#   'анкета',
#   'знакомств',
#   'на',
#   'сайте',
#   'tabor',
#   'ru'],
#  ['крахмал',
#   'загуститель',
#   'или',
#   'заменитель',
#   'полезный',
#   'и',
#   'не',
#   'очень',
#   'хорошо',
#   'выглядеть'],
#  ['сдам',
#   'ю',
#   'квартиру',
#   'до',
#   'июня',
#   'грн',
#   'долгосрочная',
#   'аренда',
#   'квартир',
#   'комнат',
#   'ильичевск',
#   'на',
#   'olx'],
#  ['серия',
#   'сезона',
#   'мультсериала',
#   'гриффины',
#   'в',
#   'озвучке',
#   'от',
#   'студии',
#   'coldfilm',
#   'игры',
#   'в',
#   'свидание',
#   'смотреть',
#   'гриффины',
#   'онлайн',
#   'в',
#   'hd',
#   'качестве'],
#  ['langes', 'blowjob', 'mдdchen'],
#  ['lush', 'silka', 'big', 'ass', 'will', 'be', 'banging', 'the', 'wall'],
#  ['расстояние', 'ростов', 'на', 'дону', 'феодосия', 'км', 'маршрута'],
#  ['pauline', 'ester', 'oui', 'je', 'l', 'adore'],
#  ['тюнинг',
#   'renault',
#   'sandero',
#   'в',
#   'казани',
#   'сравнить',
#   'цены',
#   'купить',
#   'потребительские',
#   'товары',
#   'на',
#   'маркетплейсе',
#   'tiu',
#   'ru'],
#  ['сонник',
#   'картинки',
#   'скелет',
#   'к',
#   'чему',
#   'снится',
#   'картинки',
#   'скелет',
#   'видеть',
#   'во',
#   'сне',
#   'сонник',
#   'дом'],
#  ['wise',
#   'memory',
#   'optimizer',
#   'рс',
#   'русский',
#   'portable',
#   'скачать',
#   'торрент',
#   'программу',
#   'бесплатно',
#   'без',
#   'регистрации'],
#  ['купальник',
#   'бикини',
#   'в',
#   'двухцветном',
#   'дизайне',
#   'для',
#   'размера',
#   'а',
#   'и',
#   'в',
#   'черный',
#   'серый'],
#  ['можно',
#   'обмен',
#   'на',
#   'скот',
#   'тг',
#   'nissan',
#   'нур',
#   'султан',
#   'астана',
#   'на',
#   'olx'],
#  ['temptation',
#   'of',
#   'mara',
#   'guy',
#   'sweens',
#   'скачать',
#   'бесплатно',
#   'mp',
#   'и',
#   'слушать',
#   'онлайн',
#   'видеок'],
#  ['современные',
#   'технологии',
#   'обучения',
#   'в',
#   'музыкальном',
#   'образовании',
#   'тема',
#   'научной',
#   'статьи',
#   'по',
#   'народному',
#   'образованию',
#   'и',
#   'педагогике',
#   'читайте',
#   'бесплатно'],
#  ['человек',
#   'в',
#   'одном',
#   'седане',
#   'мигранты',
#   'погибли',
#   'пытаясь',
#   'покинуть',
#   'гаити'],
#  ['playboy', 'naked', 'workout', 'more', 'girls', 'video', 'daftsex'],
#  ['урок',
#   'в',
#   'классе',
#   'по',
#   'теме',
#   'повторение',
#   'и',
#   'систематизация',
#   'изученного',
#   'об',
#   'имени',
#   'существительном',
#   'бюджетное',
#   'общеобразовательное',
#   'учреждение',
#   'вышне',
#   'ольшанская',
#   'средняя',
#   'общеобразовательная',
#   'школа'],
#  ['транспортный',
#   'налог',
#   'ветеранам',
#   'боевых',
#   'советы',
#   'адвокатов',
#   'и',
#   'юристов'],
#  ['балаба',
#   'ша',
#   'жасында',
#   'ы',
#   'балалар',
#   'а',
#   'арнал',
#   'ан',
#   'таныстыру',
#   'c',
#   'ра',
#   'жауап'],
#  ['коттеджи', 'на', 'новый', 'год', 'загородный', 'отдых'],
#  ['салат', 'гранатовый'],
#  ['блондинку',
#   'с',
#   'большими',
#   'сиськами',
#   'изнасиловали',
#   'в',
#   'бдсм',
#   'игре'],
#  ['руководство', 'издание', 'четвертое', 'дополненное', 'и', 'переработанное'],
#  ['site', 'statistics'],
#  ['indian',
#   'sal',
#   'school',
#   'ladki',
#   'ki',
#   'chudai',
#   'sal',
#   'ke',
#   'boyfriend',
#   'ke',
#   'sath',
#   'full',
#   'hd',
#   'mobile',
#   'sex',
#   'hq',
#   'videos',
#   'watch',
#   'and',
#   'download',
#   'indian',
#   'sal',
#   'school',
#   'ladki',
#   'ki',
#   'chudai',
#   'sal',
#   'ke',
#   'boyfriend',
#   'ke',
#   'sath',
#   'full',
#   'hd',
#   'hot',
#   'porn',
#   'at',
#   'rajwap',
#   'xyz'],
#  ['проблема',
#   'сцепление',
#   'моего',
#   'камаза',
#   'дальнобойщики',
#   'всех',
#   'стран',
#   'объединяйтесь'],
#  ['барахолка', 'уфа'],
#  ['отзывы', 'о', 'антиперспирант', 'maxim'],
#  ['профиль', 'пользователя', 'oazistour', 'путешествия', 'и', 'отдых'],
#  ['как',
#   'связаться',
#   'с',
#   'оператором',
#   'триколор',
#   'тв',
#   'тыс',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['запрашиваемая', 'страница', 'не', 'найдена'],
#  ['zinchenko',
#   'roman',
#   'профиль',
#   'пользователя',
#   'фото',
#   'сайт',
#   'photosight',
#   'ru'],
#  ['just',
#   'cause',
#   'multiplayer',
#   'рс',
#   'русский',
#   'repack',
#   'скачать',
#   'торрент',
#   'игру',
#   'бесплатно',
#   'без',
#   'регистрации'],
#  ['mobil',
#   'programma',
#   'ziyo',
#   'music',
#   'com',
#   'o',
#   'yin',
#   'programma',
#   'temalar',
#   'ziyo',
#   'music',
#   'com',
#   'bass',
#   'lezginka',
#   'dubstep',
#   'club',
#   'musiclar'],
#  ['mero', 'lalala', 'official', 'music'],
#  ['решение', 'м', 'м', 'от', 'сентября', 'г', 'по', 'делу', 'судакт', 'ру'],
#  ['тип',
#   'заинтересовался',
#   'дыркой',
#   'опытной',
#   'женщины',
#   'и',
#   'выебал',
#   'ее',
#   'на',
#   'диване'],
#  ['пословицы', 'и', 'поговорки', 'про', 'дни', 'недели'],
#  [],
#  ['суккулент', 'крассула', 'купера', 'растения', 'во', 'владивостоке'],
#  ['сервисная',
#   'компания',
#   'буттэк',
#   'отзывы',
#   'фото',
#   'цены',
#   'телефон',
#   'и',
#   'адрес',
#   'сервисные',
#   'центры',
#   'москва',
#   'zoon',
#   'ru'],
#  ['фото',
#   'кпб',
#   'поплин',
#   'византия',
#   'графит',
#   'цена',
#   'руб',
#   'отдам',
#   'за',
#   'руб'],
#  ['доставка',
#   'продуктов',
#   'на',
#   'дом',
#   'в',
#   'елизово',
#   'и',
#   'камчатском',
#   'крае',
#   'адрес',
#   'телефон',
#   'карта',
#   'проезда'],
#  ['продается',
#   'автобус',
#   'toyota',
#   'hiace',
#   'автобусы',
#   'в',
#   'комсомольске',
#   'на',
#   'амуре'],
#  ['hentai', 'porn', 'videos', 'perfect', 'girls'],
#  ['для', 'тебя'],
#  ['impure',
#   'sarah',
#   's',
#   'life',
#   'update',
#   'inprogress',
#   'ver',
#   'sxs',
#   'hentai'],
#  ['саратов',
#   'дача',
#   'снт',
#   'архитектор',
#   'тыс',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['детский',
#   'лагерь',
#   'огонек',
#   'в',
#   'сергиевом',
#   'посаде',
#   'оздоровительный',
#   'лагерь',
#   'огонек',
#   'детский',
#   'отдых'],
#  ['мать', 'смотрит', 'как', 'отец', 'трахает', 'красавицу', 'дочь'],
#  ['читать',
#   'онлайн',
#   'книгу',
#   'единственная',
#   'для',
#   'барса',
#   'бесплатно',
#   'страница'],
#  ['купить', 'серебряный', 'браслет', 'br', 'glitter', 'в', 'беларуси'],
#  ['сонник',
#   'смотреть',
#   'мультфильм',
#   'приснился',
#   'к',
#   'чему',
#   'снится',
#   'смотреть',
#   'мультфильм',
#   'во',
#   'сне',
#   'видеть'],
#  ['ov', 'bazunova', 'list', 'ru', 'почта', 'mail', 'ru'],
#  ['р', 'ама', 'с', 'голой', 'гс', 'с', 'дс', 'с', 'кос', 'мис', 'с', 'ебенка'],
#  ['программы',
#   'для',
#   'бесплатного',
#   'создания',
#   'сайта',
#   'движки',
#   'joomla',
#   'wordpress',
#   'и',
#   'программная',
#   'оболочка',
#   'денвер',
#   'для',
#   'создания',
#   'виртуального',
#   'хостинга',
#   'на',
#   'домашнем',
#   'комп'],
#  ['федор',
#   'бондарчук',
#   'и',
#   'паулина',
#   'андреева',
#   'сыграли',
#   'свадьбу',
#   'в',
#   'петербурге'],
#  ['автокран', 'ивановец', 'кс', 'к', 'р', 'шасси', 'камаз', 'тонн'],
#  ['bob',
#   'dylan',
#   'joan',
#   'baez',
#   'blowing',
#   'in',
#   'the',
#   'wind',
#   'смотреть',
#   'видео',
#   'онлайн',
#   'в',
#   'моем',
#   'мире',
#   'lena'],
#  ['какое',
#   'ружье',
#   'лучше',
#   'мр',
#   'или',
#   'сайга',
#   'и',
#   'чем',
#   'популярное',
#   'оружие'],
#  ['детей',
#   'в',
#   'яслях',
#   'будут',
#   'обучать',
#   'по',
#   'инновационной',
#   'программе',
#   'российская',
#   'газета'],
#  ['знакомства', 'в', 'нерюнгри', 'сайт', 'знакомств', 'шуры', 'муры'],
#  ['насос',
#   'электрический',
#   'adrenalin',
#   'air',
#   'pump',
#   'mini',
#   'купить',
#   'в',
#   'москве',
#   'цена',
#   'фото',
#   'отзывы',
#   'и',
#   'характеристики'],
#  ['tut',
#   'by',
#   'работа',
#   'тут',
#   'поиск',
#   'работы',
#   'в',
#   'минске',
#   'и',
#   'беларуси'],
#  ['шар', 'латексный'],
#  ['гласная',
#   'буква',
#   'и',
#   'класс',
#   'конспект',
#   'и',
#   'презентация',
#   'урока',
#   'по',
#   'фгос',
#   'готовый',
#   'млн',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['гифки', 'поиск', 'на', 'сайте', 'fishki', 'net'],
#  ['lot', 'of', 'problems', 'перевод', 'и', 'примеры', 'предложений'],
#  ['галерея'],
#  ['ужасы', 'страница'],
#  ['октябрьский', 'почта', 'mail', 'ru'],
#  ['моя', 'реклама'],
#  ['бетостоун',
#   'быстросохнущая',
#   'двухкомпонентная',
#   'полиуретановая',
#   'грунт',
#   'эмаль',
#   'для',
#   'от',
#   'компании',
#   'рифорн',
#   'купить',
#   'в',
#   'городе',
#   'екатеринбург'],
#  ['поиск', 'работы', 'и', 'вакансий', 'undefined', 'зарплата', 'ру'],
#  ['cкачать', 'шашки', 'windows'],
#  ['фигурки',
#   'из',
#   'оникса',
#   'и',
#   'их',
#   'значение',
#   'в',
#   'древности',
#   'и',
#   'современности',
#   'для',
#   'удачи'],
#  ['каким',
#   'образом',
#   'обеспечивается',
#   'защита',
#   'прав',
#   'ребенка',
#   'в',
#   'рф',
#   'защита',
#   'прав',
#   'ребенка',
#   'в',
#   'российской',
#   'федерации'],
#  ['золото', 'древней', 'руси', 'черняев', 'а', 'ф'],
#  ['расстановка',
#   'героев',
#   'из',
#   'альянсов',
#   'человек',
#   'воин',
#   'чешуйчатый',
#   'охотник',
#   'неуловимый',
#   'убийца'],
#  ['print', 'ru', 'оперативная', 'цифровая', 'типография', 'в', 'краснодаре'],
#  ['каждому', 'по', 'тыкве'],
#  ['скачать', 'фильм', 'звездный', 'путь', 'на', 'телефон', 'gp', 'mp'],
#  ['teen',
#   'depression',
#   'residental',
#   'hilfe',
#   'вge',
#   'blonde',
#   'com',
#   'sex',
#   'teen'],
#  ['скачать',
#   'huwannuur',
#   'lirik',
#   'terjemah',
#   'abah',
#   'guru',
#   'sekumpul',
#   'смотреть',
#   'онлайн'],
#  ['поезда', 'самолеты', 'почта', 'mail', 'ru'],
#  ['запчасти',
#   'для',
#   'блендера',
#   'scarlett',
#   'sl',
#   'hb',
#   'm',
#   'им',
#   'деталюга'],
#  ['система',
#   'оповещения',
#   'и',
#   'управления',
#   'эвакуацией',
#   'статья',
#   'омега',
#   'саунд',
#   'россия'],
#  ['программа', 'обучения', 'по', 'охране', 'труда'],
#  ['толкование',
#   'карт',
#   'таро',
#   'разное',
#   'страница',
#   'тонкий',
#   'мир',
#   'эзотерический',
#   'форум',
#   'магия',
#   'гороскопы',
#   'гадания',
#   'заговоры',
#   'привороты',
#   'сонники',
#   'астр'],
#  ['крестный',
#   'отец',
#   'pocket',
#   'пьюзо',
#   'м',
#   'купить',
#   'в',
#   'амиталь',
#   'с',
#   'доставкой'],
#  ['порадую', 'вас', 'в', 'жопу', 'аделина', 'ишим', 'район', 'сто'],
#  ['мой', 'мир', 'mail', 'ru'],
#  ['подбор', 'шин', 'по', 'автомобилю'],
#  ['сварщик', 'пластмасс', 'еткс'],
#  ['фото', 'альбом', 'фото', 'группы', 'фото', 'фотографии', 'вязание'],
#  ['asian',
#   'milf',
#   'asa',
#   'akira',
#   'is',
#   'using',
#   'a',
#   'butplug',
#   'to',
#   'prepare',
#   'her',
#   'ass',
#   'for',
#   'a',
#   'massive',
#   'dick',
#   'perfect',
#   'girls'],
#  ['фото', 'тула', 'tatra', 't', 'b', 'su', 'transphoto'],
#  ['снабженец', 'экспедитор', 'водитель'],
#  ['видео',
#   'михаил',
#   'кононенко',
#   'видео',
#   'смотреть',
#   'онлайн',
#   'в',
#   'моем',
#   'мире'],
#  ['monster',
#   'energy',
#   'lime',
#   'green',
#   'эмблемы',
#   'для',
#   'gta',
#   'grand',
#   'theft',
#   'auto',
#   'v'],
#  ['german',
#   'guy',
#   'is',
#   'about',
#   'to',
#   'fuck',
#   'a',
#   'slutty',
#   'blonde',
#   'honey',
#   'in',
#   'a',
#   'public',
#   'place',
#   'during',
#   'the',
#   'day',
#   'ipad',
#   'porn',
#   'at',
#   'perfect',
#   'girls'],
#  ['купить',
#   'тормозную',
#   'систему',
#   'ssangyong',
#   'в',
#   'томске',
#   'сравнить',
#   'цены',
#   'на',
#   'тормозную',
#   'систему',
#   'ssangyong',
#   'в',
#   'томске',
#   'blizko'],
#  ['купить',
#   'dorken',
#   'delta',
#   'roof',
#   'дышащий',
#   'подкладочный',
#   'ковер',
#   'под',
#   'битумную',
#   'черепицу',
#   'фальцевую',
#   'кровлю',
#   'и',
#   'натуральный',
#   'сланец',
#   'цена',
#   'в',
#   'москве',
#   'на',
#   'roof',
#   'n',
#   'roll',
#   'ru'],
#  ['блондинка',
#   'с',
#   'пышной',
#   'грудью',
#   'занимается',
#   'сексом',
#   'с',
#   'мужем',
#   'после',
#   'свадьбы'],
#  ['сериал',
#   'обезьян',
#   'сезон',
#   'смотреть',
#   'онлайн',
#   'бесплатно',
#   'в',
#   'хорошем',
#   'качестве'],
#  ['юленька',
#   'лет',
#   'россия',
#   'альметьевск',
#   'trulolo',
#   'com',
#   'социальная',
#   'сеть',
#   'позволяющая',
#   'знакомится',
#   'и',
#   'общятся',
#   'с',
#   'людьми',
#   'отправляю',
#   'смс',
#   'и',
#   'еще',
#   'много',
#   'другое'],
#  ['видео',
#   'молодые',
#   'русское',
#   'порно',
#   'большие',
#   'дырки',
#   'мастурбация',
#   'красотки'],
#  ['новое', 'в', 'современном', 'обезболивании', 'животных'],
#  ['знакомства',
#   'рига',
#   'ольга',
#   'лет',
#   'бесплатный',
#   'сайт',
#   'знакомств',
#   'mobi',
#   'dating',
#   'ru',
#   'датинг',
#   'ру',
#   'бесплатный',
#   'мобильный',
#   'сайт',
#   'знакомств',
#   'для',
#   'серьезных',
#   'отношений',
#   'd'],
#  ['kiki', 'cyrus', 'a', 'hot', 'shower', 'an', 'old', 'man', 'sextorrent'],
#  ['шнур', 'ну', 'и', 'так', 'далее'],
#  ['анальная',
#   'азиатка',
#   'закатила',
#   'глаза',
#   'когда',
#   'на',
#   'нее',
#   'кончили',
#   'после',
#   'секса',
#   'rusex',
#   'club',
#   'me'],
#  ...]

# %%
occurence = Counter([token for doc in docs_title for token in doc])
occurence
# Out:
# Counter({'экс': 44,
#          'министр': 11,
#          'экономики': 38,
#          'молдовы': 15,
#          'главе': 8,
#          'мидэи': 1,
#          'цель': 39,
#          'которого': 23,
#          'сделать': 235,
#          'из': 3711,
#          'республики': 111,
#          'не': 2282,
#          'просителя': 1,
#          'а': 1692,
#          'донора': 1,
#          'надо': 80,
#          'избегать': 4,
#          'долгого': 2,
#          'нахождения': 4,
#          'н': 998,
#          'эта': 33,
#          'песня': 111,
#          'стала': 51,
#          'известна': 6,
#          'многим': 1,
#          'телезрителям': 1,
#          'благодаря': 10,
#          'сериалу': 5,
#          'диверсант': 2,
#          'банши': 3,
#          'сезон': 1014,
#          'серия': 1096,
#          'бремя': 5,
#          'красоты': 169,
#          'смотреть': 5542,
#          'онлайн': 11969,
#          'беси': 1,
#          'меня': 216,
#          'картинки': 549,
#          'в': 38391,
#          'новомосковске': 3,
#          'сыграют': 3,
#          'следж': 1,
#          'хоккеисты': 1,
#          'алексинской': 1,
#          'звезды': 86,
#          'и': 22731,
#          'сборной': 18,
#          'китая': 41,
#          'т': 597,
#          'салат': 111,
#          'корейская': 6,
#          'морковь': 20,
#          'копченая': 1,
#          'курица': 29,
#          'кукуруза': 9,
#          'сухарики': 2,
#          'мой': 1358,
#          'калорийность': 32,
#          'белки': 16,
#          'жиры': 15,
#          'углеводы': 15,
#          'угловой': 33,
#          'пневмогайковерт': 1,
#          'fubag': 7,
#          'rwc': 1,
#          'екатеринбурге': 404,
#          'купить': 6315,
#          'цены': 2477,
#          'отзывы': 3264,
#          'характеристики': 627,
#          'фото': 6378,
#          'инструкция': 434,
#          'табачный': 3,
#          'магазин': 1841,
#          'мир': 1602,
#          'табака': 8,
#          'курительные': 3,
#          'трубки': 12,
#          'stanwell': 1,
#          'курительная': 2,
#          'труб': 34,
#          'league': 22,
#          'of': 1351,
#          'legends': 24,
#          'page': 946,
#          'porn': 3781,
#          'comics': 99,
#          'free': 1874,
#          'online': 1011,
#          'р': 1248,
#          'одесса': 90,
#          'ростов': 136,
#          'на': 23049,
#          'дону': 251,
#          'сентября': 478,
#          'фаворит': 8,
#          'чп': 26,
#          'огэ': 31,
#          'математика': 187,
#          'функции': 37,
#          'задача': 39,
#          'fb': 487,
#          'ответ': 98,
#          'готов': 19,
#          'мировая': 22,
#          'экономика': 69,
#          'схемах': 4,
#          'таблицах': 5,
#          'млн': 904,
#          'результатов': 2703,
#          'поиск': 5310,
#          'mail': 6808,
#          'ru': 14234,
#          'кримпай': 1,
#          'мать': 70,
#          'сын': 67,
#          'страница': 5850,
#          'порно': 5217,
#          'мультики': 59,
#          'комиксы': 251,
#          'хентай': 128,
#          'бесплатно': 8243,
#          'мария': 134,
#          'шорох': 1,
#          'без': 1998,
#          'права': 111,
#          'выбора': 27,
#          'академия': 63,
#          'си': 269,
#          'читать': 3349,
#          'днепре': 53,
#          'нашли': 39,
#          'пропавшую': 2,
#          'летнюю': 20,
#          'девушку': 117,
#          'слава': 21,
#          'медяник': 1,
#          'стучат': 1,
#          'колёса': 29,
#          'инженерный': 5,
#          'институт': 74,
#          'казанского': 3,
#          'приволжского': 1,
#          'федерального': 24,
#          'университета': 22,
#          'учёба': 20,
#          'ру': 2170,
#          'каковы': 7,
#          'основные': 137,
#          'черты': 6,
#          'размещения': 417,
#          'отраслей': 6,
#          'топливной': 8,
#          'промышленности': 25,
#          'территорий': 7,
#          'россии': 1140,
#          'мужик': 87,
#          'поставил': 10,
#          'блондинку': 43,
#          'раком': 87,
#          'отодрал': 12,
#          'ее': 307,
#          'тугое': 1,
#          'очко': 42,
#          'видео': 5138,
#          'eropixel': 19,
#          'net': 981,
#          'портер': 7,
#          'джейн': 18,
#          'под': 575,
#          'звездным': 2,
#          'дождем': 3,
#          'скачать': 7751,
#          'книгу': 737,
#          'формате': 130,
#          'doc': 69,
#          'rtf': 68,
#          'html': 111,
#          'txt': 181,
#          'которое': 27,
#          'ты': 268,
#          'искал': 1,
#          'spaces': 94,
#          'spcs': 100,
#          'me': 547,
#          'услуга': 21,
#          'городской': 121,
#          'номер': 285,
#          'как': 3368,
#          'подключить': 32,
#          'мобильный': 106,
#          'билайн': 76,
#          'ульяновск': 49,
#          'murodbek': 2,
#          'qilichev': 1,
#          'bilmiram': 1,
#          'xorazm': 6,
#          'погода': 772,
#          'сочи': 182,
#          'сентябре': 33,
#          'тыс': 1825,
#          'gismeteo': 322,
#          'у': 1696,
#          'гостомел': 1,
#          'дн': 85,
#          'прогноз': 617,
#          'погоди': 82,
#          'рп': 23,
#          'нь': 8,
#          'ки': 130,
#          'вська': 50,
#          'область': 1063,
#          'укра': 381,
#          'службы': 94,
#          'поддержки': 36,
#          'моя': 410,
#          'учетная': 5,
#          'запись': 687,
#          'нальчик': 13,
#          'кожа': 75,
#          'волосы': 48,
#          'ногти': 12,
#          'результаты': 1171,
#          'поиска': 1042,
#          'форма': 122,
#          'наряда': 2,
#          'допуска': 4,
#          'производство': 132,
#          'работ': 126,
#          'местах': 16,
#          'действия': 83,
#          'опасных': 13,
#          'или': 1593,
#          'вредных': 3,
#          'факторов': 8,
#          'снип': 14,
#          'безопасность': 57,
#          'труда': 171,
#          'строительстве': 22,
#          'часть': 555,
#          'первая': 115,
#          'the': 2133,
#          'retuses': 1,
#          'ласточка': 9,
#          'аккорды': 108,
#          'текст': 546,
#          'mp': 3606,
#          'школьная': 41,
#          'солнце': 49,
#          'мод': 145,
#          'черного': 31,
#          'цвета': 124,
#          'цена': 3067,
#          'руб': 2299,
#          'гомеле': 48,
#          'deal': 113,
#          'by': 1060,
#          'id': 880,
#          'диалог': 22,
#          'встраив': 5,
#          'газовая': 40,
#          'панель': 73,
#          'hotpoint': 15,
#          'ariston': 17,
#          'tqg': 1,
#          'ha': 15,
#          'bk': 30,
#          'каталоге': 136,
#          'интернет': 3429,
#          'магазина': 217,
#          'м': 2812,
#          'по': 8465,
#          'выгодной': 205,
#          'цене': 999,
#          'с': 11643,
#          'доставкой': 570,
#          'фотографии': 1094,
#          'вел': 3,
#          'auto': 73,
#          'n': 1033,
#          'для': 10175,
#          'леденцов': 4,
#          'шоколада': 12,
#          'курочка': 5,
#          'ряба': 4,
#          'какой': 163,
#          'будет': 166,
#          'ноябре': 4,
#          'новости': 1291,
#          'казахстана': 68,
#          'tengrinews': 21,
#          'dio': 5,
#          'don': 38,
#          't': 677,
#          'talk': 12,
#          'to': 664,
#          'strangers': 7,
#          'irina': 18,
#          'gern': 1,
#          'tactical': 5,
#          'job': 49,
#          'shirt': 14,
#          'zip': 53,
#          'xxl': 21,
#          'fire': 19,
#          'navy': 12,
#          'lamnia': 10,
#          'ohm': 2,
#          'cs': 94,
#          'отзыв': 281,
#          'о': 3258,
#          'домкрат': 10,
#          'подкатной': 4,
#          'гидравлический': 9,
#          'ombra': 2,
#          'онт': 3,
#          'удобный': 13,
#          'но': 213,
#          'тяжелый': 8,
#          'лесбийский': 10,
#          'секс': 1284,
#          'кунилингусом': 5,
#          'двух': 106,
#          'стройных': 4,
#          'студенток': 7,
#          'высококачественное': 1,
#          'участием': 49,
#          'эмили': 6,
#          'блум': 4,
#          'презентация': 269,
#          'тему': 333,
#          'приближенное': 1,
#          'значение': 129,
#          'абсолютная': 3,
#          'относительная': 1,
#          'погрешнос': 1,
#          'горбачев': 2,
#          'октября': 184,
#          'намерен': 3,
#          'участвовать': 3,
#          'заседании': 3,
#          'иску': 2,
#          'жириновского': 2,
#          'политика': 85,
#          'тасс': 33,
#          'москва': 1599,
#          'марокко': 8,
#          'ночей': 79,
#          'гоша': 6,
#          'матарадзе': 1,
#          'два': 195,
#          'сердца': 60,
#          'dj': 160,
#          'movskii': 1,
#          'karasev': 1,
#          'remix': 147,
#          'слушать': 1768,
#          'миски': 5,
#          'салатники': 3,
#          'lesbians': 64,
#          'monique': 13,
#          'alexander': 27,
#          'and': 1724,
#          'violet': 14,
#          'starr': 19,
#          'fuck': 237,
#          'on': 755,
#          'table': 21,
#          'video': 1798,
#          'мельница': 13,
#          'крупорушка': 2,
#          'заводского': 2,
#          'изготовления': 19,
#          'квт': 37,
#          'срочно': 126,
#          'грн': 989,
#          'оборудование': 459,
#          'кременчуг': 13,
#          'olx': 1623,
#          'na': 177,
#          'avon': 28,
#          'scent': 2,
#          'essence': 25,
#          'lime': 10,
#          'verbena': 1,
#          'ни': 193,
#          'изюминки': 1,
#          'тебе': 71,
#          'лимончика': 1,
#          'обычная': 9,
#          'снять': 353,
#          'быстросъем': 1,
#          'печки': 26,
#          'фокус': 24,
#          'indian': 196,
#          'aunty': 31,
#          'bjowjob': 1,
#          'fucking': 155,
#          'with': 726,
#          'her': 489,
#          'partner': 27,
#          'indians': 8,
#          'get': 72,
#          'fucked': 185,
#          'sweet': 67,
#          'russian': 122,
#          'honey': 21,
#          'angelika': 7,
#          'got': 60,
#          'down': 58,
#          'dirty': 60,
#          'roommate': 6,
#          'because': 20,
#          'she': 79,
#          'was': 37,
#          'horny': 95,
#          'ipad': 74,
#          'at': 435,
#          'perfect': 577,
#          'girls': 731,
#          'маленькие': 50,
#          'характером': 2,
#          'частный': 46,
#          'детский': 236,
#          'сад': 163,
#          'центр': 529,
#          'хорошево': 1,
#          'мневниках': 1,
#          'playlist': 14,
#          'lesbian': 139,
#          'daftsex': 614,
#          'голых': 80,
#          'девочек': 250,
#          'бесплатная': 83,
#          'эротика': 389,
#          'topdevka': 2,
#          'com': 3073,
#          'эротические': 291,
#          'фильмы': 1073,
#          'малолетками': 2,
#          'dohera': 8,
#          'porno': 924,
#          'света': 84,
#          'оренбург': 52,
#          'оренбургская': 30,
#          'обл': 355,
#          'россия': 1670,
#          'лет': 1574,
#          'вакансии': 752,
#          'микролаб': 2,
#          'системс': 4,
#          'москве': 1597,
#          'работа': 1958,
#          'superjob': 130,
#          'ассасинавт': 1,
#          'торрент': 1570,
#          'хорошем': 1644,
#          'качестве': 1874,
#          'ведущий': 48,
#          'специалист': 128,
#          'закупкам': 6,
#          'дима': 17,
#          'билан': 4,
#          'снимется': 3,
#          'фильме': 65,
#          'андрея': 16,
#          'кончаловского': 1,
#          'русская': 286,
#          'наследница': 2,
#          'hd': 2672,
#          'беговую': 2,
#          'дорожку': 2,
#          'квартиру': 438,
#          'магазине': 1563,
#          'зона': 45,
#          'спорта': 96,
#          'профессия': 26,
#          'стыковщик': 1,
#          'текстиля': 6,
#          'прессе': 2,
#          'описание': 633,
#          'суть': 18,
#          'какая': 76,
#          'зарплата': 223,
#          'пейзаж': 20,
#          'пейзажные': 3,
#          'социальная': 152,
#          'сеть': 508,
#          'фотокто': 18,
#          'бишунму': 1,
#          'танцующие': 4,
#          'небесах': 3,
#          'dzen': 22,
#          'kino': 68,
#          'характеристика': 104,
#          'различных': 19,
#          'видов': 33,
#          'перевозки': 47,
#          'грузов': 39,
#          'буквы': 45,
#          'научно': 174,
#          'популярный': 21,
#          'портал': 511,
#          'script': 24,
#          'async': 1,
#          'custom': 17,
#          'element': 8,
#          'amp': 61,
#          'ads': 42,
#          'src': 2,
#          'https': 39,
#          'cdn': 2,
#          'ampproject': 1,
#          'org': 557,
#          'v': 876,
#          'js': 11,
#          'кольцо': 79,
#          'инкрустация': 1,
#          'цирконием': 1,
#          'позолота': 1,
#          'xuping': 2,
#          'продажа': 1992,
#          'ровно': 25,
#          'кольца': 63,
#          'перстни': 4,
#          'от': 5361,
#          'оптовый': 35,
#          'позолоченной': 1,
#          'бижутерии': 8,
#          'rv': 6,
#          'ua': 1166,
#          'судаке': 3,
#          'затонул': 1,
#          'прогулочный': 3,
#          'катер': 10,
#          'туристами': 2,
#          'одна': 69,
#          'пассажирка': 4,
#          'погибла': 5,
#          'яплакалъ': 174,
#          'общие': 50,
#          'положения': 33,
#          'консультантплюс': 114,
#          'фильм': 943,
#          'смешная': 2,
#          'девчонка': 13,
#          'полностью': 138,
#          'начало': 50,
#          'артек': 4,
#          'список': 352,
#          'актеров': 33,
#          'вокруг': 115,
#          'тв': 436,
#          'разбираем': 2,
#          'принтер': 25,
#          'l': 710,
#          'xp': 36,
#          'замятие': 1,
#          'бумаги': 58,
#          'аналогичные': 2,
#          'принтеры': 4,
#          'tubedoc': 2,
#          'воровайки': 6,
#          'мурки': 1,
#          'клип': 171,
#          'восход': 8,
#          'заход': 1,
#          'солнца': 77,
#          'астане': 39,
#          'блокування': 2,
#          'мосту': 13,
#          'метро': 271,
#          'кличко': 7,
#          'розпов': 16,
#          'що': 44,
#          'нувальник': 1,
#          'мав': 2,
#          'серйозн': 1,
#          'нам': 51,
#          'ри': 15,
#          'та': 229,
#          'перебував': 1,
#          'стан': 31,
#          'сп': 143,
#          'ян': 14,
#          'ння': 18,
#          'новини': 59,
#          'ва': 40,
#          'tch': 21,
#          'книга': 571,
#          'магия': 66,
#          'поцелуев': 4,
#          'мори': 4,
#          'триш': 5,
#          'литлайф': 5,
#          'книги': 811,
#          'полные': 20,
#          'мангу': 615,
#          'крутой': 17,
#          'учитель': 52,
#          'онидзука': 3,
#          'глава': 931,
#          'русском': 967,
#          'другом': 41,
#          'мире': 461,
#          'моё': 25,
#          'имя': 46,
#          'чёрный': 58,
#          'целитель': 12,
#          'кр': 40,
#          'улуттук': 2,
#          'банкынын': 1,
#          'нарын': 2,
#          'облустук': 1,
#          'башкармалыгынын': 1,
#          'филиалынын': 1,
#          'улук': 1,
#          'бухгалтери': 1,
#          'токтакунова': 1,
#          'кызматынан': 1,
#          'негизсиз': 1,
#          'четтетилген': 1,
#          'кабар': 3,
#          'кыргыз': 8,
#          'маалымат': 2,
#          'агенттиги': 1,
#          'candy': 33,
#          'make': 53,
#          'up': 195,
#          'lylagames': 2,
#          'изумрудные': 3,
#          'сказки': 88,
#          'эсми': 2,
#          'никс': 1,
#          'ямогу': 1,
#          'каталог': 834,
#          'мастеров': 179,
#          'авторов': 8,
#          'кукол': 109,
#          'игрушек': 38,
#          'кукольной': 1,
#          'одежды': 182,
#          'аксессуаров': 41,
#          'бэйбики': 71,
#          'куклы': 140,
#          'одежда': 617,
#          'кук': 4,
#          'рисовая': 12,
#          'каша': 20,
#          'воде': 20,
#          'рецепт': 510,
#          'горная': 4,
#          'болезнь': 25,
#          'супервайзер': 4,
#          'супервайзера': 1,
#          'увеличить': 22,
#          'объем': 30,
#          'продаж': 65,
#          'solaray': 2,
#          'cat': 51,
#          's': 1618,
#          'claw': 3,
#          'mg': 25,
#          'vegcaps': 1,
#          'iherb': 111,
#          'checkoutarrow': 5,
#          'mood': 9,
#          'curl': 2,
#          'wave': 8,
#          'натуральных': 12,
#          'волос': 190,
#          'вы': 314,
#          'назовете': 1,
#          'человека': 185,
#          'думающего': 1,
#          'других': 128,
#          'больше': 105,
#          'чем': 330,
#          'себе': 85,
#          'фильтр': 91,
#          'пол': 89,
#          'полы': 15,
#          'полов': 9,
#          'закупки': 93,
#          'этапе': 19,
#          'подача': 18,
#          'заявок': 15,
#          'пермь': 114,
#          'пермский': 46,
#          'край': 375,
#          'zq': 1,
#          'ф': 200,
#          'ромео': 11,
#          'обочины': 2,
#          'индия': 39,
#          'росфинмониторинг': 1,
#          'почта': 873,
#          'порошенко': 17,
#          'п': 608,
#          'дписав': 2,
#          'антирейдерський': 1,
#          'земельний': 1,
#          'закон': 101,
#          'нська': 36,
#          'правда': 91,
#          'морковные': 2,
#          'палочки': 10,
#          'государственный': 59,
#          'музей': 51,
#          'л': 973,
#          'толстого': 16,
#          'гмт': 1,
#          'элкос': 1,
#          'дизайн': 126,
#          'рамблер': 133,
#          'касса': 37,
#          'шикарная': 22,
#          'молодая': 93,
#          'женщина': 148,
#          'обнаженными': 4,
#          'сосками': 2,
#          'голые': 201,
#          'целующиеся': 4,
#          'девушки': 294,
#          'раздетые': 7,
#          'женщины': 191,
#          'со': 883,
#          'мной': 190,
#          'олеся': 33,
#          'швецова': 2,
#          'строительство': 114,
#          'коттеджей': 34,
#          'пенобетона': 5,
#          'ключ': 95,
#          'омскдом': 1,
#          'военная': 36,
#          'тематика': 6,
#          'форматах': 16,
#          'pdf': 346,
#          'бесплатн': 12,
#          'электронных': 38,
#          'компонентов': 14,
#          'электронщик': 3,
#          'радиодеталей': 4,
#          'измерительной': 1,
#          'техники': 144,
#          'светотехнических': 1,
#          'сушка': 9,
#          'дерева': 59,
#          'вакуумной': 3,
#          'камере': 3,
#          'guns': 45,
#          'talks': 47,
#          'picanto': 3,
#          'срок': 203,
#          'поставки': 26,
#          'киа': 73,
#          'пиканто': 1,
#          'субкомпактный': 1,
#          'автомобиль': 187,
#          'почтовый': 39,
#          'индекс': 56,
#          'улицы': 22,
#          'льва': 11,
#          'санкт': 1442,
#          'петербурга': 109,
#          'номерами': 34,
#          'домов': 187,
#          'indexmap': 2,
#          'комплект': 223,
#          'муравьиной': 1,
#          'фермы': 11,
#          'smart': 99,
#          'горный': 30,
#          'мох': 3,
#          'белгороде': 36,
#          'antfarms': 1,
#          'tinko': 1,
#          'h': 425,
#          'презентац': 14,
#          'я': 1313,
#          'сутн': 2,
#          'сть': 43,
#          'маркетингу': 12,
#          'його': 11,
#          'визначення': 4,
#          'марсель': 8,
#          'муратов': 3,
#          'казань': 122,
#          'татарстан': 56,
#          'года': 1695,
#          'charlie': 11,
#          'red': 127,
#          'anal': 622,
#          'администрация': 69,
#          'дк': 18,
#          'город': 432,
#          'холм': 6,
#          'челябинской': 27,
#          'области': 670,
#          'появится': 13,
#          'еще': 151,
#          'три': 157,
#          'виртуальных': 3,
#          'концертных': 2,
#          'зала': 33,
#          'анжелика': 26,
#          'агурбаш': 2,
#          'мне': 173,
#          'любви': 159,
#          'твоей': 14,
#          'мало': 18,
#          'музыка': 427,
#          'музыку': 688,
#          'песен': 165,
#          'песни': 803,
#          'необычные': 30,
#          'рецепты': 268,
#          'вкусные': 47,
#          'идеи': 104,
#          'каждый': 113,
#          'день': 545,
#          'девчат': 3,
#          'радостью': 5,
#          'бы': 87,
#          'пописали': 1,
#          'таких': 9,
#          'туалетах': 1,
#          'сообщение': 79,
#          'гостиница': 59,
#          'авс': 5,
#          'отель': 268,
#          'свердловская': 67,
#          'екатеринбург': 290,
#          'кронштейн': 19,
#          'наклонно': 4,
#          'поворотный': 10,
#          'vogel': 1,
#          'thin': 3,
#          'black': 585,
#          'фотогра': 2,
#          'flora': 5,
#          'gucci': 7,
#          'ml': 62,
#          'al': 88,
#          'rayan': 1,
#          'технические': 113,
#          'функциональные': 2,
#          'возможности': 30,
#          'интерактивной': 1,
#          'доски': 20,
#          'тема': 386,
#          'научной': 279,
#          'статьи': 490,
#          'общим': 12,
#          'комплексным': 10,
#          'проблемам': 11,
#          'естественных': 6,
#          'точн': 1,
#          'знакомства': 709,
#          'обмен': 211,
#          'интим': 56,
#          'регистрации': 906,
#          'смс': 131,
#          'jebug': 1,
#          'obok': 2,
#          'susu': 2,
#          'подскажите': 41,
#          'ваши': 43,
#          'дети': 179,
#          'написали': 1,
#          'централизованную': 1,
#          'работу': 102,
#          'геометрии': 26,
#          'которая': 53,
#          'была': 55,
#          'наш': 71,
#          'класс': 1412,
#          'походу': 3,
#          'очень': 225,
#          'teenfidelity': 2,
#          'tf': 8,
#          'real': 98,
#          'life': 184,
#          'ryan': 28,
#          'madison': 16,
#          'jennifer': 25,
#          'bliss': 6,
#          'small': 63,
#          'tits': 428,
#          'porntube': 18,
#          'millie': 2,
#          'азарова': 3,
#          'английский': 144,
#          'язык': 318,
#          'младшей': 28,
#          'школы': 166,
#          'беслатно': 1,
#          'учебники': 54,
#          'тетради': 6,
#          'аудио': 44,
#          'карточки': 30,
#          'всех': 209,
#          'классов': 37,
#          'ребенка': 232,
#          'красные': 29,
#          'глаза': 50,
#          'гноятся': 1,
#          'гной': 1,
#          'урале': 9,
#          'играют': 16,
#          'кёрлинг': 1,
#          'автомобилями': 2,
#          'ока': 12,
#          'моем': 356,
#          'олег': 87,
#          'фролов': 1,
#          'оригинал': 93,
#          'библиотека': 415,
#          'книг': 322,
#          'игры': 790,
#          'ps': 98,
#          'бархатцы': 2,
#          'махровые': 7,
#          'гиганты': 5,
#          'гр': 91,
#          'цп': 8,
#          'семена': 56,
#          'алтая': 5,
#          'arilara': 1,
#          'soyle': 1,
#          'trsub': 2,
#          'filmizlevip': 2,
#          'ahmet': 7,
#          'bulut': 4,
#          'собаки': 70,
#          'поездах': 3,
#          'укрзализныця': 2,
#          'объяснила': 4,
#          'правила': 151,
#          'животных': 89,
#          'сегодня': 516,
#          'жанра': 66,
#          'комедия': 34,
#          'реклама': 100,
#          'ленинский': 34,
#          'район': 702,
#          'состоится': 14,
#          'очередное': 2,
#          'заседание': 9,
#          'комиссии': 18,
#          'профилактике': 4,
#          'правонарушений': 5,
#          'побег': 28,
#          'лос': 12,
#          'анджелеса': 5,
#          'mixmuz': 62,
#          'таинственный': 3,
#          'лес': 65,
#          'тайна': 49,
#          'покрытая': 2,
#          'мраком': 1,
#          'танцевальный': 2,
#          'клуб': 388,
#          'импульс': 4,
#          'детей': 501,
#          'винкс': 20,
#          'обратно': 36,
#          'средние': 16,
#          'века': 71,
#          'русский': 476,
#          'никелодеон': 2,
#          'против': 196,
#          'язвы': 3,
#          'большой': 352,
#          'шар': 22,
#          'куклами': 1,
#          'lol': 8,
#          'краснодаре': 239,
#          'дата': 489,
#          'игрушки': 190,
#          'answear': 21,
#          'женской': 32,
#          'мужской': 100,
#          'детской': 60,
#          'обуви': 64,
#          'доставка': 399,
#          'за': 2216,
#          'дня': 187,
#          'отправка': 21,
#          'заказа': 81,
#          'соликамск': 9,
#          'база': 717,
#          'данных': 71,
#          'недвижимости': 93,
#          'соликамска': 1,
#          'сайт': 1266,
#          'объявлений': 418,
#          'продаже': 143,
#          ...})

# %% [markdown]
# ### Загрузка стоп-слов

# %%
from nltk.corpus import stopwords as stopwrds
stopwrds.fileids()
# Out:
# ['arabic',
#  'azerbaijani',
#  'basque',
#  'bengali',
#  'catalan',
#  'chinese',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hebrew',
#  'hinglish',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'turkish']

# %%
nltk.corpus.stopwords.words('turkish')
# Out:
# ['acaba',
#  'ama',
#  'aslında',
#  'az',
#  'bazı',
#  'belki',
#  'biri',
#  'birkaç',
#  'birşey',
#  'biz',
#  'bu',
#  'çok',
#  'çünkü',
#  'da',
#  'daha',
#  'de',
#  'defa',
#  'diye',
#  'eğer',
#  'en',
#  'gibi',
#  'hem',
#  'hep',
#  'hepsi',
#  'her',
#  'hiç',
#  'için',
#  'ile',
#  'ise',
#  'kez',
#  'ki',
#  'kim',
#  'mı',
#  'mu',
#  'mü',
#  'nasıl',
#  'ne',
#  'neden',
#  'nerde',
#  'nerede',
#  'nereye',
#  'niçin',
#  'niye',
#  'o',
#  'sanki',
#  'şey',
#  'siz',
#  'şu',
#  'tüm',
#  've',
#  'veya',
#  'ya',
#  'yani']

# %%
stopwords = []
for language in ['russian', 'english', 'portuguese', 'spanish', 'tajik', 'turkish']:
    stopwords += nltk.corpus.stopwords.words(language)
stopwords
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между',
#  'i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hão',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houverá',
#  'houveram',
#  'houvéramos',
#  'houverão',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveríamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvéssemos',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'não',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nós',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'são',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'será',
#  'serão',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seríamos',
#  'seu',
#  'seus',
#  'só',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'também',
#  'te',
#  'tem',
#  'tém',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terá',
#  'terão',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tínhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tivéramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos',
#  'de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
#  'vosotras',
#  'os',
#  'mío',
#  'mía',
#  'míos',
#  'mías',
#  'tuyo',
#  'tuya',
#  'tuyos',
#  'tuyas',
#  'suyo',
#  'suya',
#  'suyos',
#  'suyas',
#  'nuestro',
#  'nuestra',
#  'nuestros',
#  'nuestras',
#  'vuestro',
#  'vuestra',
#  'vuestros',
#  'vuestras',
#  'esos',
#  'esas',
#  'estoy',
#  'estás',
#  'está',
#  'estamos',
#  'estáis',
#  'están',
#  'esté',
#  'estés',
#  'estemos',
#  'estéis',
#  'estén',
#  'estaré',
#  'estarás',
#  'estará',
#  'estaremos',
#  'estaréis',
#  'estarán',
#  'estaría',
#  'estarías',
#  'estaríamos',
#  'estaríais',
#  'estarían',
#  'estaba',
#  'estabas',
#  'estábamos',
#  'estabais',
#  'estaban',
#  'estuve',
#  'estuviste',
#  'estuvo',
#  'estuvimos',
#  'estuvisteis',
#  'estuvieron',
#  'estuviera',
#  'estuvieras',
#  'estuviéramos',
#  'estuvierais',
#  'estuvieran',
#  'estuviese',
#  'estuvieses',
#  'estuviésemos',
#  'estuvieseis',
#  'estuviesen',
#  'estando',
#  'estado',
#  'estada',
#  'estados',
#  'estadas',
#  'estad',
#  'he',
#  'has',
#  'ha',
#  'hemos',
#  'habéis',
#  'han',
#  'haya',
#  'hayas',
#  'hayamos',
#  'hayáis',
#  'hayan',
#  'habré',
#  'habrás',
#  'habrá',
#  'habremos',
#  'habréis',
#  'habrán',
#  'habría',
#  'habrías',
#  'habríamos',
#  'habríais',
#  'habrían',
#  'había',
#  'habías',
#  'habíamos',
#  'habíais',
#  'habían',
#  'hube',
#  'hubiste',
#  'hubo',
#  'hubimos',
#  'hubisteis',
#  'hubieron',
#  'hubiera',
#  'hubieras',
#  'hubiéramos',
#  'hubierais',
#  'hubieran',
#  'hubiese',
#  'hubieses',
#  'hubiésemos',
#  'hubieseis',
#  'hubiesen',
#  'habiendo',
#  'habido',
#  'habida',
#  'habidos',
#  'habidas',
#  'soy',
#  'eres',
#  'es',
#  'somos',
#  'sois',
#  'son',
#  'sea',
#  'seas',
#  'seamos',
#  'seáis',
#  'sean',
#  'seré',
#  'serás',
#  'será',
#  'seremos',
#  'seréis',
#  'serán',
#  'sería',
#  'serías',
#  'seríamos',
#  'seríais',
#  'serían',
#  'era',
#  'eras',
#  'éramos',
#  'erais',
#  'eran',
#  'fui',
#  'fuiste',
#  'fue',
#  'fuimos',
#  'fuisteis',
#  'fueron',
#  'fuera',
#  'fueras',
#  'fuéramos',
#  'fuerais',
#  'fueran',
#  'fuese',
#  'fueses',
#  'fuésemos',
#  'fueseis',
#  'fuesen',
#  'sintiendo',
#  'sentido',
#  'sentida',
#  'sentidos',
#  'sentidas',
#  'siente',
#  'sentid',
#  'tengo',
#  'tienes',
#  'tiene',
#  'tenemos',
#  'tenéis',
#  'tienen',
#  'tenga',
#  'tengas',
#  'tengamos',
#  'tengáis',
#  'tengan',
#  'tendré',
#  'tendrás',
#  'tendrá',
#  'tendremos',
#  'tendréis',
#  'tendrán',
#  'tendría',
#  'tendrías',
#  'tendríamos',
#  'tendríais',
#  'tendrían',
#  'tenía',
#  'tenías',
#  'teníamos',
#  'teníais',
#  'tenían',
#  'tuve',
#  'tuviste',
#  'tuvo',
#  'tuvimos',
#  'tuvisteis',
#  'tuvieron',
#  'tuviera',
#  'tuvieras',
#  'tuviéramos',
#  'tuvierais',
#  'tuvieran',
#  'tuviese',
#  'tuvieses',
#  'tuviésemos',
#  'tuvieseis',
#  'tuviesen',
#  'teniendo',
#  'tenido',
#  'tenida',
#  'tenidos',
#  'tenidas',
#  'tened',
#  'аз',
#  'дар',
#  'ба',
#  'бо',
#  'барои',
#  'бе',
#  'то',
#  'ҷуз',
#  'пеши',
#  'назди',
#  'рӯйи',
#  'болои ',
#  'паси',
#  'ғайри',
#  'ҳамон',
#  'ҳамоно',
#  'инҷониб',
#  'замон',
#  'замоно',
#  'эътиборан',
#  'пеш',
#  'қабл',
#  'дида',
#  'сар карда',
#  'агар ',
#  'агар ки',
#  'валекин ',
#  'ки',
#  'лекин',
#  'аммо',
#  'вале',
#  'балки',
#  'ва',
#  'ҳарчанд',
#  'чунки',
#  'зеро',
#  'зеро ки',
#  'вақте ки',
#  'то вақте ки',
#  'барои он ки',
#  'бо нияти он ки',
#  'лекин ва ҳол он ки',
#  'ё',
#  'ё ин ки  ',
#  'бе он ки ',
#  'дар ҳолате ки',
#  'то даме ки ',
#  'баъд аз он ки',
#  'даме ки',
#  'ба тразе ки ',
#  'аз баҳри он ки',
#  'гар ',
#  'ар',
#  'ба шарте',
#  'азбаски ',
#  'модоме ки',
#  'агар чи',
#  'гарчанде ки ',
#  'бо вуҷуди он ки',
#  'гӯё',
#  'аз-баски ',
#  'чун-ки',
#  'агар-чанд',
#  'агар-чи ',
#  'гар-чи',
#  'то ки',
#  'чунон ки',
#  'то даме ки',
#  'ҳар қадар ки',
#  'магар ',
#  'оё',
#  'наход',
#  'ҳатто ',
#  'ҳам ',
#  'бале ',
#  'оре ',
#  'хуб ',
#  'хуш',
#  'хайр',
#  'не',
#  'на',
#  'мана',
#  'э',
#  'фақат',
#  'танҳо',
#  'кошки ',
#  'мабодо',
#  'ҳтимол',
#  'ана ҳамин',
#  'наход ки',
#  'ҳатто ки',
#  'аз афташ',
#  'майлаш куя',
#  'ана',
#  'ҳа',
#  'канӣ',
#  'гӯё ки',
#  'ҳо ана',
#  'на ин ки',
#  'ваҳ',
#  'ҳой',
#  'и',
#  'а',
#  'о',
#  'эҳ',
#  'ҳе',
#  'ҳу',
#  'аҳа',
#  'оҳе',
#  'уҳа',
#  'ҳм',
#  'нм',
#  'оббо',
#  'ӯббо',
#  'ҳой-ҳой ',
#  'вой-вой',
#  'ту-ту',
#  'ҳмм',
#  'эҳа',
#  'тавба',
#  'ӯҳӯ',
#  'аҷабо',
#  'ало',
#  'аё',
#  'ой',
#  'ӯим ',
#  'ором',
#  'хом?ш',
#  'ҳай-ҳай ',
#  'бай-бай',
#  'аз ',
#  'он',
#  'баъд',
#  'азбаски',
#  'ӯ',
#  'ҳангоми',
#  'чӣ',
#  'кадом',
#  'ин',
#  'ҷо',
#  'ҳам',
#  'ё ки',
#  'бояд',
#  'аст',
#  'чанд',
#  'ҳар',
#  'бар',
#  'чаро ки',
#  'агар',
#  'то кӣ',
#  ...]

# %% [markdown]
# ### Лемматизация

# %%
lemmatizer = pymorphy2.MorphAnalyzer()

# %%
lemmatizer_cache = {}

def lemmatize(token):
    if lemmatizer.word_is_known(token):
        if token not in lemmatizer_cache:
            lemmatizer_cache[token] = lemmatizer.parse(token)[0].normal_form
        return lemmatizer_cache[token]
    return token

lemmatized_docs = [[lemmatize(token) for token in text] for text in tqdm_notebook(docs_title)]

cleared_docs = [[token for token in text if token not in stopwords] for text in tqdm_notebook(lemmatized_docs)]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6012\2321608028.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   lemmatized_docs = [[lemmatize(token) for token in text] for text in tqdm_notebook(docs_title)]
#   0%|          | 0/135309 [00:00<?, ?it/s]
# C:\Users\User\AppData\Local\Temp\ipykernel_6012\2321608028.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   cleared_docs = [[token for token in text if token not in stopwords] for text in tqdm_notebook(lemmatized_docs)]
#   0%|          | 0/135309 [00:00<?, ?it/s]

# %%
docs_title
# Out:
# [['экс',
#   'министр',
#   'экономики',
#   'молдовы',
#   'главе',
#   'мидэи',
#   'цель',
#   'которого',
#   'сделать',
#   'из',
#   'республики',
#   'не',
#   'просителя',
#   'а',
#   'донора',
#   'надо',
#   'избегать',
#   'долгого',
#   'нахождения',
#   'н'],
#  ['эта',
#   'песня',
#   'стала',
#   'известна',
#   'многим',
#   'телезрителям',
#   'благодаря',
#   'сериалу',
#   'диверсант'],
#  ['банши', 'сезон', 'серия', 'бремя', 'красоты', 'смотреть', 'онлайн'],
#  ['не', 'беси', 'меня', 'картинки'],
#  ['в',
#   'новомосковске',
#   'сыграют',
#   'следж',
#   'хоккеисты',
#   'алексинской',
#   'звезды',
#   'и',
#   'сборной',
#   'китая',
#   'т'],
#  ['салат',
#   'корейская',
#   'морковь',
#   'копченая',
#   'курица',
#   'кукуруза',
#   'сухарики',
#   'мой',
#   'калорийность',
#   'белки',
#   'жиры',
#   'углеводы'],
#  ['угловой',
#   'пневмогайковерт',
#   'fubag',
#   'rwc',
#   'в',
#   'екатеринбурге',
#   'купить',
#   'цены',
#   'отзывы',
#   'характеристики',
#   'фото',
#   'инструкция'],
#  ['табачный',
#   'магазин',
#   'мир',
#   'табака',
#   'курительные',
#   'трубки',
#   'stanwell',
#   'курительная',
#   'труб'],
#  ['league', 'of', 'legends', 'page', 'porn', 'comics', 'free', 'online'],
#  ['р', 'одесса', 'ростов', 'на', 'дону', 'сентября', 'фаворит', 'чп'],
#  ['огэ', 'математика', 'функции', 'задача', 'fb', 'ответ', 'готов'],
#  ['мировая',
#   'экономика',
#   'в',
#   'схемах',
#   'и',
#   'таблицах',
#   'млн',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['кримпай',
#   'мать',
#   'и',
#   'сын',
#   'страница',
#   'смотреть',
#   'порно',
#   'мультики',
#   'порно',
#   'комиксы',
#   'хентай',
#   'онлайн',
#   'бесплатно'],
#  ['мария',
#   'шорох',
#   'без',
#   'права',
#   'выбора',
#   'академия',
#   'си',
#   'читать',
#   'онлайн'],
#  ['в', 'днепре', 'нашли', 'пропавшую', 'летнюю', 'девушку'],
#  ['мой', 'мир', 'mail', 'ru'],
#  ['слава', 'медяник', 'стучат', 'колёса'],
#  ['инженерный',
#   'институт',
#   'казанского',
#   'приволжского',
#   'федерального',
#   'университета',
#   'учёба',
#   'ру'],
#  ['каковы',
#   'основные',
#   'черты',
#   'размещения',
#   'отраслей',
#   'топливной',
#   'промышленности',
#   'на',
#   'территорий',
#   'россии',
#   'млн',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['мужик',
#   'поставил',
#   'блондинку',
#   'раком',
#   'и',
#   'отодрал',
#   'ее',
#   'тугое',
#   'очко',
#   'порно',
#   'видео',
#   'на',
#   'eropixel',
#   'net'],
#  ['портер',
#   'джейн',
#   'под',
#   'звездным',
#   'дождем',
#   'скачать',
#   'бесплатно',
#   'книгу',
#   'в',
#   'формате',
#   'fb',
#   'doc',
#   'rtf',
#   'html',
#   'txt'],
#  ['порно', 'которое', 'ты', 'искал', 'видео', 'spaces', 'ru', 'spcs', 'me'],
#  ['услуга',
#   'городской',
#   'номер',
#   'как',
#   'подключить',
#   'мобильный',
#   'билайн',
#   'ульяновск'],
#  ['murodbek', 'qilichev', 'bilmiram', 'xorazm', 'net'],
#  ['погода',
#   'в',
#   'сочи',
#   'в',
#   'сентябре',
#   'тыс',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['gismeteo',
#   'погода',
#   'у',
#   'гостомел',
#   'на',
#   'дн',
#   'в',
#   'прогноз',
#   'погоди',
#   'на',
#   'дн',
#   'в',
#   'рп',
#   'нь',
#   'ки',
#   'вська',
#   'область',
#   'укра',
#   'на'],
#  ['службы', 'поддержки'],
#  ['моя', 'учетная', 'запись', 'нальчик'],
#  ['кожа', 'волосы', 'ногти', 'результаты', 'поиска'],
#  ['форма',
#   'наряда',
#   'допуска',
#   'на',
#   'производство',
#   'работ',
#   'в',
#   'местах',
#   'действия',
#   'опасных',
#   'или',
#   'вредных',
#   'факторов',
#   'снип',
#   'безопасность',
#   'труда',
#   'в',
#   'строительстве',
#   'часть',
#   'первая'],
#  ['the', 'retuses', 'ласточка', 'аккорды', 'текст', 'mp', 'видео'],
#  ['школьная',
#   'форма',
#   'солнце',
#   'мод',
#   'черного',
#   'цвета',
#   'цена',
#   'руб',
#   'купить',
#   'в',
#   'гомеле',
#   'deal',
#   'by',
#   'id'],
#  ['диалог'],
#  ['купить',
#   'встраив',
#   'газовая',
#   'панель',
#   'hotpoint',
#   'ariston',
#   'tqg',
#   'ha',
#   'bk',
#   'в',
#   'каталоге',
#   'интернет',
#   'магазина',
#   'м',
#   'видео',
#   'по',
#   'выгодной',
#   'цене',
#   'с',
#   'доставкой',
#   'отзывы',
#   'фотографии',
#   'вел'],
#  ['auto', 'n'],
#  ['форма', 'для', 'леденцов', 'и', 'шоколада', 'курочка', 'ряба', 'купить'],
#  ['какой',
#   'будет',
#   'погода',
#   'в',
#   'ноябре',
#   'новости',
#   'казахстана',
#   'tengrinews'],
#  ['видео',
#   'dio',
#   'don',
#   't',
#   'talk',
#   'to',
#   'strangers',
#   'irina',
#   'gern',
#   'видео',
#   'mail',
#   'ru'],
#  ['tactical', 'job', 'shirt', 'zip', 'xxl', 'fire', 'navy', 'lamnia'],
#  ['ohm', 'cs'],
#  ['отзыв',
#   'о',
#   'домкрат',
#   'подкатной',
#   'гидравлический',
#   'ombra',
#   'онт',
#   'удобный',
#   'но',
#   'тяжелый',
#   'домкрат'],
#  ['лесбийский',
#   'секс',
#   'с',
#   'кунилингусом',
#   'двух',
#   'стройных',
#   'студенток',
#   'высококачественное',
#   'порно',
#   'видео',
#   'с',
#   'участием',
#   'эмили',
#   'блум'],
#  ['презентация',
#   'на',
#   'тему',
#   'приближенное',
#   'значение',
#   'абсолютная',
#   'и',
#   'относительная',
#   'погрешнос'],
#  ['горбачев',
#   'октября',
#   'намерен',
#   'участвовать',
#   'в',
#   'заседании',
#   'по',
#   'иску',
#   'жириновского',
#   'политика',
#   'тасс'],
#  ['москва', 'марокко', 'на', 'ночей', 'руб'],
#  ['гоша',
#   'матарадзе',
#   'два',
#   'сердца',
#   'dj',
#   'movskii',
#   'dj',
#   'karasev',
#   'remix',
#   'слушать',
#   'бесплатно',
#   'онлайн'],
#  ['миски', 'салатники', 'страница'],
#  ['lesbians',
#   'monique',
#   'alexander',
#   'and',
#   'violet',
#   'starr',
#   'fuck',
#   'on',
#   'the',
#   'table',
#   'porn',
#   'video'],
#  ['мельница',
#   'крупорушка',
#   'заводского',
#   'изготовления',
#   'квт',
#   'в',
#   'срочно',
#   'грн',
#   'оборудование',
#   'кременчуг',
#   'на',
#   'olx'],
#  ['na'],
#  ['avon',
#   'scent',
#   'essence',
#   'lime',
#   'verbena',
#   'ни',
#   'изюминки',
#   'тебе',
#   'ни',
#   'лимончика',
#   'обычная',
#   'и'],
#  ['как',
#   'снять',
#   'быстросъем',
#   'с',
#   'печки',
#   'фокус',
#   'тыс',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['indian',
#   'aunty',
#   'bjowjob',
#   'and',
#   'fucking',
#   'with',
#   'her',
#   'partner',
#   'indians',
#   'get',
#   'fucked'],
#  ['sweet',
#   'russian',
#   'honey',
#   'angelika',
#   'got',
#   'down',
#   'and',
#   'dirty',
#   'with',
#   'her',
#   'roommate',
#   'because',
#   'she',
#   'was',
#   'horny',
#   'ipad',
#   'porn',
#   'at',
#   'perfect',
#   'girls'],
#  ['маленькие',
#   'с',
#   'характером',
#   'частный',
#   'детский',
#   'сад',
#   'детский',
#   'центр',
#   'в',
#   'хорошево',
#   'мневниках'],
#  ['playlist', 'lesbian', 'daftsex'],
#  ['фото',
#   'голых',
#   'девочек',
#   'и',
#   'бесплатная',
#   'эротика',
#   'на',
#   'topdevka',
#   'com'],
#  ['порно',
#   'видео',
#   'эротические',
#   'фильмы',
#   'с',
#   'малолетками',
#   'на',
#   'dohera',
#   'porno',
#   'net'],
#  ['света',
#   'света',
#   'оренбург',
#   'оренбургская',
#   'обл',
#   'россия',
#   'лет',
#   'на',
#   'мой',
#   'мир',
#   'mail',
#   'ru'],
#  ['вакансии',
#   'микролаб',
#   'системс',
#   'в',
#   'москве',
#   'работа',
#   'в',
#   'микролаб',
#   'системс',
#   'на',
#   'superjob'],
#  ['ассасинавт', 'скачать', 'торрент', 'в', 'хорошем', 'качестве'],
#  ['ведущий', 'специалист', 'по', 'закупкам'],
#  ['дима', 'билан', 'снимется', 'в', 'фильме', 'андрея', 'кончаловского'],
#  ['русская',
#   'наследница',
#   'сезон',
#   'смотреть',
#   'онлайн',
#   'в',
#   'хорошем',
#   'качестве',
#   'hd'],
#  ['купить',
#   'беговую',
#   'дорожку',
#   'в',
#   'квартиру',
#   'в',
#   'интернет',
#   'магазине',
#   'зона',
#   'спорта',
#   'интернет',
#   'м'],
#  ['профессия',
#   'стыковщик',
#   'текстиля',
#   'на',
#   'прессе',
#   'описание',
#   'суть',
#   'какая',
#   'зарплата'],
#  ['фото',
#   'пейзаж',
#   'пейзажные',
#   'фотографии',
#   'страница',
#   'социальная',
#   'сеть',
#   'фотокто'],
#  ['бишунму',
#   'танцующие',
#   'в',
#   'небесах',
#   'серия',
#   'сезон',
#   'смотреть',
#   'онлайн',
#   'dzen',
#   'kino'],
#  ['характеристика',
#   'различных',
#   'видов',
#   'перевозки',
#   'грузов',
#   'буквы',
#   'ру',
#   'научно',
#   'популярный',
#   'портал',
#   'script',
#   'async',
#   'custom',
#   'element',
#   'amp',
#   'auto',
#   'ads',
#   'src',
#   'https',
#   'cdn',
#   'ampproject',
#   'org',
#   'v',
#   'amp',
#   'auto',
#   'ads',
#   'js'],
#  ['кольцо',
#   'в',
#   'инкрустация',
#   'цирконием',
#   'р',
#   'р',
#   'р',
#   'позолота',
#   'xuping',
#   'продажа',
#   'цена',
#   'в',
#   'ровно',
#   'кольца',
#   'и',
#   'перстни',
#   'от',
#   'оптовый',
#   'интернет',
#   'магазин',
#   'позолоченной',
#   'бижутерии',
#   'xuping',
#   'rv',
#   'ua'],
#  ['в',
#   'судаке',
#   'затонул',
#   'прогулочный',
#   'катер',
#   'с',
#   'туристами',
#   'одна',
#   'пассажирка',
#   'погибла',
#   'яплакалъ'],
#  ['общие', 'положения', 'консультантплюс'],
#  ['фильм',
#   'смешная',
#   'девчонка',
#   'смотреть',
#   'онлайн',
#   'полностью',
#   'в',
#   'hd',
#   'качестве',
#   'бесплатно'],
#  ['начало', 'смотреть', 'онлайн', 'бесплатно', 'в', 'хорошем', 'качестве'],
#  ['фильм', 'артек', 'фото', 'видео', 'список', 'актеров', 'вокруг', 'тв'],
#  ['разбираем',
#   'принтер',
#   'l',
#   'l',
#   'xp',
#   'xp',
#   'замятие',
#   'бумаги',
#   'и',
#   'аналогичные',
#   'принтеры',
#   'смотреть',
#   'видео',
#   'онлайн',
#   'tubedoc',
#   'ru'],
#  ['воровайки', 'мурки', 'воровайки', 'клип', 'смотреть', 'онлайн'],
#  ['восход',
#   'и',
#   'заход',
#   'солнца',
#   'в',
#   'астане',
#   'тыс',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['блокування',
#   'мосту',
#   'метро',
#   'кличко',
#   'розпов',
#   'в',
#   'що',
#   'м',
#   'нувальник',
#   'мав',
#   'серйозн',
#   'нам',
#   'ри',
#   'та',
#   'перебував',
#   'у',
#   'стан',
#   'сп',
#   'ян',
#   'ння',
#   'новини',
#   'ки',
#   'ва',
#   'ки',
#   'в',
#   'tch',
#   'ua'],
#  ['книга',
#   'магия',
#   'поцелуев',
#   'мори',
#   'триш',
#   'литлайф',
#   'книги',
#   'читать',
#   'онлайн',
#   'скачать',
#   'бесплатно',
#   'полные',
#   'книги'],
#  ['читать',
#   'мангу',
#   'крутой',
#   'учитель',
#   'онидзука',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['читать',
#   'мангу',
#   'в',
#   'другом',
#   'мире',
#   'моё',
#   'имя',
#   'чёрный',
#   'целитель',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['кр',
#   'улуттук',
#   'банкынын',
#   'нарын',
#   'облустук',
#   'башкармалыгынын',
#   'филиалынын',
#   'улук',
#   'бухгалтери',
#   'а',
#   'токтакунова',
#   'кызматынан',
#   'негизсиз',
#   'четтетилген',
#   'кабар',
#   'кыргыз',
#   'улуттук',
#   'маалымат',
#   'агенттиги'],
#  ['candy', 'perfect', 'make', 'up', 'on', 'lylagames'],
#  ['изумрудные',
#   'сказки',
#   'эсми',
#   'никс',
#   'ямогу',
#   'каталог',
#   'мастеров',
#   'и',
#   'авторов',
#   'кукол',
#   'игрушек',
#   'кукольной',
#   'одежды',
#   'и',
#   'аксессуаров',
#   'бэйбики',
#   'куклы',
#   'фото',
#   'одежда',
#   'для',
#   'кук'],
#  ['рисовая', 'каша', 'на', 'воде', 'рецепт', 'с', 'фото'],
#  ['горная', 'болезнь'],
#  ['супервайзер',
#   'книга',
#   'супервайзера',
#   'как',
#   'увеличить',
#   'объем',
#   'продаж'],
#  ['solaray',
#   'cat',
#   's',
#   'claw',
#   'mg',
#   'vegcaps',
#   'iherb',
#   'com',
#   'checkoutarrow',
#   'checkoutarrow'],
#  ['mood', 'curl', 'wave', 'для', 'натуральных', 'волос', 'mood'],
#  ['как',
#   'вы',
#   'назовете',
#   'человека',
#   'думающего',
#   'о',
#   'других',
#   'больше',
#   'чем',
#   'о',
#   'себе'],
#  ['фильтр', 'страница'],
#  ['пол',
#   'полы',
#   'полов',
#   'закупки',
#   'на',
#   'этапе',
#   'подача',
#   'заявок',
#   'пермь',
#   'пермский',
#   'край',
#   'пермский',
#   'р',
#   'н'],
#  ['zq', 'м', 'ф', 'ромео', 'с', 'обочины', 'индия', 'mp'],
#  ['росфинмониторинг', 'почта', 'mail', 'ru'],
#  ['порошенко',
#   'п',
#   'дписав',
#   'антирейдерський',
#   'земельний',
#   'закон',
#   'укра',
#   'нська',
#   'правда'],
#  ['морковные', 'палочки'],
#  ['государственный', 'музей', 'л', 'н', 'толстого', 'гмт', 'элкос', 'дизайн'],
#  ['рамблер', 'касса'],
#  ['шикарная',
#   'молодая',
#   'женщина',
#   'с',
#   'обнаженными',
#   'сосками',
#   'эротика',
#   'фото',
#   'и',
#   'голые',
#   'целующиеся',
#   'девушки',
#   'раздетые',
#   'женщины'],
#  ['фото', 'со', 'мной', 'фото', 'фотографии', 'олеся', 'швецова'],
#  ['строительство', 'коттеджей', 'из', 'пенобетона', 'под', 'ключ', 'омскдом'],
#  ['военная',
#   'тематика',
#   'страница',
#   'скачать',
#   'книги',
#   'в',
#   'форматах',
#   'txt',
#   'fb',
#   'pdf',
#   'бесплатн'],
#  ['магазин',
#   'электронных',
#   'компонентов',
#   'электронщик',
#   'продажа',
#   'электронных',
#   'компонентов',
#   'радиодеталей',
#   'измерительной',
#   'техники',
#   'светотехнических',
#   'и'],
#  ['сушка', 'дерева', 'в', 'вакуумной', 'камере', 'guns', 'ru', 'talks'],
#  ['picanto',
#   'срок',
#   'поставки',
#   'киа',
#   'пиканто',
#   'субкомпактный',
#   'автомобиль'],
#  ['почтовый',
#   'индекс',
#   'улицы',
#   'льва',
#   'толстого',
#   'санкт',
#   'петербурга',
#   'с',
#   'номерами',
#   'домов',
#   'indexmap',
#   'ru'],
#  ['комплект',
#   'муравьиной',
#   'фермы',
#   'smart',
#   'горный',
#   'мох',
#   'купить',
#   'в',
#   'белгороде',
#   'в',
#   'интернет',
#   'магазине',
#   'antfarms',
#   'ru'],
#  ['tinko', 'h'],
#  ['презентац', 'я', 'сутн', 'сть', 'маркетингу', 'та', 'його', 'визначення'],
#  ['марсель',
#   'муратов',
#   'казань',
#   'татарстан',
#   'россия',
#   'года',
#   'на',
#   'мой',
#   'мир',
#   'mail',
#   'ru'],
#  ['charlie', 'red', 'anal', 'daftsex'],
#  ['администрация', 'дк'],
#  ['город', 'холм'],
#  ['в',
#   'челябинской',
#   'области',
#   'появится',
#   'еще',
#   'три',
#   'виртуальных',
#   'концертных',
#   'зала'],
#  ['анжелика',
#   'агурбаш',
#   'мне',
#   'любви',
#   'твоей',
#   'мало',
#   'музыка',
#   'в',
#   'mp',
#   'скачать',
#   'бесплатно',
#   'слушать',
#   'музыку',
#   'анжелика',
#   'агурбаш',
#   'мне',
#   'любви',
#   'твоей',
#   'мало',
#   'песен',
#   'песни',
#   'онлайн',
#   'на'],
#  ['необычные', 'рецепты', 'вкусные', 'идеи', 'каждый', 'день'],
#  ['девчат',
#   'с',
#   'радостью',
#   'бы',
#   'пописали',
#   'в',
#   'таких',
#   'туалетах',
#   'сообщение',
#   'москва'],
#  ['гостиница',
#   'авс',
#   'отель',
#   'россия',
#   'свердловская',
#   'область',
#   'екатеринбург',
#   'цены'],
#  ['купить',
#   'кронштейн',
#   'для',
#   'тв',
#   'наклонно',
#   'поворотный',
#   'vogel',
#   's',
#   'thin',
#   'black',
#   'в',
#   'каталоге',
#   'интернет',
#   'магазина',
#   'м',
#   'видео',
#   'по',
#   'выгодной',
#   'цене',
#   'с',
#   'доставкой',
#   'отзывы',
#   'фотогра'],
#  ['flora', 'by', 'gucci', 'ml', 'al', 'rayan'],
#  ['технические',
#   'и',
#   'функциональные',
#   'возможности',
#   'интерактивной',
#   'доски',
#   'тема',
#   'научной',
#   'статьи',
#   'по',
#   'общим',
#   'и',
#   'комплексным',
#   'проблемам',
#   'естественных',
#   'и',
#   'точн'],
#  ['секс',
#   'знакомства',
#   'обмен',
#   'интим',
#   'фото',
#   'без',
#   'регистрации',
#   'бесплатно',
#   'без',
#   'смс'],
#  ['jebug', 'obok', 'obok', 'susu', 'смотреть', 'онлайн'],
#  ['подскажите',
#   'как',
#   'ваши',
#   'дети',
#   'написали',
#   'централизованную',
#   'работу',
#   'по',
#   'геометрии',
#   'которая',
#   'была',
#   'наш',
#   'класс',
#   'походу',
#   'не',
#   'очень'],
#  ['teenfidelity',
#   'com',
#   'tf',
#   's',
#   'real',
#   'life',
#   'ryan',
#   'madison',
#   'jennifer',
#   'bliss',
#   'small',
#   'tits',
#   'porntube'],
#  ['millie',
#   'азарова',
#   'английский',
#   'язык',
#   'для',
#   'младшей',
#   'школы',
#   'скачать',
#   'беслатно',
#   'учебники',
#   'тетради',
#   'аудио',
#   'карточки',
#   'для',
#   'всех',
#   'классов',
#   'pdf'],
#  ['у',
#   'ребенка',
#   'красные',
#   'глаза',
#   'и',
#   'гноятся',
#   'у',
#   'ребенка',
#   'красные',
#   'глаза',
#   'и',
#   'гной'],
#  ['на',
#   'урале',
#   'играют',
#   'в',
#   'кёрлинг',
#   'автомобилями',
#   'ока',
#   'смотреть',
#   'видео',
#   'онлайн',
#   'в',
#   'моем',
#   'мире',
#   'олег',
#   'фролов'],
#  ['читать', 'книгу', 'оригинал', 'си', 'страница', 'библиотека', 'книг'],
#  ['игры',
#   'на',
#   'ps',
#   'скачать',
#   'торрент',
#   'бесплатно',
#   'и',
#   'без',
#   'регистрации'],
#  ['бархатцы', 'махровые', 'гиганты', 'гр', 'цп', 'семена', 'алтая'],
#  ['arilara',
#   'soyle',
#   'trsub',
#   'filmizlevip',
#   'смотреть',
#   'видео',
#   'онлайн',
#   'в',
#   'моем',
#   'мире',
#   'ahmet',
#   'bulut'],
#  ['собаки',
#   'в',
#   'поездах',
#   'укрзализныця',
#   'объяснила',
#   'правила',
#   'перевозки',
#   'животных',
#   'сегодня'],
#  ['фильмы', 'жанра', 'комедия', 'смотреть', 'онлайн', 'бесплатно'],
#  ['моя', 'реклама'],
#  ['ленинский',
#   'район',
#   'сентября',
#   'состоится',
#   'очередное',
#   'заседание',
#   'комиссии',
#   'по',
#   'профилактике',
#   'правонарушений'],
#  ['побег',
#   'из',
#   'лос',
#   'анджелеса',
#   'слушать',
#   'и',
#   'скачать',
#   'на',
#   'mixmuz'],
#  ['таинственный', 'лес', 'тайна', 'покрытая', 'мраком', 'отзывы'],
#  ['танцевальный', 'клуб', 'импульс', 'в', 'белгороде', 'для', 'детей', 'лет'],
#  ['скачать',
#   'клуб',
#   'винкс',
#   'сезон',
#   'серия',
#   'обратно',
#   'в',
#   'средние',
#   'века',
#   'русский',
#   'никелодеон',
#   'hd',
#   'смотреть',
#   'онлайн'],
#  ['мой', 'мир', 'mail', 'ru'],
#  ['против', 'язвы', 'iherb', 'com'],
#  ['большой',
#   'шар',
#   'с',
#   'куклами',
#   'lol',
#   'купить',
#   'в',
#   'краснодаре',
#   'цена',
#   'руб',
#   'дата',
#   'размещения',
#   'игрушки',
#   'и',
#   'игры'],
#  ['answear',
#   'ua',
#   'интернет',
#   'магазин',
#   'женской',
#   'мужской',
#   'и',
#   'детской',
#   'одежды',
#   'обуви',
#   'и',
#   'аксессуаров',
#   'онлайн',
#   'доставка',
#   'за',
#   'дня',
#   'бесплатная',
#   'отправка',
#   'заказа',
#   'от'],
#  ['соликамск',
#   'база',
#   'данных',
#   'недвижимости',
#   'соликамска',
#   'сайт',
#   'объявлений',
#   'о',
#   'продаже',
#   'и',
#   'аренде',
#   'объявления'],
#  ['big',
#   'titted',
#   'milf',
#   'with',
#   'glasses',
#   'is',
#   'rubbing',
#   'her',
#   'lover',
#   's',
#   'dick',
#   'in',
#   'front',
#   'of',
#   'a',
#   'hidden',
#   'camera',
#   'perfect',
#   'girls'],
#  ['водителя',
#   'элитного',
#   'мерседеса',
#   'убийцы',
#   'который',
#   'насмерть',
#   'сбил',
#   'парня',
#   'на',
#   'бауманской',
#   'экстрадировали',
#   'из',
#   'мюнхена',
#   'в',
#   'москву'],
#  ['тайная',
#   'война',
#   'воздушного',
#   'штрафбата',
#   'война',
#   'художественная',
#   'литература',
#   'читать',
#   'онлайн',
#   'booksbunker'],
#  ['отправление', 'ответа', 'на', 'объявление', 'огосекс', 'ру'],
#  ['результаты',
#   'поиска',
#   'по',
#   'запросу',
#   'секреты',
#   'пластилина',
#   'интернет',
#   'магазин',
#   'читай',
#   'город'],
#  ['читать', 'мангу', 'скала', 'кен', 'глава', 'на', 'русском', 'онлайн'],
#  ['крыло',
#   'toyota',
#   'caldina',
#   'правое',
#   'переднее',
#   'st',
#   'автозапчасти',
#   'в',
#   'горно',
#   'алтайске'],
#  ['акция',
#   'myllyn',
#   'paras',
#   'в',
#   'пятерочке',
#   'на',
#   'завтрак',
#   'каша',
#   'и',
#   'машина',
#   'ваша'],
#  ['колледжи',
#   'красноярска',
#   'со',
#   'специальностью',
#   'преподавание',
#   'в',
#   'начальных',
#   'классах'],
#  ['натали', 'natali', 'инстаграм', 'фотографии'],
#  ['кожаная',
#   'сумка',
#   'delgamo',
#   'купить',
#   'от',
#   'интернет',
#   'магазина',
#   'домани'],
#  ['фильтр', 'поиска'],
#  ['купить',
#   'кабель',
#   'aux',
#   'jack',
#   'rock',
#   'multifunctional',
#   'audio',
#   'cable',
#   'с',
#   'пультом',
#   'и',
#   'микрофоном',
#   'по',
#   'цене',
#   'руб'],
#  ['event', 'show', 'full', 'immersion', 'читайте', 'на', 'cossa', 'ru'],
#  ['cherie',
#   'deville',
#   'порно',
#   'видео',
#   'скачать',
#   'и',
#   'смотреть',
#   'фильмы',
#   'с',
#   'cherie',
#   'deville',
#   'в',
#   'hd'],
#  ['kayla', 'kayden', 'anal', 'daftsex'],
#  ['у',
#   'меня',
#   'на',
#   'great',
#   'wall',
#   'sailor',
#   'постоянно',
#   'горит',
#   'h',
#   'l',
#   'и',
#   'rew',
#   'lock',
#   'ответов',
#   'ремонт',
#   'и',
#   'эксплуатация',
#   'форум',
#   'авто',
#   'mail',
#   'ru'],
#  ['передняя', 'энциклопедия', 'pickupclub', 'ru'],
#  ['песни',
#   'say',
#   'mo',
#   'и',
#   'slame',
#   'номад',
#   'сезон',
#   'выпуск',
#   'фрагмент',
#   'из',
#   'песни',
#   'смотреть',
#   'онлайн',
#   'видео',
#   'бесплатно',
#   'видеохостинг',
#   'rutube'],
#  ['взрыв',
#   'на',
#   'заводе',
#   'поставщика',
#   'тойоты',
#   'не',
#   'скажется',
#   'на',
#   'производстве',
#   'компании',
#   'в',
#   'россии'],
#  ['лучшие',
#   'цены',
#   'для',
#   'ford',
#   'деталь',
#   'лучшие',
#   'цены',
#   'поставщиков',
#   'для',
#   'деталь',
#   'ford',
#   'burjauto'],
#  ['search', 'videos', 'for', 'threesome', 'docot', 'movies', 'page'],
#  ['inputbox',
#   'оператор',
#   'vba',
#   'для',
#   'получения',
#   'входных',
#   'данных',
#   'от',
#   'пользователя',
#   'процедуры'],
#  ['студент',
#   'який',
#   'кинув',
#   'яйце',
#   'в',
#   'януковича',
#   'у',
#   'роц',
#   'дор',
#   'с',
#   'до',
#   'директора',
#   'департаменту',
#   'ода',
#   'портал',
#   'новин',
#   'lb',
#   'ua'],
#  ['бережинський',
#   'ззсо',
#   'ступен',
#   'в',
#   'к',
#   'ровоградська',
#   'область',
#   'суо'],
#  ['луга', 'фреш', 'синюга', 'poly', 'pack'],
#  ['whaff',
#   'locker',
#   'скачать',
#   'на',
#   'андроид',
#   'и',
#   'ios',
#   'отзывы',
#   'и',
#   'промокод',
#   'деньги',
#   'на',
#   'телефон',
#   'рф'],
#  ['специальности',
#   'сибгу',
#   'им',
#   'м',
#   'ф',
#   'решетнева',
#   'направления',
#   'образования',
#   'бакалавриата',
#   'языкознание',
#   'и',
#   'литературоведение',
#   'в',
#   'красноярске'],
#  ['атлантис',
#   'тв',
#   'кабельное',
#   'телевидение',
#   'гай',
#   'адрес',
#   'описание',
#   'отзывы'],
#  ['гдз',
#   'номер',
#   'математика',
#   'класс',
#   'рабочая',
#   'тетрадь',
#   'а',
#   'г',
#   'мерзляк',
#   'в',
#   'б',
#   'полонский'],
#  ['результаты', 'поиска', 'по', 'запросу', 'гарри', 'потер'],
#  ['девочки', 'самое', 'интересное', 'фото', 'дом', 'солнца'],
#  ['портфель', 'blackterminal'],
#  ['whatsapp',
#   'messenger',
#   'pour',
#   'htc',
#   'wildfire',
#   's',
#   'tйlйchargement',
#   'gratuit',
#   'programmes',
#   'pour'],
#  ['image', 'hosting', 'script'],
#  ['hot', 'beauty', 'undressing', 'gallery'],
#  ['смотрите', 'видео', 'онлайн', 'бесплатно'],
#  ['porn',
#   'albums',
#   'with',
#   'alex',
#   'coal',
#   'jay',
#   's',
#   'pov',
#   'hd',
#   'porn',
#   'videos',
#   'sex',
#   'movies',
#   'porn',
#   'tube'],
#  ['общественные',
#   'и',
#   'политические',
#   'организации',
#   'в',
#   'пензе',
#   'на',
#   'ул',
#   'титова',
#   'организации'],
#  ['горячие', 'закуски', 'банкетный', 'зал', 'шартрез'],
#  ['офис',
#   'the',
#   'office',
#   'сезон',
#   'серия',
#   'смотреть',
#   'онлайн',
#   'в',
#   'высоком',
#   'качестве',
#   'pilot'],
#  ['танк',
#   'армата',
#   'и',
#   'с',
#   'никогда',
#   'не',
#   'поступят',
#   'в',
#   'армию',
#   'экспресс',
#   'газета'],
#  ['сырный', 'дом', 'все', 'о', 'домашнем', 'сыроделии'],
#  ['sodomie',
#   'a',
#   'repetition',
#   'xvideos',
#   'videoclipuri',
#   'porno',
#   'gratuite',
#   'xhamster',
#   'animal'],
#  ['читать',
#   'книгу',
#   'спящая',
#   'красавица',
#   'лп',
#   'страница',
#   'библиотека',
#   'книг'],
#  ['после', 'ролевых', 'игр', 'жестко', 'ебёт', 'в', 'д', 'жену'],
#  ['отзыв',
#   'о',
#   'работе',
#   'в',
#   'сеть',
#   'кафе',
#   'столовых',
#   'подсолнухи',
#   'город',
#   'новосибирск',
#   'черный',
#   'сп'],
#  ['девичья', 'стройность', 'почему', 'француженки', 'не', 'толстеют'],
#  ['сопр', 'вариант', 'дз', 'часть', 'студизба'],
#  ['класс', 'тест', 'доказательства', 'эволюции'],
#  ['об',
#   'утверждении',
#   'перечня',
#   'государственных',
#   'работ',
#   'выполняемых',
#   'государственными',
#   'учреждениями',
#   'владимирской',
#   'области',
#   'в',
#   'отношении',
#   'которых',
#   'государственная',
#   'инспекция',
#   'по',
#   'охране',
#   'и',
#   'использованию',
#   'животного',
#   'мира',
#   'администрации',
#   'области',
#   'осуществляет',
#   'функции',
#   'и',
#   'полномочия'],
#  ['задание',
#   'решение',
#   'русский',
#   'язык',
#   'класс',
#   'ладыженская',
#   'onlinegdz'],
#  ['эбби',
#   'глайнс',
#   'не',
#   'для',
#   'тебя',
#   'читать',
#   'книгу',
#   'онлайн',
#   'бесплатно'],
#  ['услуги',
#   'трубочиста',
#   'в',
#   'спб',
#   'прочистка',
#   'дымоходов',
#   'и',
#   'вентканалов'],
#  ['слив',
#   'обучения',
#   'plastik',
#   'за',
#   'k',
#   'форум',
#   'социальной',
#   'инженерии',
#   'lolzteam',
#   'net'],
#  ['поездка', 'с', 'попутчиками', 'и', 'данные', 'водителя', 'blablacar'],
#  ['газэнергоавтоматика'],
#  ['идей', 'для', 'создания', 'новогоднего', 'уюта', 'в', 'доме'],
#  ['великая',
#   'северная',
#   'война',
#   'программа',
#   'виват',
#   'история',
#   'виват',
#   'история',
#   'подкаст',
#   'на'],
#  ['м',
#   'и',
#   'цветаева',
#   'никто',
#   'ничего',
#   'не',
#   'отнял',
#   'текст',
#   'произведения'],
#  ['morning',
#   'sex',
#   'two',
#   'chicks',
#   'and',
#   'a',
#   'hot',
#   'male',
#   'porn',
#   'video'],
#  ['casey',
#   'calvert',
#   'порно',
#   'porno',
#   'русский',
#   'секс',
#   'домашнее',
#   'гей',
#   'видео',
#   'biqle',
#   'видео'],
#  ['закупки',
#   'моуо',
#   'отдел',
#   'образования',
#   'администрации',
#   'куртамышского',
#   'района'],
#  ['корова',
#   'из',
#   'цветов',
#   'обсуждение',
#   'на',
#   'liveinternet',
#   'российский',
#   'сервис',
#   'онлайн',
#   'дневник'],
#  ['sinoptik',
#   'погода',
#   'в',
#   'тужаре',
#   'прогноз',
#   'погоды',
#   'тужар',
#   'в',
#   'черниговской',
#   'области',
#   'козелецком',
#   'районе',
#   'на',
#   'неделю',
#   'украина'],
#  ['альбом',
#   'это',
#   'я',
#   'екатерина',
#   'года',
#   'россия',
#   'екатеринбург',
#   'сеть',
#   'знакомств',
#   'мамба'],
#  ['ремкомплект',
#   'суппорта',
#   'skoda',
#   'octavia',
#   'шкода',
#   'октавия',
#   'комплект',
#   'направляющей',
#   'гильзы',
#   'st',
#   'st',
#   'купить',
#   'в',
#   'киеве',
#   'цена',
#   'в',
#   'киеве',
#   'автозапчасти',
#   'абсолют',
#   'авто',
#   'абсолютное',
#   'качество',
#   'absolutavto',
#   'com',
#   'ua'],
#  ['зозуля', 'дитяч', 'п', 'сн', 'укра', 'нськ', 'дитяч', 'п', 'сн'],
#  ['результаты', 'поиска', 'по', 'запросу', 'железная', 'хватка'],
#  ['скачать',
#   'порно',
#   'на',
#   'телефон',
#   'дама',
#   'на',
#   'цепи',
#   'была',
#   'трахнута',
#   'ебальной',
#   'машиной',
#   'своего',
#   'друга',
#   'в',
#   'gp',
#   'и',
#   'mp'],
#  ['капернаум', 'фильм', 'онлайн', 'бесплатно', 'кинохолд'],
#  ['туника',
#   'c',
#   'в',
#   'г',
#   'душанбе',
#   'блузки',
#   'somon',
#   'tj',
#   'бесплатные',
#   'объявления',
#   'куплю',
#   'продам',
#   'б',
#   'у'],
#  ['необходима', 'проверка', 'безопасности'],
#  ['фотографии', 'бр', 'фото', 'в', 'моем', 'мире'],
#  ['готовый',
#   'перевод',
#   'i',
#   'm',
#   'really',
#   'a',
#   'superstar',
#   'я',
#   'стану',
#   'суперзвездой',
#   'глава',
#   'tl',
#   'rulate',
#   'ru'],
#  ['powered', 'by', 'line'],
#  ['куртка',
#   'утепленная',
#   'baon',
#   'купить',
#   'за',
#   'руб',
#   'ba',
#   'ewfzew',
#   'в',
#   'интернет',
#   'магазине',
#   'lamoda',
#   'ru'],
#  ['два',
#   'овертайма',
#   'и',
#   'новый',
#   'подвиг',
#   'летнего',
#   'сколы',
#   'как',
#   'сборные',
#   'испании',
#   'и',
#   'аргентины',
#   'вышли',
#   'в',
#   'финал',
#   'км',
#   'по',
#   'баскетболу',
#   'рт',
#   'на',
#   'русском'],
#  ['училка', 'в', 'стрингах', 'молодая', 'порно', 'фото'],
#  ['технология', 'производства', 'жби', 'колец', 'бетон', 'центр'],
#  ['aptekirls',
#   'ru',
#   'артрозилен',
#   'гель',
#   'г',
#   'заказать',
#   'онлайн',
#   'и',
#   'купить',
#   'в',
#   'ближайшей',
#   'аптеке',
#   'по',
#   'выгодным',
#   'ценам'],
#  ['секс',
#   'бесплатно',
#   'wicked',
#   'guy',
#   'gets',
#   'undressed',
#   'to',
#   'fuck',
#   'sexy',
#   'nice',
#   'looking',
#   'girl',
#   'бесплатное',
#   'секс',
#   'видео',
#   'онлайн',
#   'каждый',
#   'день'],
#  ['new',
#   'life',
#   'скачать',
#   'онлайн',
#   'игру',
#   'обзор',
#   'официальный',
#   'сайт',
#   'и',
#   'видео',
#   'new',
#   'life'],
#  ['плакат', 'кипелов', 'в', 'дар', 'москва', 'дарудар'],
#  ['файтеры', 'lurkmore'],
#  ['дом',
#   'интерьеры',
#   'красивых',
#   'домов',
#   'и',
#   'квартир',
#   'со',
#   'всего',
#   'мира',
#   'пуфик',
#   'блог',
#   'о',
#   'дизайне',
#   'интерьера'],
#  ['lemon', 'delfi', 'тыс', 'результатов', 'поиск', 'mail', 'ru'],
#  ['фотографии', 'юлиана', 'тугалова', 'фото', 'в', 'моем', 'мире'],
#  ['гранитная',
#   'мойка',
#   'для',
#   'кухни',
#   'u',
#   'цвет',
#   'песочный',
#   'сантехника',
#   'и',
#   'водоснабжение',
#   'во',
#   'в'],
#  ['защита',
#   'от',
#   'обратной',
#   'тяги',
#   'мм',
#   'era',
#   'ок',
#   'в',
#   'санкт',
#   'петербурге',
#   'купить',
#   'по',
#   'низкой',
#   'цене',
#   'отзывы',
#   'характеристики',
#   'фото',
#   'инструкция'],
#  ['два',
#   'аборигена',
#   'отдерут',
#   'шикарную',
#   'девицу',
#   'в',
#   'половую',
#   'оральную',
#   'и',
#   'анальную',
#   'щель',
#   'отборное',
#   'порно',
#   'на',
#   'ебухе'],
#  ['eaec',
#   'e',
#   'a',
#   'e',
#   'b',
#   'e',
#   'c',
#   'fae',
#   'скачать',
#   'бесплатно',
#   'электронная',
#   'библиотека',
#   'поиск',
#   'книг',
#   'bookfi'],
#  ['читать',
#   'мангу',
#   'месть',
#   'масамуне',
#   'куна',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['cosplay', 'caveira'],
#  ['немного',
#   'из',
#   'обычаев',
#   'и',
#   'нравов',
#   'рая',
#   'под',
#   'названием',
#   'доминикана',
#   'страна',
#   'мам'],
#  ['сергей',
#   'жорин',
#   'александр',
#   'толмацкий',
#   'не',
#   'собирается',
#   'забирать',
#   'ребенка',
#   'у',
#   'вдовы',
#   'децла'],
#  ['соединение',
#   'труб',
#   'корсис',
#   'с',
#   'трубами',
#   'других',
#   'систем',
#   'и',
#   'установка',
#   'колодцев'],
#  ['взять', 'заказ', 'taxi', 'money'],
#  ['ежедневно',
#   'кыргызстанцев',
#   'умирают',
#   'от',
#   'болезней',
#   'сердца',
#   'эксперт'],
#  ['wings', 'palette', 'lockheed', 'p', 'lightning', 'france'],
#  ['де',
#   'ла',
#   'круз',
#   'мелисса',
#   'маскарад',
#   'страница',
#   'читать',
#   'онлайн',
#   'rbook'],
#  ['поиск', 'скраб', 'для', 'тела', 'yves', 'rocher'],
#  ['розбираю',
#   'в',
#   'то',
#   'грн',
#   'транспорт',
#   'на',
#   'запчасти',
#   'рава',
#   'русская',
#   'на',
#   'olx'],
#  ['прокат',
#   'квадроциклов',
#   'как',
#   'бизнес',
#   'в',
#   'с',
#   'чего',
#   'начать',
#   'и',
#   'сколько',
#   'можно',
#   'заработать'],
#  ['search', 'videos', 'for', 'mom', 'porn', 'com', 'page'],
#  ['гдз',
#   'по',
#   'английскому',
#   'языку',
#   'для',
#   'класса',
#   'баранова',
#   'к',
#   'м',
#   'страница'],
#  ['мод', 'war', 'on', 'terror', 'pack', 'для', 'ravenfield'],
#  ['кыргызча', 'жаны', 'ырлар', 'скачать', 'бесплатно', 'текст'],
#  ['нумерология', 'data', 'rozhdenya'],
#  ['вредность',
#   'вредничество',
#   'непокорность',
#   'язвительство',
#   'новое',
#   'естественное',
#   'лечение'],
#  ['свадебные',
#   'и',
#   'вечерние',
#   'платья',
#   'в',
#   'новочеркасске',
#   'салон',
#   'скарлетт',
#   'новочеркасск',
#   'net'],
#  ['zuspitze',
#   'xvideos',
#   'bedava',
#   'porno',
#   'videolar',
#   'tan',
#   've',
#   'serseri',
#   'k',
#   'zlar',
#   'becer'],
#  ['светодинамический',
#   'фонтан',
#   'средний',
#   'нижний',
#   'царицынский',
#   'пруд',
#   'бирюлево',
#   'восточное'],
#  ['кент',
#   'а',
#   'кил',
#   'психопаты',
#   'достоверный',
#   'рассказ',
#   'о',
#   'людях',
#   'без',
#   'жалости',
#   'без',
#   'совести',
#   'без',
#   'раскаяния',
#   'читать',
#   'онлайн',
#   'полностью',
#   'литрес'],
#  ['маруся',
#   'если',
#   'человек',
#   'боится',
#   'показать',
#   'как',
#   'ты',
#   'ему',
#   'нужен',
#   'отпусти',
#   'его',
#   'пусть',
#   'боится',
#   'дальше'],
#  ['свитер', 'мэйбл', 'со', 'звездой', 'вязание', 'страна', 'мам'],
#  ['к', 'за', 'снеговика'],
#  ['птуп',
#   'мартин',
#   'бел',
#   'предлагает',
#   'грузы',
#   'для',
#   'перевозки',
#   'по',
#   'беларуси',
#   'sit',
#   'trans'],
#  ['new', 'videos', 'free', 'porn', 'sex', 'xxx', 'movies', 'page'],
#  ['бассейн',
#   'каркасный',
#   'прямоугольный',
#   'bestway',
#   'x',
#   'x',
#   'см',
#   'цена',
#   'грн',
#   'купить',
#   'в',
#   'киеве',
#   'prom',
#   'ua',
#   'id'],
#  ['buttonbar',
#   'скомпилированные',
#   'скрипты',
#   'autoit',
#   'каталог',
#   'файлов',
#   'cайт',
#   'azjio'],
#  ['женатый',
#   'парень',
#   'отжарил',
#   'молодую',
#   'соседку',
#   'втихаря',
#   'от',
#   'своей',
#   'жены'],
#  ['экологические',
#   'пирамиды',
#   'биомассы',
#   'и',
#   'численности',
#   'bio',
#   'learn',
#   'com'],
#  ['скачать',
#   'файл',
#   'alper',
#   'e',
#   'ri',
#   'bom',
#   'bom',
#   'mp',
#   'на',
#   'oxy',
#   'cloud'],
#  ['вакансии',
#   'и',
#   'работа',
#   'нормировщик',
#   'участка',
#   'в',
#   'твери',
#   'поиск',
#   'работы',
#   'с',
#   'городработ',
#   'ру'],
#  ['hussy',
#   'slut',
#   'mckenzee',
#   'miles',
#   'gets',
#   'her',
#   'asshole',
#   'stretched',
#   'hard',
#   'streaming',
#   'porn'],
#  [],
#  ['повышенное',
#   'выделение',
#   'слизи',
#   'у',
#   'женщин',
#   'виды',
#   'прозрачных',
#   'выделений',
#   'при',
#   'заболеваниях'],
#  ['танки',
#   'всё',
#   'о',
#   'фильме',
#   'отзывы',
#   'рецензии',
#   'смотреть',
#   'видео',
#   'онлайн',
#   'на',
#   'film',
#   'ru'],
#  ['автобусные', 'туры', 'в', 'бельгию', 'из', 'минска', 'цены'],
#  ['курица',
#   'с',
#   'кабачками',
#   'по',
#   'китайски',
#   'рецепт',
#   'с',
#   'пошаговыми',
#   'фотографиями'],
#  ['хореография', 'для', 'детей', 'направления', 'центра', 'знаток'],
#  ['photo', 'oiled', 'big', 'tits', 'boobs', 'topless', 'wallpaper'],
#  ['разрушители', 'легенд', 'mythbusters', 'сша', 'сериалы', 'вебург'],
#  ['мамка',
#   'в',
#   'белом',
#   'нижнем',
#   'белье',
#   'удовлетворяет',
#   'бородатого',
#   'парня',
#   'в',
#   'спальне'],
#  ['нож', 'бабочка', 'на', 'd', 'принтере'],
#  ['автоматические', 'установки', 'пожарной', 'сигнализации'],
#  ['николай', 'запорожье', 'лет', 'фото', 'и', 'страница'],
#  ['большой', 'козловский', 'переулок', 'д', 'на', 'карте', 'москвы'],
#  ['немолодая',
#   'женщина',
#   'показала',
#   'волосатую',
#   'вагину',
#   'порно',
#   'и',
#   'секс',
#   'фото',
#   'с',
#   'зрелыми',
#   'дамочками'],
#  ['русское',
#   'порно',
#   'смотреть',
#   'российскую',
#   'порнуху',
#   'бесплатно',
#   'онлайн',
#   'страница'],
#  ['порно',
#   'видео',
#   'с',
#   'каролина',
#   'свитс',
#   'carolina',
#   'sweets',
#   'jumpboobs',
#   'info'],
#  ['рассрочка', 'на', 'трансплантацию', 'волос'],
#  ['codycross', 'a', 'alogia', 'й', 'a', 'ausкncia', 'dela', 'respostas'],
#  ['наташа',
#   'мищенко',
#   'natashazabava',
#   'свадебный',
#   'фотограф',
#   'ставрополь',
#   'россия'],
#  ['в',
#   'россии',
#   'ужесточили',
#   'контроль',
#   'за',
#   'перевод',
#   'с',
#   'карты',
#   'на',
#   'карту'],
#  ['читать', 'мангу', 'опасная', 'любовь', 'глава', 'на', 'русском', 'онлайн'],
#  ['людмила',
#   'баснак',
#   'алма',
#   'ата',
#   'казахстан',
#   'на',
#   'мой',
#   'мир',
#   'mail',
#   'ru'],
#  ['twitter'],
#  ['кран',
#   'для',
#   'кулера',
#   'в',
#   'укра',
#   'н',
#   'пор',
#   'вняти',
#   'ц',
#   'ни',
#   'придбати',
#   'споживч',
#   'товари',
#   'на',
#   'маркетплейс',
#   'prom',
#   'ua'],
#  ['альбомы',
#   'по',
#   'развитию',
#   'речи',
#   'запись',
#   'пользователя',
#   'василиса',
#   'vasilisaart',
#   'в',
#   'сообществе',
#   'детские',
#   'книги',
#   'в',
#   'категории',
#   'для',
#   'самых',
#   'маленьких',
#   'babyblog',
#   'ru'],
#  ['макс', 'барских', 'займёмся', 'любовью', 'слушать', 'бесплатно', 'онлайн'],
#  ['не', 'могу', 'бегать', 'из', 'за', 'одышки', 'рассказываем', 'как', 'быть'],
#  ['просклонять', 'слово', 'кроватка', 'по', 'падежам', 'безбукв', 'ру'],
#  ['фотографии', 'анастасия', 'соломонова', 'фото', 'в', 'моем', 'мире'],
#  ['анданте',
#   'сезон',
#   'торрент',
#   'сериал',
#   'скачать',
#   'бесплатно',
#   'или',
#   'смотреть',
#   'онлайн'],
#  ['технология', 'покраски', 'бетона'],
#  ['ставка',
#   'рефинансирования',
#   'ключевая',
#   'ставка',
#   'цб',
#   'рф',
#   'на',
#   'год',
#   'таблица'],
#  ['читать',
#   'мангу',
#   'восьмой',
#   'сын',
#   'я',
#   'не',
#   'могу',
#   'этого',
#   'принять',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['new', 'lisa', 'ann', 'daftsex'],
#  ['фильм',
#   'операция',
#   'тушенка',
#   'смотреть',
#   'онлайн',
#   'бесплатно',
#   'в',
#   'хорошем',
#   'качестве',
#   'p',
#   'hd'],
#  ['купить',
#   'туалетная',
#   'кабина',
#   'х',
#   'х',
#   'м',
#   'в',
#   'невинномысске',
#   'в',
#   'невинномысске',
#   'от',
#   'производителя'],
#  ['купить',
#   'тонометр',
#   'механический',
#   'иад',
#   'со',
#   'стетоскопом',
#   'комплект',
#   'в',
#   'аптеках',
#   'московского',
#   'региона',
#   'с',
#   'доставкой',
#   'сравнение',
#   'цен',
#   'аптекамос'],
#  ['play',
#   'subway',
#   'surfers',
#   'world',
#   'tour',
#   'mexico',
#   'city',
#   'on',
#   'najox',
#   'com'],
#  ['обои', 'природа', 'обои', 'для', 'рабочего', 'стола', 'фото'],
#  ['трансформатор', 'грн', 'прочая', 'электроника', 'запорожье', 'на', 'olx'],
#  ['худи',
#   'спортивное',
#   'худи',
#   'с',
#   'капюшоном',
#   'и',
#   'большим',
#   'наклданым',
#   'карманом',
#   'кенгуру',
#   'ткань',
#   'одежда',
#   'для',
#   'женщин'],
#  ['дорама',
#   'цветочки',
#   'после',
#   'ягодок',
#   'смотреть',
#   'онлайн',
#   'русская',
#   'озвучка',
#   'результата',
#   'поиск',
#   'mail',
#   'ru'],
#  ['icon',
#   'pedro',
#   'capo',
#   'feat',
#   'reykon',
#   'como',
#   'lo',
#   'hiciste',
#   'ayer',
#   'скачать',
#   'бесплатно',
#   'песню',
#   'в',
#   'mp'],
#  ['рожанец',
#   'александр',
#   'робертович',
#   'физиотерапевт',
#   'отзывы',
#   'запись',
#   'на',
#   'прием',
#   'docdoc',
#   'ru'],
#  ['shemale', 'cam', 'show', 'videos', 'with', 'amateur', 'models', 'strictly'],
#  ['фото', 'топ', 'р', 'новая', 'цена', 'р'],
#  ['такой',
#   'разный',
#   'магний',
#   'стр',
#   'запись',
#   'пользователя',
#   'марина',
#   'id',
#   'в',
#   'сообществе',
#   'благополучная',
#   'беременность',
#   'в',
#   'категории',
#   'медикаменты',
#   'витамины',
#   'процедуры',
#   'babyblog',
#   'ru'],
#  ['черемухово', 'сайт', 'города', 'североуральска'],
#  ['презентация',
#   'на',
#   'тему',
#   'построение',
#   'курса',
#   'математики',
#   'умк',
#   'перспективная',
#   'начальная',
#   'ш'],
#  ['сдается',
#   'двухкомнатная',
#   'квартира',
#   'кв',
#   'м',
#   'в',
#   'екатеринбурге',
#   'вторчермет',
#   'эскадронная',
#   'ул',
#   'руб',
#   'месяц'],
#  ['вакансии',
#   'и',
#   'работа',
#   'дворник',
#   'разнорабочий',
#   'у',
#   'прямого',
#   'работодателя',
#   'в',
#   'москве',
#   'поиск',
#   'работы',
#   'с',
#   'городработ',
#   'ру'],
#  ['скачать',
#   'песню',
#   'kreayshawn',
#   'hey',
#   'bitch',
#   'do',
#   'you',
#   'really',
#   'wanna',
#   'go',
#   'hard',
#   'trap',
#   'mix',
#   'бесплатно',
#   'и',
#   'слушать',
#   'онлайн',
#   'mp',
#   'cc',
#   'biz'],
#  ['дроссельную',
#   'заслонку',
#   'gaz',
#   'газель',
#   'купить',
#   'в',
#   'барнауле',
#   'цены',
#   'на',
#   'новые',
#   'бу',
#   'и',
#   'контрактные',
#   'запчасти',
#   'для',
#   'авто',
#   'газ',
#   'газель'],
#  ['заготовки', 'рецепты'],
#  ['biolage', 'отзывы', 'покупателей'],
#  ['наталья', 'москва'],
#  ['администратор'],
#  ['лучшие', 'светодиодные', 'ленты', 'года', 'топ', 'рейтинг', 'лучших'],
#  ['обои',
#   'видео',
#   'игры',
#   'mass',
#   'effect',
#   'обои',
#   'для',
#   'рабочего',
#   'стола',
#   'фотографии',
#   'видео',
#   'игры',
#   'm'],
#  ['значение', 'имени', 'иннокентий', 'кеша'],
#  ['tut',
#   'by',
#   'работа',
#   'тут',
#   'поиск',
#   'работы',
#   'в',
#   'минске',
#   'и',
#   'беларуси'],
#  ['гдз',
#   'по',
#   'русскому',
#   'языку',
#   'за',
#   'класс',
#   'решебники',
#   'ответы',
#   'онлайн'],
#  ['комплексный',
#   'центр',
#   'социального',
#   'обслуживания',
#   'населения',
#   'бологовского',
#   'района',
#   'структура',
#   'центра'],
#  ['документы', 'для', 'учебы'],
#  ['подсветка',
#   'салона',
#   'vw',
#   'skoda',
#   'передний',
#   'плафон',
#   'цена',
#   'руб',
#   'купить',
#   'в',
#   'санкт',
#   'петербурге',
#   'tiu',
#   'ru',
#   'id'],
#  ['watch', 'online', 'dyan', 'cannon', 'doctors', 'wives', 'hd', 'p'],
#  ['профессор', 'карапуз', 'музична', 'пригода', 'dvd', 'бесплатно', 'скачать'],
#  ['продам',
#   'volkswagen',
#   'bora',
#   'г',
#   'в',
#   'пмр',
#   'авторынок',
#   'пмр',
#   'и',
#   'молдовы',
#   'клаксона'],
#  ['визиты',
#   'осенние',
#   'визиты',
#   'спектр',
#   'кредо',
#   'электронная',
#   'библиотека',
#   'асмодея'],
#  ['вакансия',
#   'слесарь',
#   'механосборочных',
#   'работ',
#   'в',
#   'туле',
#   'работа',
#   'в',
#   'витра'],
#  ['рукоделие',
#   'картины',
#   'образы',
#   'рукодельниц',
#   'в',
#   'живописи',
#   'картин',
#   'современных',
#   'художников'],
#  ['joyreactor',
#   'смешные',
#   'картинки',
#   'и',
#   'другие',
#   'приколы',
#   'комиксы',
#   'гиф',
#   'анимация',
#   'видео',
#   'лучший',
#   'интеллектуальный',
#   'юмор'],
#  ['art', 'lingerie', 'ero', 'full', 'sets', 'page'],
#  ['нахальный', 'пронырливый', 'человек', 'букв'],
#  ['charles',
#   'perrot',
#   'hood',
#   'little',
#   'riding',
#   'red',
#   'ringkasan',
#   'pelajaran',
#   'tentang',
#   'bacaan',
#   'sastera',
#   'mengenai',
#   'tema',
#   'charles',
#   'perrot',
#   'little',
#   'red',
#   'riding',
#   'hood'],
#  ['powered', 'by', 'ameba'],
#  ['туры',
#   'в',
#   'отель',
#   'alara',
#   'star',
#   'турция',
#   'аланья',
#   'цены',
#   'и',
#   'отзывы'],
#  ['объявление',
#   'снять',
#   'комнатную',
#   'квартиру',
#   'в',
#   'районе',
#   'центральный',
#   'в',
#   'городе',
#   'хабаровск',
#   'аренда',
#   'трехкомнатных',
#   'квартир',
#   'на',
#   'длительный',
#   'срок',
#   'найти',
#   'ж'],
#  ['стоматология',
#   'до',
#   'и',
#   'после',
#   'улыбка',
#   'всевластия',
#   'стоматолог',
#   'улыбка',
#   'зубы',
#   'властел'],
#  ['перечень',
#   'предохранителей',
#   'для',
#   'компонетов',
#   'блок',
#   'реле',
#   'и',
#   'предохранителей',
#   'расположенный',
#   'под',
#   'панелью',
#   'управления',
#   'руководство',
#   'по',
#   'обслуживанию',
#   'и',
#   'ремонту',
#   'honda',
#   'fr',
#   'v',
#   'sjd',
#   'e',
#   'j',
#   'cbrt'],
#  ['new',
#   'best',
#   'of',
#   'deep',
#   'house',
#   'the',
#   'best',
#   'of',
#   'sexy',
#   'party',
#   'deep',
#   'house',
#   'nu',
#   'disco',
#   'music',
#   'girls',
#   'music',
#   'video',
#   'daftsex'],
#  ['una',
#   'buena',
#   'follada',
#   'para',
#   'marta',
#   'croft',
#   'rica',
#   'follada',
#   'con',
#   'una',
#   'joven',
#   'reina'],
#  ['отзывы',
#   'о',
#   'моделирующая',
#   'паста',
#   'для',
#   'тела',
#   'organic',
#   'shop',
#   'похудение',
#   'экспресс',
#   'греческое',
#   'талассо'],
#  ['дестабилизировать', 'это', 'что', 'такое', 'дестабилизировать'],
#  ['стр',
#   'работа',
#   'нур',
#   'султан',
#   'объявлений',
#   'на',
#   'вакансий',
#   'www',
#   'enbek',
#   'kz'],
#  ['мой', 'мир', 'mail', 'ru'],
#  ['streptococcus',
#   'pneumonia',
#   'в',
#   'горле',
#   'отоларингология',
#   'здоровье',
#   'mail',
#   'ru'],
#  ['фото', 'города', 'бетлица', 'россия', 'фотографий'],
#  ['route',
#   'advisor',
#   'small',
#   'mirrors',
#   'версия',
#   'для',
#   'american',
#   'truck',
#   'simulator',
#   'v'],
#  ['читать',
#   'книгу',
#   'поцелуй',
#   'горца',
#   'автор',
#   'монинг',
#   'карен',
#   'онлайн',
#   'страница',
#   'читать',
#   'книгу',
#   'без',
#   'регистрации'],
#  ['спасибо', 'за', 'покупку'],
#  ['надежда', 'псков'],
#  ['оргия',
#   'на',
#   'яхте',
#   'в',
#   'море',
#   'порно',
#   'видео',
#   'онлайн',
#   'смотреть',
#   'бесплатно'],
#  ['проверка', 'и', 'отзывы', 'о', 'сайте', 'prezika', 'net'],
#  ['аладдин',
#   'мультфильм',
#   'смотреть',
#   'онлайн',
#   'в',
#   'хорошем',
#   'качестве',
#   'бесплатно'],
#  ['kedi', 'lerde', 'hi', 'perti', 'roi', 'di', 'pati', 'saray'],
#  ['taboo', 'heat', 'full', 'xxx', 'movies'],
#  ['преддипломная', 'практика', 'в', 'начальной', 'школе'],
#  ['сковороды',
#   'сотейники',
#   'scovo',
#   'купить',
#   'в',
#   'крыму',
#   'севастополе',
#   'симферополе',
#   'керчи',
#   'феодосии',
#   'ялте',
#   'topsto',
#   'страница'],
#  ['workout', 'archives', 'coca', 'porn'],
#  ['download',
#   'photo',
#   'x',
#   'jeans',
#   'skirt',
#   'ass',
#   'asshole',
#   'pussy',
#   'henessy',
#   'meaty',
#   'pussy',
#   'nice',
#   'ass',
#   'hamburger',
#   'pussy',
#   'plump',
#   'pussy',
#   'puffy',
#   'pussy',
#   'thighs',
#   'id'],
#  ['конструктор',
#   'строительная',
#   'площадка',
#   'купить',
#   'в',
#   'тольятти',
#   'цена',
#   'руб',
#   'дата',
#   'размещения',
#   'игрушки',
#   'и',
#   'игры'],
#  ['лучшие',
#   'цены',
#   'для',
#   'toyota',
#   'трос',
#   'стояночного',
#   'тормоза',
#   'лучшие',
#   'цены',
#   'поставщиков',
#   'для',
#   'трос',
#   'стояночного',
#   'тормоза',
#   'toyota',
#   'burjauto'],
#  ['некоторые',
#   'думают',
#   'что',
#   'футбол',
#   'это',
#   'дело',
#   'жизни',
#   'и',
#   'смерти',
#   'я',
#   'совершенно',
#   'разочарован',
#   'их',
#   'позицией',
#   'футбол',
#   'намного',
#   'важнее',
#   'свободное',
#   'мнение',
#   'бло'],
#  ['what',
#   'remains',
#   'of',
#   'edith',
#   'finch',
#   'pc',
#   'repack',
#   'от',
#   'xatab',
#   'скачать',
#   'через',
#   'торрент',
#   'на',
#   'pc'],
#  ['secure', 'monitor', 'clip', 'art', 'clip', 'art', 'library'],
#  ['target', 'my', 'com'],
#  ['знакомства',
#   'с',
#   'парнями',
#   'краснодарский',
#   'край',
#   'новороссийск',
#   'результаты',
#   'поиска',
#   'сайт',
#   'знакомств',
#   'тралоло'],
#  ['сказка',
#   'о',
#   'попе',
#   'и',
#   'работнике',
#   'его',
#   'балде',
#   'а',
#   'с',
#   'пушкин',
#   'читать',
#   'онлайн'],
#  ['baleja', 'na', 'd', 'ugich', 'w', 'osach'],
#  ['ылым',
#   'саласында',
#   'ы',
#   'сыйлы',
#   'тар',
#   'мен',
#   'мемлекетт',
#   'к',
#   'ылыми',
#   'стипендиялар',
#   'туралы',
#   'аза',
#   'стан',
#   'республикасы',
#   'к',
#   'мет',
#   'н',
#   'жыл',
#   'ы',
#   'ш',
#   'лдедег',
#   'аулысы'],
#  ['сонник',
#   'новые',
#   'отношения',
#   'приснились',
#   'к',
#   'чему',
#   'снятся',
#   'новые',
#   'отношения',
#   'во',
#   'сне',
#   'видеть'],
#  ['куркума',
#   'при',
#   'ваг',
#   'тност',
#   'експерти',
#   'назвали',
#   'неспод',
#   'вану',
#   'користь',
#   'але',
#   'нюанси',
#   'znaj',
#   'ua'],
#  ['tamil', 'actress', 'sona', 'nude', 'hairy', 'pussy', 'sex', 'photo'],
#  ['фото',
#   'альбом',
#   'фото',
#   'группы',
#   'фото',
#   'фотографии',
#   'будь',
#   'в',
#   'тренде'],
#  ['кондиционеры',
#   'balea',
#   'для',
#   'волос',
#   'заказать',
#   'из',
#   'германии',
#   'доставка'],
#  ['харампурнефтегаз',
#   'получил',
#   'права',
#   'на',
#   'строительство',
#   'объектов',
#   'на',
#   'харампурском',
#   'месторождении',
#   'oilcapital'],
#  ['остров',
#   'миагани',
#   'последняя',
#   'бомба',
#   'местонахождение',
#   'virtualgameinfo',
#   'ru'],
#  ['архитектурные',
#   'вузы',
#   'университеты',
#   'институты',
#   'академии',
#   'и',
#   'факультеты',
#   'саратовской',
#   'области',
#   'вузы',
#   'для',
#   'архитекторов',
#   'учёба',
#   'ру'],
#  ['авторизац', 'я', 'на', 'портал', 'apkua', 'net'],
#  ['blue',
#   'eyed',
#   'babe',
#   'is',
#   'gently',
#   'licking',
#   'the',
#   'tip',
#   'of',
#   'her',
#   'lover',
#   's',
#   'dick',
#   'to',
#   'make',
#   'him',
#   'cum',
#   'perfect',
#   'girls'],
#  ['спортмастер',
#   'г',
#   'санкт',
#   'петербург',
#   'трк',
#   'жемчужная',
#   'плаза',
#   'петергофское',
#   'шоссе',
#   'д',
#   'в',
#   'г',
#   'санкт',
#   'петербург'],
#  ['урок', 'по', 'музыке', 'главный', 'кит', 'песня', 'класс', 'урок'],
#  ['извадете',
#   'електричеството',
#   'както',
#   'сте',
#   'избрали',
#   'електрически',
#   'длето',
#   'универсален',
#   'инструмент',
#   'за',
#   'работилница',
#   'за',
#   'домашен',
#   'фурнир'],
#  ['александры', 'с', 'загран', 'паспортами', 'помогите'],
#  ['pavloolesya', 'yandex', 'ru', 'почта', 'mail', 'ru'],
#  ['синонимы', 'к', 'слову', 'удержать', 'в', 'вертикальном', 'положении'],
#  ['читать',
#   'мангу',
#   'макрофаг',
#   'ломая',
#   'каноны',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['l',
#   'incroyable',
#   'histoire',
#   'de',
#   'la',
#   'chirurgie',
#   'plastique',
#   'la',
#   'plus',
#   'effrayante',
#   'au',
#   'monde',
#   'savoir'],
#  ['начальный', 'уровень', 'гдз', 'решебник', 'по', 'физике', 'классов'],
#  ['работа',
#   'в',
#   'сфере',
#   'транспорт',
#   'автобизнес',
#   'автосервис',
#   'от',
#   'руб',
#   'в',
#   'москве'],
#  ['shawna', 'lenee', 'porn', 'videos', 'perfect', 'girls'],
#  ['tralolo',
#   'com',
#   'социальная',
#   'сеть',
#   'позволяющая',
#   'знакомится',
#   'и',
#   'общятся',
#   'с',
#   'людьми',
#   'отправляю',
#   'смс',
#   'и',
#   'еще',
#   'много',
#   'другое'],
#  ['фильм',
#   'закон',
#   'каменных',
#   'джунглей',
#   'фильм',
#   'фото',
#   'видео',
#   'список',
#   'актеров',
#   'вокруг',
#   'тв'],
#  ['бедная',
#   'настя',
#   'серия',
#   'смотреть',
#   'онлайн',
#   'сериал',
#   'gidfilm',
#   'ru',
#   'красвью'],
#  ['обувь', 'shop', 'страница', 'slon', 'sneakers'],
#  ['мотоциклист',
#   'погиб',
#   'из',
#   'за',
#   'столкновения',
#   'с',
#   'иномаркой',
#   'на',
#   'улице',
#   'землячки',
#   'в',
#   'сормовском',
#   'районе',
#   'нижнего',
#   'новгорода',
#   'сентября',
#   'года',
#   'новости',
#   'nn',
#   'ru'],
#  ['плохие',
#   'отзывы',
#   'о',
#   'bfgoodrich',
#   'g',
#   'force',
#   'winter',
#   'r',
#   't',
#   'я',
#   'прочитал',
#   'здесь'],
#  ['приказ', 'минобразования', 'рф', 'от', 'n'],
#  ['электротриммер', 'p', 'i', 't', 'ptr', 'el'],
#  ['страница',
#   'моя',
#   'любимая',
#   'с',
#   'нежность',
#   'читать',
#   'онлайн',
#   'юлия',
#   'шкутова',
#   'полно',
#   'книг'],
#  ['схемка',
#   'осенняя',
#   'красота',
#   'листьев',
#   'от',
#   'мариэлла',
#   'обсуждение',
#   'на',
#   'liveinternet'],
#  ['особенности',
#   'межнациональных',
#   'сношений',
#   'dvdrip',
#   'hd',
#   'в',
#   'хорошем',
#   'качестве',
#   'вид'],
#  ['фильмов', 'о', 'подвиге', 'и', 'силе', 'духа', 'рамблер', 'кино'],
#  ['аренда',
#   'cклада',
#   'м',
#   'сигнальный',
#   'проезд',
#   'с',
#   'москва',
#   'свао',
#   'р',
#   'н',
#   'отрадное',
#   'м',
#   'владыкино',
#   'база',
#   'циан',
#   'объявление'],
#  ['погода',
#   'в',
#   'актаныш',
#   'на',
#   'сентябрь',
#   'самый',
#   'tочный',
#   'прогноз',
#   'на',
#   'сентябрь',
#   'от',
#   'гидрометцентра',
#   'актаныш'],
#  ['разнообразие',
#   'стилей',
#   'в',
#   'творчестве',
#   'художника',
#   'казимира',
#   'малевича',
#   'designonstop',
#   'о'],
#  ['блендеры',
#   'bosch',
#   'купить',
#   'блендер',
#   'бош',
#   'цены',
#   'и',
#   'отзывы',
#   'в',
#   'интернет',
#   'магазине',
#   'ситилинк',
#   'таганрог'],
#  ['мой', 'мир', 'mail', 'ru'],
#  ['порно',
#   'телеканал',
#   'o',
#   'la',
#   'la',
#   'tv',
#   'смотреть',
#   'онлайн',
#   'бесплатно'],
#  ['беру',
#   'скидка',
#   'на',
#   'все',
#   'промокод',
#   'по',
#   'ваш',
#   'промокод',
#   'kuponinaskidku',
#   'купоны',
#   'на',
#   'скидку'],
#  ['мужик', 'развел', 'чужую', 'жену', 'с', 'большими', 'сиськами'],
#  ['pes',
#   'pro',
#   'evolution',
#   'soccer',
#   'skachat',
#   'tas',
#   'ix',
#   'скачать',
#   'без',
#   'steam',
#   'asilmedia',
#   'net',
#   'тас',
#   'икс',
#   'tas',
#   'ix',
#   'фильмы',
#   'сериалы',
#   'игры',
#   'клипы',
#   'музыка',
#   'програм'],
#  ['слушать',
#   'аудиои',
#   'книгу',
#   'выжми',
#   'из',
#   'бизнеса',
#   'все',
#   'млн',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['миля', 'трейлер', 'на', 'русском'],
#  ['фистинг', 'девушки', 'в', 'латексе'],
#  ['китайская',
#   'биокомпания',
#   'создала',
#   'своего',
#   'первого',
#   'клонированного',
#   'котенка',
#   'техкульт'],
#  ['наглядная',
#   'биохимия',
#   'я',
#   'кольман',
#   'к',
#   'г',
#   'рем',
#   'год',
#   'библиотека',
#   'медицинской',
#   'л'],
#  ['orgpage'],
#  ['размер', 'колес', 'на', 'toyota', 'verossa', 'размер', 'колес'],
#  ['читать',
#   'онлайн',
#   'бартш',
#   'карина',
#   'бирюзовая',
#   'зима',
#   'электронная',
#   'библиотека',
#   'e',
#   'libra',
#   'ru'],
#  ['алалия', 'методика', 'работы', 'с', 'безречевыми', 'детьми'],
#  ['приговор', 'суда', 'по', 'ч', 'ст', 'ук', 'рф', 'судебная', 'практика'],
#  ['масло',
#   'для',
#   'загара',
#   'в',
#   'солярии',
#   'ultra',
#   'x',
#   'oil',
#   'capsule',
#   'power',
#   'tan',
#   'ultra',
#   'x'],
#  ['серия',
#   'аниме',
#   'покорение',
#   'горизонта',
#   'log',
#   'horizon',
#   'озвучка',
#   'от',
#   'anidub',
#   'ancord',
#   'balfor',
#   'cuba',
#   'inspector',
#   'gadjet',
#   'jam',
#   'nika',
#   'lenina',
#   'oslikt',
#   'shina',
#   'trina',
#   'd',
#   'смотреть',
#   'онлайн',
#   'anime'],
#  ['арсенал',
#   'частное',
#   'охранное',
#   'предприятие',
# ...
#  ['manyvids', 'page', 'incest', 'porn', 'videos', 'family', 'extreme', 'sex'],
#  ['сим', 'таррэн', 'феррис', 'от', 'аканехиде'],
#  ['декасан',
#   'состав',
#   'препарата',
#   'от',
#   'чего',
#   'помогает',
#   'в',
#   'стомалогории',
#   'при',
#   'бронхите',
#   'ангине',
#   'как',
#   'применять',
#   'при',
#   'беременности',
#   'для',
#   'детей',
#   'цена',
#   'аналоги'],
#  ['в', 'дорогу', 'с', 'попутчиками', 'без', 'хлопот', 'blablacar', 'ru'],
#  ['черные', 'босоножки', 'на', 'блочном', 'каблуке', 'glamorous', 'asos'],
#  ['declan', 'wake', 'форум', 'о', 'куклах', 'dp'],
#  ['как',
#   'грамотно',
#   'расставить',
#   'мебель',
#   'в',
#   'маленькой',
#   'кухне',
#   'чтобы',
#   'использовать',
#   'все',
#   'пространство'],
#  ['вакансия',
#   'для',
#   'студентов',
#   'в',
#   'городе',
#   'санкт',
#   'петербург',
#   'работа',
#   'в',
#   'coach',
#   'institute',
#   'гибкий',
#   'график'],
#  ['полная',
#   'вагина',
#   'спермы',
#   'онлайн',
#   'смотреть',
#   'бесплатно',
#   'порно',
#   'видео',
#   'онлайн'],
#  ['developpe',
#   'sex',
#   'цена',
#   'руб',
#   'купить',
#   'в',
#   'москве',
#   'tiu',
#   'ru',
#   'id'],
#  ['отзывы',
#   'о',
#   'сбербанке',
#   'россии',
#   'двойное',
#   'списание',
#   'средств',
#   'за',
#   'мобильный',
#   'банк',
#   'банки',
#   'ру'],
#  ['телка',
#   'из',
#   'питера',
#   'после',
#   'знакомства',
#   'с',
#   'новым',
#   'другом',
#   'снимается',
#   'в',
#   'крутом',
#   'домашнем',
#   'порн'],
#  ['русский',
#   'язык',
#   'класс',
#   'т',
#   'а',
#   'ладыженская',
#   'м',
#   'т',
#   'баранов',
#   'в',
#   'ч',
#   'номер'],
#  ['иерусалимское', 'королевство', 'все', 'монархии', 'мира'],
#  ['как',
#   'отучить',
#   'лайку',
#   'поедать',
#   'или',
#   'трепать',
#   'битую',
#   'дичь',
#   'зверька'],
#  ['сайт', 'знакомств', 'loveplanet', 'ru'],
#  ['blowyourbrain',
#   'россия',
#   'санкт',
#   'петербург',
#   'м',
#   'лесная',
#   'dating',
#   'ru'],
#  ['сервис', 'не', 'доступен'],
#  ['термо',
#   'комбинезон',
#   'на',
#   'мальчика',
#   'французский',
#   'peak',
#   'mountain',
#   'грн',
#   'одежда',
#   'для',
#   'мальчиков',
#   'киев',
#   'на',
#   'olx'],
#  ['редактировать', 'товар', 'личный', 'кабинет', 'agroserver', 'ru'],
#  ['коттеджи', 'дома', 'участки', 'realt', 'by'],
#  ['порно', 'видео', 'онлайн', 'мин'],
#  ['стихи', 'детям', 'как', 'зимуют', 'животные'],
#  ['уайат',
#   'сенак',
#   'разрулит',
#   'сезон',
#   'серия',
#   'смотреть',
#   'онлайн',
#   'hd',
#   'беспла'],
#  ['тюменский',
#   'дизайнер',
#   'алена',
#   'дубровина',
#   'получила',
#   'гран',
#   'при',
#   'в',
#   'москве',
#   'ru',
#   'новости',
#   'тюмени'],
#  ['коты', 'мордой', 'вниз'],
#  ['администратор', 'отеля'],
#  ['ооо',
#   'группа',
#   'компаний',
#   'михайлов',
#   'и',
#   'партнеры',
#   'москва',
#   'инн',
#   'огрн'],
#  ['сергей', 'скрипаль', 'контингент', 'книга', 'афган', 'читать', 'онлайн'],
#  ['beautiful',
#   'teen',
#   'softcore',
#   'free',
#   'porn',
#   'sex',
#   'videos',
#   'xxx',
#   'movies',
#   'hd',
#   'home',
#   'of',
#   'videos',
#   'porno'],
#  ['team', 'nonfiction', 'aimi', 'yoshikawa', 'daftsex'],
#  ['кислоты', 'в', 'фармакологии'],
#  ['читать',
#   'мангу',
#   'боевой',
#   'континент',
#   'страна',
#   'душ',
#   'глава',
#   'на',
#   'русском',
#   'онлайн'],
#  ['продаётся',
#   'ссангйонг',
#   'рекстон',
#   'года',
#   'в',
#   'томске',
#   'собственник',
#   'владею',
#   'лет',
#   'литра',
#   'бензин',
#   'акпп'],
#  ['armtek',
#   'запчасти',
#   'для',
#   'грузовых',
#   'и',
#   'легковых',
#   'автомобилей',
#   'оборудование',
#   'для',
#   'сто'],
#  ['нордрута', 'пододеяльник', 'и', 'наволочка', 'серый', 'синий', 'ikea'],
#  ['манга', 'the', 'promised', 'neverland', 'онлайн'],
#  ['продам', 'батареи', 'грн', 'отопление', 'харьков', 'на', 'olx'],
#  ['автозапчасти',
#   'в',
#   'городе',
#   'дюссельдорф',
#   'германия',
#   'каталог',
#   'магазинов',
#   'автозапчастей',
#   'адреса',
#   'телефоны',
#   'время',
#   'работы',
#   'сайт'],
#  ['вакансия',
#   'инженер',
#   'видеонаблюдения',
#   'в',
#   'серове',
#   'работа',
#   'в',
#   'компании',
#   'угмк',
#   'холдинг',
#   'полный',
#   'рабочий',
#   'день'],
#  ['секс', 'на', 'выпускном', 'вечере'],
#  ['скачать', 'порно', 'длинноволосых', 'красоток', 'на', 'телефон'],
#  ['мег', 'монстр', 'глубины', 'скачать', 'торрент', 'файл', 'бесплатно'],
#  ['решено',
#   'упр',
#   'урок',
#   'unit',
#   'гдз',
#   'english',
#   'кузовлев',
#   'класс',
#   'с',
#   'переводом',
#   'заданий'],
#  ['анатоли',
#   'лет',
#   'лев',
#   'плещеницы',
#   'анкета',
#   'знакомств',
#   'на',
#   'сайте',
#   'tabor',
#   'ru'],
#  ['крахмал',
#   'загуститель',
#   'или',
#   'заменитель',
#   'полезный',
#   'и',
#   'не',
#   'очень',
#   'хорошо',
#   'выглядеть'],
#  ['сдам',
#   'ю',
#   'квартиру',
#   'до',
#   'июня',
#   'грн',
#   'долгосрочная',
#   'аренда',
#   'квартир',
#   'комнат',
#   'ильичевск',
#   'на',
#   'olx'],
#  ['серия',
#   'сезона',
#   'мультсериала',
#   'гриффины',
#   'в',
#   'озвучке',
#   'от',
#   'студии',
#   'coldfilm',
#   'игры',
#   'в',
#   'свидание',
#   'смотреть',
#   'гриффины',
#   'онлайн',
#   'в',
#   'hd',
#   'качестве'],
#  ['langes', 'blowjob', 'mдdchen'],
#  ['lush', 'silka', 'big', 'ass', 'will', 'be', 'banging', 'the', 'wall'],
#  ['расстояние', 'ростов', 'на', 'дону', 'феодосия', 'км', 'маршрута'],
#  ['pauline', 'ester', 'oui', 'je', 'l', 'adore'],
#  ['тюнинг',
#   'renault',
#   'sandero',
#   'в',
#   'казани',
#   'сравнить',
#   'цены',
#   'купить',
#   'потребительские',
#   'товары',
#   'на',
#   'маркетплейсе',
#   'tiu',
#   'ru'],
#  ['сонник',
#   'картинки',
#   'скелет',
#   'к',
#   'чему',
#   'снится',
#   'картинки',
#   'скелет',
#   'видеть',
#   'во',
#   'сне',
#   'сонник',
#   'дом'],
#  ['wise',
#   'memory',
#   'optimizer',
#   'рс',
#   'русский',
#   'portable',
#   'скачать',
#   'торрент',
#   'программу',
#   'бесплатно',
#   'без',
#   'регистрации'],
#  ['купальник',
#   'бикини',
#   'в',
#   'двухцветном',
#   'дизайне',
#   'для',
#   'размера',
#   'а',
#   'и',
#   'в',
#   'черный',
#   'серый'],
#  ['можно',
#   'обмен',
#   'на',
#   'скот',
#   'тг',
#   'nissan',
#   'нур',
#   'султан',
#   'астана',
#   'на',
#   'olx'],
#  ['temptation',
#   'of',
#   'mara',
#   'guy',
#   'sweens',
#   'скачать',
#   'бесплатно',
#   'mp',
#   'и',
#   'слушать',
#   'онлайн',
#   'видеок'],
#  ['современные',
#   'технологии',
#   'обучения',
#   'в',
#   'музыкальном',
#   'образовании',
#   'тема',
#   'научной',
#   'статьи',
#   'по',
#   'народному',
#   'образованию',
#   'и',
#   'педагогике',
#   'читайте',
#   'бесплатно'],
#  ['человек',
#   'в',
#   'одном',
#   'седане',
#   'мигранты',
#   'погибли',
#   'пытаясь',
#   'покинуть',
#   'гаити'],
#  ['playboy', 'naked', 'workout', 'more', 'girls', 'video', 'daftsex'],
#  ['урок',
#   'в',
#   'классе',
#   'по',
#   'теме',
#   'повторение',
#   'и',
#   'систематизация',
#   'изученного',
#   'об',
#   'имени',
#   'существительном',
#   'бюджетное',
#   'общеобразовательное',
#   'учреждение',
#   'вышне',
#   'ольшанская',
#   'средняя',
#   'общеобразовательная',
#   'школа'],
#  ['транспортный',
#   'налог',
#   'ветеранам',
#   'боевых',
#   'советы',
#   'адвокатов',
#   'и',
#   'юристов'],
#  ['балаба',
#   'ша',
#   'жасында',
#   'ы',
#   'балалар',
#   'а',
#   'арнал',
#   'ан',
#   'таныстыру',
#   'c',
#   'ра',
#   'жауап'],
#  ['коттеджи', 'на', 'новый', 'год', 'загородный', 'отдых'],
#  ['салат', 'гранатовый'],
#  ['блондинку',
#   'с',
#   'большими',
#   'сиськами',
#   'изнасиловали',
#   'в',
#   'бдсм',
#   'игре'],
#  ['руководство', 'издание', 'четвертое', 'дополненное', 'и', 'переработанное'],
#  ['site', 'statistics'],
#  ['indian',
#   'sal',
#   'school',
#   'ladki',
#   'ki',
#   'chudai',
#   'sal',
#   'ke',
#   'boyfriend',
#   'ke',
#   'sath',
#   'full',
#   'hd',
#   'mobile',
#   'sex',
#   'hq',
#   'videos',
#   'watch',
#   'and',
#   'download',
#   'indian',
#   'sal',
#   'school',
#   'ladki',
#   'ki',
#   'chudai',
#   'sal',
#   'ke',
#   'boyfriend',
#   'ke',
#   'sath',
#   'full',
#   'hd',
#   'hot',
#   'porn',
#   'at',
#   'rajwap',
#   'xyz'],
#  ['проблема',
#   'сцепление',
#   'моего',
#   'камаза',
#   'дальнобойщики',
#   'всех',
#   'стран',
#   'объединяйтесь'],
#  ['барахолка', 'уфа'],
#  ['отзывы', 'о', 'антиперспирант', 'maxim'],
#  ['профиль', 'пользователя', 'oazistour', 'путешествия', 'и', 'отдых'],
#  ['как',
#   'связаться',
#   'с',
#   'оператором',
#   'триколор',
#   'тв',
#   'тыс',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['запрашиваемая', 'страница', 'не', 'найдена'],
#  ['zinchenko',
#   'roman',
#   'профиль',
#   'пользователя',
#   'фото',
#   'сайт',
#   'photosight',
#   'ru'],
#  ['just',
#   'cause',
#   'multiplayer',
#   'рс',
#   'русский',
#   'repack',
#   'скачать',
#   'торрент',
#   'игру',
#   'бесплатно',
#   'без',
#   'регистрации'],
#  ['mobil',
#   'programma',
#   'ziyo',
#   'music',
#   'com',
#   'o',
#   'yin',
#   'programma',
#   'temalar',
#   'ziyo',
#   'music',
#   'com',
#   'bass',
#   'lezginka',
#   'dubstep',
#   'club',
#   'musiclar'],
#  ['mero', 'lalala', 'official', 'music'],
#  ['решение', 'м', 'м', 'от', 'сентября', 'г', 'по', 'делу', 'судакт', 'ру'],
#  ['тип',
#   'заинтересовался',
#   'дыркой',
#   'опытной',
#   'женщины',
#   'и',
#   'выебал',
#   'ее',
#   'на',
#   'диване'],
#  ['пословицы', 'и', 'поговорки', 'про', 'дни', 'недели'],
#  [],
#  ['суккулент', 'крассула', 'купера', 'растения', 'во', 'владивостоке'],
#  ['сервисная',
#   'компания',
#   'буттэк',
#   'отзывы',
#   'фото',
#   'цены',
#   'телефон',
#   'и',
#   'адрес',
#   'сервисные',
#   'центры',
#   'москва',
#   'zoon',
#   'ru'],
#  ['фото',
#   'кпб',
#   'поплин',
#   'византия',
#   'графит',
#   'цена',
#   'руб',
#   'отдам',
#   'за',
#   'руб'],
#  ['доставка',
#   'продуктов',
#   'на',
#   'дом',
#   'в',
#   'елизово',
#   'и',
#   'камчатском',
#   'крае',
#   'адрес',
#   'телефон',
#   'карта',
#   'проезда'],
#  ['продается',
#   'автобус',
#   'toyota',
#   'hiace',
#   'автобусы',
#   'в',
#   'комсомольске',
#   'на',
#   'амуре'],
#  ['hentai', 'porn', 'videos', 'perfect', 'girls'],
#  ['для', 'тебя'],
#  ['impure',
#   'sarah',
#   's',
#   'life',
#   'update',
#   'inprogress',
#   'ver',
#   'sxs',
#   'hentai'],
#  ['саратов',
#   'дача',
#   'снт',
#   'архитектор',
#   'тыс',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['детский',
#   'лагерь',
#   'огонек',
#   'в',
#   'сергиевом',
#   'посаде',
#   'оздоровительный',
#   'лагерь',
#   'огонек',
#   'детский',
#   'отдых'],
#  ['мать', 'смотрит', 'как', 'отец', 'трахает', 'красавицу', 'дочь'],
#  ['читать',
#   'онлайн',
#   'книгу',
#   'единственная',
#   'для',
#   'барса',
#   'бесплатно',
#   'страница'],
#  ['купить', 'серебряный', 'браслет', 'br', 'glitter', 'в', 'беларуси'],
#  ['сонник',
#   'смотреть',
#   'мультфильм',
#   'приснился',
#   'к',
#   'чему',
#   'снится',
#   'смотреть',
#   'мультфильм',
#   'во',
#   'сне',
#   'видеть'],
#  ['ov', 'bazunova', 'list', 'ru', 'почта', 'mail', 'ru'],
#  ['р', 'ама', 'с', 'голой', 'гс', 'с', 'дс', 'с', 'кос', 'мис', 'с', 'ебенка'],
#  ['программы',
#   'для',
#   'бесплатного',
#   'создания',
#   'сайта',
#   'движки',
#   'joomla',
#   'wordpress',
#   'и',
#   'программная',
#   'оболочка',
#   'денвер',
#   'для',
#   'создания',
#   'виртуального',
#   'хостинга',
#   'на',
#   'домашнем',
#   'комп'],
#  ['федор',
#   'бондарчук',
#   'и',
#   'паулина',
#   'андреева',
#   'сыграли',
#   'свадьбу',
#   'в',
#   'петербурге'],
#  ['автокран', 'ивановец', 'кс', 'к', 'р', 'шасси', 'камаз', 'тонн'],
#  ['bob',
#   'dylan',
#   'joan',
#   'baez',
#   'blowing',
#   'in',
#   'the',
#   'wind',
#   'смотреть',
#   'видео',
#   'онлайн',
#   'в',
#   'моем',
#   'мире',
#   'lena'],
#  ['какое',
#   'ружье',
#   'лучше',
#   'мр',
#   'или',
#   'сайга',
#   'и',
#   'чем',
#   'популярное',
#   'оружие'],
#  ['детей',
#   'в',
#   'яслях',
#   'будут',
#   'обучать',
#   'по',
#   'инновационной',
#   'программе',
#   'российская',
#   'газета'],
#  ['знакомства', 'в', 'нерюнгри', 'сайт', 'знакомств', 'шуры', 'муры'],
#  ['насос',
#   'электрический',
#   'adrenalin',
#   'air',
#   'pump',
#   'mini',
#   'купить',
#   'в',
#   'москве',
#   'цена',
#   'фото',
#   'отзывы',
#   'и',
#   'характеристики'],
#  ['tut',
#   'by',
#   'работа',
#   'тут',
#   'поиск',
#   'работы',
#   'в',
#   'минске',
#   'и',
#   'беларуси'],
#  ['шар', 'латексный'],
#  ['гласная',
#   'буква',
#   'и',
#   'класс',
#   'конспект',
#   'и',
#   'презентация',
#   'урока',
#   'по',
#   'фгос',
#   'готовый',
#   'млн',
#   'результатов',
#   'поиск',
#   'mail',
#   'ru'],
#  ['гифки', 'поиск', 'на', 'сайте', 'fishki', 'net'],
#  ['lot', 'of', 'problems', 'перевод', 'и', 'примеры', 'предложений'],
#  ['галерея'],
#  ['ужасы', 'страница'],
#  ['октябрьский', 'почта', 'mail', 'ru'],
#  ['моя', 'реклама'],
#  ['бетостоун',
#   'быстросохнущая',
#   'двухкомпонентная',
#   'полиуретановая',
#   'грунт',
#   'эмаль',
#   'для',
#   'от',
#   'компании',
#   'рифорн',
#   'купить',
#   'в',
#   'городе',
#   'екатеринбург'],
#  ['поиск', 'работы', 'и', 'вакансий', 'undefined', 'зарплата', 'ру'],
#  ['cкачать', 'шашки', 'windows'],
#  ['фигурки',
#   'из',
#   'оникса',
#   'и',
#   'их',
#   'значение',
#   'в',
#   'древности',
#   'и',
#   'современности',
#   'для',
#   'удачи'],
#  ['каким',
#   'образом',
#   'обеспечивается',
#   'защита',
#   'прав',
#   'ребенка',
#   'в',
#   'рф',
#   'защита',
#   'прав',
#   'ребенка',
#   'в',
#   'российской',
#   'федерации'],
#  ['золото', 'древней', 'руси', 'черняев', 'а', 'ф'],
#  ['расстановка',
#   'героев',
#   'из',
#   'альянсов',
#   'человек',
#   'воин',
#   'чешуйчатый',
#   'охотник',
#   'неуловимый',
#   'убийца'],
#  ['print', 'ru', 'оперативная', 'цифровая', 'типография', 'в', 'краснодаре'],
#  ['каждому', 'по', 'тыкве'],
#  ['скачать', 'фильм', 'звездный', 'путь', 'на', 'телефон', 'gp', 'mp'],
#  ['teen',
#   'depression',
#   'residental',
#   'hilfe',
#   'вge',
#   'blonde',
#   'com',
#   'sex',
#   'teen'],
#  ['скачать',
#   'huwannuur',
#   'lirik',
#   'terjemah',
#   'abah',
#   'guru',
#   'sekumpul',
#   'смотреть',
#   'онлайн'],
#  ['поезда', 'самолеты', 'почта', 'mail', 'ru'],
#  ['запчасти',
#   'для',
#   'блендера',
#   'scarlett',
#   'sl',
#   'hb',
#   'm',
#   'им',
#   'деталюга'],
#  ['система',
#   'оповещения',
#   'и',
#   'управления',
#   'эвакуацией',
#   'статья',
#   'омега',
#   'саунд',
#   'россия'],
#  ['программа', 'обучения', 'по', 'охране', 'труда'],
#  ['толкование',
#   'карт',
#   'таро',
#   'разное',
#   'страница',
#   'тонкий',
#   'мир',
#   'эзотерический',
#   'форум',
#   'магия',
#   'гороскопы',
#   'гадания',
#   'заговоры',
#   'привороты',
#   'сонники',
#   'астр'],
#  ['крестный',
#   'отец',
#   'pocket',
#   'пьюзо',
#   'м',
#   'купить',
#   'в',
#   'амиталь',
#   'с',
#   'доставкой'],
#  ['порадую', 'вас', 'в', 'жопу', 'аделина', 'ишим', 'район', 'сто'],
#  ['мой', 'мир', 'mail', 'ru'],
#  ['подбор', 'шин', 'по', 'автомобилю'],
#  ['сварщик', 'пластмасс', 'еткс'],
#  ['фото', 'альбом', 'фото', 'группы', 'фото', 'фотографии', 'вязание'],
#  ['asian',
#   'milf',
#   'asa',
#   'akira',
#   'is',
#   'using',
#   'a',
#   'butplug',
#   'to',
#   'prepare',
#   'her',
#   'ass',
#   'for',
#   'a',
#   'massive',
#   'dick',
#   'perfect',
#   'girls'],
#  ['фото', 'тула', 'tatra', 't', 'b', 'su', 'transphoto'],
#  ['снабженец', 'экспедитор', 'водитель'],
#  ['видео',
#   'михаил',
#   'кононенко',
#   'видео',
#   'смотреть',
#   'онлайн',
#   'в',
#   'моем',
#   'мире'],
#  ['monster',
#   'energy',
#   'lime',
#   'green',
#   'эмблемы',
#   'для',
#   'gta',
#   'grand',
#   'theft',
#   'auto',
#   'v'],
#  ['german',
#   'guy',
#   'is',
#   'about',
#   'to',
#   'fuck',
#   'a',
#   'slutty',
#   'blonde',
#   'honey',
#   'in',
#   'a',
#   'public',
#   'place',
#   'during',
#   'the',
#   'day',
#   'ipad',
#   'porn',
#   'at',
#   'perfect',
#   'girls'],
#  ['купить',
#   'тормозную',
#   'систему',
#   'ssangyong',
#   'в',
#   'томске',
#   'сравнить',
#   'цены',
#   'на',
#   'тормозную',
#   'систему',
#   'ssangyong',
#   'в',
#   'томске',
#   'blizko'],
#  ['купить',
#   'dorken',
#   'delta',
#   'roof',
#   'дышащий',
#   'подкладочный',
#   'ковер',
#   'под',
#   'битумную',
#   'черепицу',
#   'фальцевую',
#   'кровлю',
#   'и',
#   'натуральный',
#   'сланец',
#   'цена',
#   'в',
#   'москве',
#   'на',
#   'roof',
#   'n',
#   'roll',
#   'ru'],
#  ['блондинка',
#   'с',
#   'пышной',
#   'грудью',
#   'занимается',
#   'сексом',
#   'с',
#   'мужем',
#   'после',
#   'свадьбы'],
#  ['сериал',
#   'обезьян',
#   'сезон',
#   'смотреть',
#   'онлайн',
#   'бесплатно',
#   'в',
#   'хорошем',
#   'качестве'],
#  ['юленька',
#   'лет',
#   'россия',
#   'альметьевск',
#   'trulolo',
#   'com',
#   'социальная',
#   'сеть',
#   'позволяющая',
#   'знакомится',
#   'и',
#   'общятся',
#   'с',
#   'людьми',
#   'отправляю',
#   'смс',
#   'и',
#   'еще',
#   'много',
#   'другое'],
#  ['видео',
#   'молодые',
#   'русское',
#   'порно',
#   'большие',
#   'дырки',
#   'мастурбация',
#   'красотки'],
#  ['новое', 'в', 'современном', 'обезболивании', 'животных'],
#  ['знакомства',
#   'рига',
#   'ольга',
#   'лет',
#   'бесплатный',
#   'сайт',
#   'знакомств',
#   'mobi',
#   'dating',
#   'ru',
#   'датинг',
#   'ру',
#   'бесплатный',
#   'мобильный',
#   'сайт',
#   'знакомств',
#   'для',
#   'серьезных',
#   'отношений',
#   'd'],
#  ['kiki', 'cyrus', 'a', 'hot', 'shower', 'an', 'old', 'man', 'sextorrent'],
#  ['шнур', 'ну', 'и', 'так', 'далее'],
#  ['анальная',
#   'азиатка',
#   'закатила',
#   'глаза',
#   'когда',
#   'на',
#   'нее',
#   'кончили',
#   'после',
#   'секса',
#   'rusex',
#   'club',
#   'me'],
#  ...]

# %%
cooccurence_title = Counter([(doc[i], doc[i + 1]) for doc in docs_title for i in range(len(doc) - 1)])

# %%
cooccurence_title.most_common(20)
# Out:
# [(('mail', 'ru'), 6701),
#  (('смотреть', 'онлайн'), 3820),
#  (('поиск', 'mail'), 3502),
#  (('результатов', 'поиск'), 2622),
#  (('купить', 'в'), 2107),
#  (('скачать', 'бесплатно'), 2012),
#  (('онлайн', 'бесплатно'), 1957),
#  (('читать', 'онлайн'), 1808),
#  (('в', 'хорошем'), 1629),
#  (('тыс', 'результатов'), 1611),
#  (('порно', 'видео'), 1529),
#  (('в', 'интернет'), 1529),
#  (('в', 'москве'), 1489),
#  (('интернет', 'магазине'), 1419),
#  (('интернет', 'магазин'), 1377),
#  (('хорошем', 'качестве'), 1361),
#  (('бесплатно', 'в'), 1315),
#  (('на', 'olx'), 1289),
#  (('мой', 'мир'), 1123),
#  (('мир', 'mail'), 1054)]

# %%
cooccurence_url = Counter([(doc[i], doc[i + 1]) for doc in docs_url for i in range(len(doc) - 1)])

# %%
cooccurence_url.most_common(20)
# Out:
# [(('mail', 'ru'), 7906),
#  (('drom', 'ru'), 2272),
#  (('xn', 'p'), 1455),
#  (('p', 'ai'), 1447),
#  (('com', 'ua'), 1258),
#  (('www', 'olx'), 1234),
#  (('baza', 'drom'), 1042),
#  (('olx', 'ua'), 949),
#  (('irecommend', 'ru'), 767),
#  (('cdn', 'ampproject'), 751),
#  (('ampproject', 'org'), 751),
#  (('youla', 'ru'), 750),
#  (('hh', 'ru'), 745),
#  (('daftsex', 'com'), 741),
#  (('babyblog', 'ru'), 721),
#  (('cian', 'ru'), 688),
#  (('fotostrana', 'ru'), 687),
#  (('s', 'mobi'), 669),
#  (('v', 's'), 668),
#  (('biqle', 'ru'), 658)]

# %% [markdown]
# ### Создание обработанного датасета

# %%
cleared_docs_sentence = [' '.join(text) for text in cleared_docs]

# %%
docs_url_sentence = [' '.join(text) for text in docs_url]

# %%
d = {'url':docs_url_sentence, 'title': cleared_docs_sentence, 'target': y_train}

# %%
train_dataset = pd.DataFrame(data=d)
train_dataset
# Out:
#                               url
# 0                         m kp md  \
# 1                       www kp by
# 2                   fanserials tv
# 3                 colorbox spb ru
# 4                   tula sport ru
# ...                           ...
# 135304                    mail ru
# 135305                 www ntv ru
# 135306  topclassiccarsforsale com
# 135307                wowcream ru
# 135308                 www ubu ru
#
#                                                     title  target
# 0       экс министр экономика молдова глава мидэи цель...       0
# 1       песня стать известный многий телезритель благо...       0
# 2         банши сезон серия бремя красота смотреть онлайн       0
# 3                                         бесить картинка       0
# 4       новомосковск сыграть следж хоккеист алексински...       0
# ...                                                   ...     ...
# 135304  пора тюльпан турецкий сериал русский язык резу...       0
# 135305      остросюжетный сериал шеф игра повышение серия       0
# 135306  plymouth special deluxe hot rod automatic smal...       0
# 135307  купить skin сыворотка питательный power formul...       0
# 135308    технический спирт канистра флакон купить москва       0
#
# [135309 rows x 3 columns]

# %%
SEED = 42
df_train, df_val = train_test_split(train_dataset, test_size=0.2, random_state=SEED)

# %%
df_train
# Out:
#                               url
# 36898                karat spb ru  \
# 69667            samara farfor ru
# 111124                  www zr ru
# 35818   xn htbdmodofzkc c xn p ai
# 123149                   porno co
# ...                           ...
# 110268             pornophoto pro
# 119879            multilisting su
# 103694               digital k by
# 131932            www citilink ru
# 121958               myzcloud pro
#
#                                                     title  target
# 36898   амиксидин продажа цена санкт петербург медицин...       0
# 69667                                       ультрасет new       0
# 111124  lada vesta cross видеообзор презентация серийн...       0
# 35818   фрезерный станок моделист cnc х мм продажа цен...       0
# 123149  популярный порно просмотр порнуха популярный с...       1
# ...                                                   ...     ...
# 110268                         смотреть бритый вагин фото       1
# 119879  продать трехкомнатную вторичку мкр олимпийский...       0
# 103694                            sharp dg купить минск k       0
# 131932  купить web камера logitech conferencecam rally...       0
# 121958  rnb gold classics скачать сборник бесплатно сл...       0
#
# [108247 rows x 3 columns]

# %%
df_val
# Out:
#                                url
# 54589            www kinotrast com  \
# 41071                        pc ru
# 19161         forum zoneofgames ru
# 75429                 librebook me
# 121091               meduniver com
# ...                            ...
# 67849              sdelairukami ru
# 30903             agroolkar com ua
# 43564               lyricshare net
# 67387             worldserials org
# 49332   xn sbpabhjc bdcg j xn p ai
#
#                                                     title  target
# 54589   сериал качели беларусь весь серия смотреть онл...       0
# 41071   шкаф спальный гарнитур энрике рубль грозный ан...       0
# 19161   swat close quarters battle русификатор zone ga...       0
# 75429   читать онлайн электронный книга прометей жизнь...       0
# 121091  научить щедрость собственный мужчина отучить м...       0
# ...                                                   ...     ...
# 67849   деревянный настольный лампа трансформер свой рука       0
# 30903   кормовой добавка сила природа дойный корова l ...       0
# 43564     текст песнь софия ротару белый зима слово песнь       0
# 67387   защитник protector сезон смотреть сериал онлай...       0
# 49332                                  поиск имя евфрасия       0
#
# [27062 rows x 3 columns]

# %%
df_train[df_train['target'] == 1].shape[0] / df_train.shape[0]
# Out:
# 0.12356000628192929

# %%
df_val[df_val['target'] == 1].shape[0] / df_val.shape[0]
# Out:
# 0.12342029413938364

# %% [markdown]
# ## Объединение признаков

# %%
def preprocessor(text):
    whitespaced_text = re.sub("[^a-zа-яё]", ' ', text.lower())
    return re.sub(' +', ' ',  whitespaced_text)

# %%
pipeline = Pipeline([
    (
        'features', 
        ColumnTransformer([
            (
                'url', 
                TfidfVectorizer(
            lowercase=True, ngram_range=(3, 6), analyzer='char',
            preprocessor=preprocessor, min_df=3, max_df=0.5
        ), 
                'url'
            ),
            (
                'title',
                TfidfVectorizer(
            lowercase=True, ngram_range=(3, 6), analyzer='char',
            preprocessor=preprocessor, min_df=3, max_df=0.5
        ), 
                'title'
            )
        ])
    ),
    ('clf', SGDClassifier(random_state=SEED, loss='modified_huber', class_weight='balanced'))
])

# %%
x_train = df_train[['url', 'title']]
y_train = df_train['target'].values

# %%
x_val = df_val[['url', 'title']]
y_val = df_val['target'].values

# %%
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('features',
#                  ColumnTransformer(transformers=[('url',
#                                                   TfidfVectorizer(analyzer='char',
#                                                                   max_df=0.5,
#                                                                   min_df=3,
#                                                                   ngram_range=(3,
#                                                                                6),
#                                                                   preprocessor=<function preprocessor at 0x000001FD48E77400>),
#                                                   'url'),
#                                                  ('title',
#                                                   TfidfVectorizer(analyzer='char',
#                                                                   max_df=0.5,
#                                                                   min_df=3,
#                                                                   ngram_range=(3,
#                                                                                6),
#                                                                   preprocessor=<function preprocessor at 0x000001FD48E77400>),
#                                                   'title')])),
#                 ('clf',
#                  SGDClassifier(class_weight='balanced', loss='modified_huber',
#                                random_state=42))])

# %%
f1_score(
    y_train,
    pipeline.predict(df_train)
)
# Out:
# 0.994973751815034

# %%
f1_score(
    y_val,
    pipeline.predict(df_val)
)
# Out:
# 0.9845739104388198

# %% [markdown]
# ## Обработака тестового датасета

# %%
docs_test_url = [tokenize(str(text)) for text in X_test['url']]
docs_test_title = [tokenize(str(text)) for text in X_test['title']]

# %%
lemmatized_docs_test = [[lemmatize(token) for token in text] for text in tqdm_notebook(docs_test_title)]

cleared_docs_test = [[token for token in text if token not in stopwords] for text in lemmatized_docs_test]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6012\250155301.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   lemmatized_docs_test = [[lemmatize(token) for token in text] for text in tqdm_notebook(docs_test_title)]
#   0%|          | 0/165378 [00:00<?, ?it/s]

# %%
cleared_docs_test
# Out:
# [['шесть',
#   'кассационный',
#   'суд',
#   'самар',
#   'начать',
#   'работа',
#   'разный',
#   'здание',
#   'фото',
#   'коммерсантъ'],
#  ['индексация',
#   'алименты',
#   'случай',
#   'производиться',
#   'каков',
#   'порядок',
#   'правило',
#   'процедура'],
#  ['женщина', 'империя', 'мех', 'part'],
#  ['небритый',
#   'волосатый',
#   'киска',
#   'порно',
#   'весь',
#   'страна',
#   'национальность',
#   'онлайн'],
#  [],
#  ['вакансия',
#   'мерчендайзер',
#   'визитный',
#   'рязань',
#   'группа',
#   'компания',
#   'open',
#   'поиск',
#   'работа',
#   'городработ',
#   'ру'],
#  ['смартфон',
#   'apple',
#   'iphone',
#   'xr',
#   'gb',
#   'чёрный',
#   'купить',
#   'интернет',
#   'магазин',
#   'фотосклад',
#   'ру',
#   'цена',
#   'отзыв',
#   'видео',
#   'обзор'],
#  ['духов',
#   'шкаф',
#   'siemens',
#   'hb',
#   'gys',
#   'r',
#   'sim',
#   'dealer',
#   'цена',
#   'москва'],
#  ['вакансия',
#   'аналитик',
#   'департамент',
#   'внедрение',
#   'информационный',
#   'система',
#   'crm',
#   'платформа'],
#  ['anomaly', 'defenders', 'v', 'торрент'],
#  ['убрать', 'запах', 'выгребной', 'ям'],
#  ['озаботить', 'старый', 'баба', 'порно', 'фотосессия'],
#  ['mia', 'khalifa', 'hot', 'video', 'смотреть', 'онлайн', 'наш'],
#  ['ещё', 'видеть', 'айдаприкол'],
#  ['развивать',
#   'игрушка',
#   'весы',
#   'тюлень',
#   'солнышко',
#   'игрушка',
#   'ребёнок',
#   'год'],
#  ['mdv', 'mdvs', 'w', 'drn', 'наружный', 'блок'],
#  ['дочь',
#   'кадыров',
#   'признать',
#   'самый',
#   'одарённый',
#   'ученик',
#   'чечня',
#   'яплакалъ'],
#  ['theenglishmansion',
#   'dominant',
#   'dolly',
#   'miss',
#   'jade',
#   'jones',
#   'used',
#   'dominant',
#   'dolly',
#   'pt',
#   'part',
#   'free',
#   'femdom',
#   'porn',
#   'videos',
#   'blog'],
#  ['рекомендация',
#   'учёт',
#   'жёсткость',
#   'диафрагма',
#   'стальной',
#   'профилировать',
#   'настил',
#   'покрытие'],
#  ['продажа',
#   'hyundai',
#   'grand',
#   'starex',
#   'год',
#   'уссурийск',
#   'отправка',
#   'регион',
#   'подробность',
#   'телефон',
#   'вап',
#   'сап',
#   'акпп',
#   'литр',
#   'вд',
#   'дизель',
#   'дилер'],
#  ['ерлан',
#   'тажибаев',
#   'безгранично',
#   'влюбить',
#   'казахский',
#   'женщина',
#   'yvision',
#   'kz'],
#  ['кулак',
#   'рот',
#   'запись',
#   'пользователь',
#   'валерий',
#   'id',
#   'сообщество',
#   'здоровье',
#   'новорождённый',
#   'категория',
#   'разный',
#   'babyblog',
#   'ru'],
#  ['триллер',
#   'смотреть',
#   'онлайн',
#   'хороший',
#   'качество',
#   'бесплатно',
#   'страница'],
#  ['картинка',
#   'megan',
#   'fox',
#   'рабочий',
#   'стол',
#   'скачать',
#   'обои',
#   'megan',
#   'fox',
#   'страница'],
#  ['портал',
#   'pierre',
#   'luxe',
#   'очаг',
#   'cassete',
#   'купить',
#   'интернет',
#   'магазин',
#   'электрокамин',
#   'владимир'],
#  ['найти', 'сумма', 'член', 'ариф', 'прогрессия', 'php', 'киберфорум'],
#  ['кед', 'кроссовок', 'женщина', 'cavalli', 'yoox', 'россия'],
#  ['скачать', 'экшен', 'игра', 'торрент', 'страница'],
#  ['товар', 'продажа', 'b', 'af', 'c'],
#  ['тест', 'русский', 'язык'],
#  ['гостиница',
#   'gregory',
#   'urban',
#   'москва',
#   'отзыв',
#   'отель',
#   'цена',
#   'фото',
#   'номер',
#   'забронировать',
#   'гостиница',
#   'gregory',
#   'urban',
#   'онлайн'],
#  ['марка', 'машина', 'буква', 'наш', 'марка', 'автомобиль', 'буква', 'наш'],
#  ['rapture',
#   'pieces',
#   'people',
#   'love',
#   'скачать',
#   'бесплатно',
#   'песня',
#   'mp'],
#  ['кронштейн',
#   'тв',
#   'наклонно',
#   'поворотный',
#   'resonans',
#   'ps',
#   'наличие',
#   'магазин',
#   'метр',
#   'видео',
#   'челябинск'],
#  ['niletto', 'скачать', 'бесплатно', 'mp', 'niletto'],
#  ['яичница', 'ветчина', 'яплакалъ'],
#  ['доставка'],
#  ['инвертор', 'барс', 'eko', 'arc', 'св'],
#  ['двадцатилетний',
#   'телок',
#   'свободный',
#   'время',
#   'красоваться',
#   'большой',
#   'жопа',
#   'прелесть',
#   'картинка'],
#  ['работа', 'контролёр', 'велик', 'новгород', 'вакансия', 'rabota', 'ru'],
#  ['вакансия',
#   'продавец',
#   'консультант',
#   'одежда',
#   'поиск',
#   'работа',
#   'запрос',
#   'продавец',
#   'консул'],
#  ['бал',
#   'свой',
#   'плата',
#   'даком',
#   'жирный',
#   'секс',
#   'бомба',
#   'анна',
#   'седокова',
#   'похвастаться',
#   'свой',
#   'роскошный',
#   'фигура',
#   'выставить',
#   'пc'],
#  ['огурец', 'форсаж', 'f'],
#  ['нелли', 'ржевский'],
#  ['alexis', 'kline', 'biqle', 'видео'],
#  ['цена',
#   'видеоняни',
#   'купить',
#   'минск',
#   'компания',
#   'vimart',
#   'интернет',
#   'магазин'],
#  ['результат', 'поиск', 'запрос', 'интернет', 'магазин', 'читать', 'город'],
#  ['вновь', 'кипр', 'октябрь', 'фото', 'фотография', 'оля', 'вейдман'],
#  ['просмотр', 'картинка', 'rusair', 'аэрофлот'],
#  ['номер',
#   'р',
#   'проверка',
#   'авто',
#   'гос',
#   'номер',
#   'бесплатно',
#   'новосибирский',
#   'область'],
#  ['признак', 'перфекционист'],
#  ['бывать', 'прицел', 'карта', 'слово', 'выражение', 'русский', 'язык'],
#  ['юлий', 'новороссийск', 'год', 'фото', 'страница'],
#  ['купить',
#   'детектор',
#   'газа',
#   'дом',
#   'светов',
#   'звуковой',
#   'сигнал',
#   'тревога',
#   'окись',
#   'углерод',
#   'угарный',
#   'газа',
#   'копоть',
#   'угольный',
#   'печь',
#   'сирена',
#   'брикет',
#   'детектор'],
#  ['пользователь', 'super', 'proстанки'],
#  ['фото',
#   'альбом',
#   'фото',
#   'группа',
#   'фото',
#   'фотография',
#   'мужской',
#   'журнал'],
#  ['приложение'],
#  ['функция', 'вид', 'социальный', 'норма'],
#  ['island', 'airboat', 'sportsman', 'sale', 'boats', 'usa'],
#  ['неактивно'],
#  ['stories',
#   'ass',
#   'рассказ',
#   'задница',
#   'эротика',
#   'порно',
#   'смотреть',
#   'онлайн',
#   'хороший',
#   'фильм',
#   'видео',
#   'erotik',
#   'tv',
#   'ru'],
#  ['мк',
#   'блок',
#   'газ',
#   'бизнес',
#   'дв',
#   'cummins',
#   'регулировка',
#   'скорость',
#   'вентилятор',
#   'отопитель',
#   'наш',
#   'оао',
#   'газ',
#   'мк',
#   'ut',
#   'мк',
#   'фото',
#   'цена',
#   'описа'],
#  ['city',
#   'travel',
#   'отзыв',
#   'клиент',
#   'покупатель',
#   'компания',
#   'google',
#   'chrome',
#   'kb'],
#  ['архив', 'уход', 'посадка'],
#  ['мужской',
#   'зимний',
#   'куртка',
#   'стиль',
#   'white',
#   'топовый',
#   'качество',
#   'ц',
#   'грн',
#   'купити',
#   'киев',
#   'prom',
#   'ua',
#   'id'],
#  ['zacharowa',
#   'odpowiedzia',
#   'owa',
#   'szefa',
#   'krld',
#   'dotycz',
#   'ce',
#   'ch',
#   'ci',
#   'przyst',
#   'pienia',
#   'rosji',
#   'wideo',
#   'rosyjska',
#   'wiosna'],
#  ['сидение', 'комплект', 'bmw', 'bmw', 'пить', 'автозапчасть', 'кемерово'],
#  ['joli', 'rouge', 'губный', 'помада', 'clarins'],
#  ['sweettpussysex', 'biqle', 'видео'],
#  ['погода',
#   'ростовский',
#   'область',
#   'россия',
#   'карта',
#   'район',
#   'ростовский',
#   'область',
#   'погода'],
#  ['тверь', 'троллейбус', 'transphoto'],
#  ['mercedes',
#   'benz',
#   'class',
#   'красноярск',
#   'отличный',
#   'состояние',
#   'обмен',
#   'рассмотреть',
#   'вариант',
#   'чёрный',
#   'автомат',
#   'седан',
#   'литр',
#   'бу',
#   'бензин',
#   'цена',
#   'тысяча',
#   'рубль'],
#  ['жареный', 'акула', 'рецепт', 'фото'],
#  ['толстовочка',
#   'купить',
#   'санкт',
#   'петербург',
#   'цена',
#   'рубль',
#   'дата',
#   'размещение',
#   'свитер',
#   'толстовка'],
#  ['сапог', 'ботинок', 'обувь', 'мальчик', 'answear', 'ua'],
#  ['фигурка',
#   'funko',
#   'pop',
#   'bobble',
#   'marvel',
#   'spider',
#   'man',
#   'green',
#   'goblin',
#   'характеристика',
#   'технический',
#   'описание',
#   'интернет',
#   'магазин',
#   'метр',
#   'видео',
#   'москва',
#   'москва'],
#  ['хорькин', 'борис', 'михайло', 'тренер', 'санкт', 'петербург'],
#  ['зимний', 'шина', 'bridgestone', 'nokian', 'continental', 'cordiant', 'r'],
#  ['поиск',
#   'глубокий',
#   'сон',
#   'каталог',
#   'торрент',
#   'x',
#   'torrent',
#   'pro',
#   'профессиональный',
#   'торрент',
#   'трекер',
#   'страница'],
#  ['мингазова',
#   'рузиля',
#   'саетгалиевна',
#   'уфа',
#   'тысяча',
#   'результат',
#   'поиск',
#   'mail',
#   'ru'],
#  ['восприятие', 'человек', 'человек', 'носить', 'специальный', 'название'],
#  [],
#  ['general', 'xmovies'],
#  ['porn',
#   'videos',
#   'malayalam',
#   'free',
#   'porn',
#   'sex',
#   'videos',
#   'xxx',
#   'movies'],
#  ['учебник', 'издательство', 'атамура', 'результат', 'поиск', 'mail', 'ru'],
#  ['наруто',
#   'naruto',
#   'смотреть',
#   'сериал',
#   'онлайн',
#   'cкачать',
#   'торрент',
#   'бесплатно'],
#  ['разница', 'фантастика', 'фентези'],
#  ['библиотерапия', 'лечение', 'книга', 'книга', 'страница'],
#  ['правовой',
#   'основа',
#   'деятельность',
#   'союз',
#   'общественный',
#   'объединение',
#   'audit',
#   'ru'],
#  ['малония',
#   'гибридный',
#   'яблоня',
#   'айвовый',
#   'гибрид',
#   'купить',
#   'ростов',
#   'malonia',
#   'hybrid',
#   'cydomalus',
#   'плодовый',
#   'саженец',
#   'фруктовый',
#   'дерево',
#   'привить',
#   'форма',
#   'купить',
#   'растение',
#   'ростов',
#   'дон',
#   'интернет',
#   'магазин',
#   'питомник',
#   'растение',
#   'хвойный',
#   'лиственный',
#   'уличный',
#   'плодовый',
#   'де'],
#  ['вакансия', 'мастер', 'участок', 'волгоград', 'работа', 'ата', 'группа'],
#  ['узи', 'неделя', 'день', 'блог', 'бэтэшка'],
#  ['суперотношения',
#   'любовь',
#   'семья',
#   'наладить',
#   'сберечь',
#   'илья',
#   'шабшин'],
#  ['кормление', 'ягнёнок', 'норма', 'схема', 'кормление', 'таблица'],
#  ['январь',
#   'обрезание',
#   'господний',
#   'история',
#   'христианский',
#   'смысл',
#   'крестовоздвиженск'],
#  ['dll', 'files'],
#  ['видео',
#   'анал',
#   'брюнетка',
#   'красотка',
#   'brazzers',
#   'free',
#   'porn',
#   'videos',
#   'смотр'],
#  ['римма', 'авшалумов', 'убийца', 'неизвестный'],
#  ['детальный',
#   'разбор',
#   'google',
#   'показать',
#   'конференция',
#   'flutterlive',
#   'это'],
#  ['задвижка',
#   'ду',
#   'число',
#   'бр',
#   'аналог',
#   'число',
#   'бр',
#   'вода',
#   'пара',
#   'эл',
#   'привод',
#   'купить',
#   'бел',
#   'рубль',
#   'шт',
#   'минск',
#   'компания',
#   'чтуп',
#   'эймост',
#   'продажа',
#   'юр',
#   'литр'],
#  ['v', 'p', 'zoopark', 'answers', 'likes', 'askfm'],
#  ['ютуб',
#   'валер',
#   'желейный',
#   'медведь',
#   'новое',
#   'серия',
#   'тысяча',
#   'ролик',
#   'поиск',
#   'mail',
#   'ru'],
#  ['ст',
#   'льц',
#   'дк',
#   'код',
#   'сид',
#   'ння',
#   'ст',
#   'льц',
#   'супутн',
#   'вироби',
#   'частини'],
#  ['охранник', 'брат', 'brother', 'keeper', 'kinomania', 'ru'],
#  ['состязательный',
#   'рынок',
#   'концепция',
#   'состязательный',
#   'рынок',
#   'предложить',
#   'начало',
#   'х',
#   'год'],
#  ['ивановский', 'барахолка', 'ivbb', 'ru', 'x', 'moto', 'raptor', 'кроссовый'],
#  ['зеркало', 'тумба', 'машенька', 'цена', 'рубль', 'каталог', 'выборг'],
#  ['менять',
#   'задний',
#   'поводок',
#   'дворник',
#   'лачетти',
#   'поводок',
#   'рио',
#   'весь',
#   'шевроле',
#   'chevrolet',
#   'фото',
#   'видео',
#   'ремонт',
#   'отзыв'],
#  ['комнатный',
#   'квартира',
#   'метр',
#   'купить',
#   'рубль',
#   'пермь',
#   'улица',
#   'докучаев',
#   'move',
#   'ru'],
#  ['интернет',
#   'магазин',
#   'видео',
#   'настольный',
#   'игра',
#   'gamepull',
#   'красноармейский',
#   'улица',
#   'отзыв',
#   'фото',
#   'каталог',
#   'товар',
#   'цена',
#   'телефон',
#   'адрес',
#   'добраться',
#   'магазин',
#   'ростов',
#   'дон',
#   'zoon',
#   'ru'],
#  ['микаел',
#   'минасян',
#   'нынешний',
#   'власть',
#   'вместо',
#   'новый',
#   'армения',
#   'выбрать',
#   'армения',
#   'фейсбука',
#   'аrm',
#   'portal',
#   'ru',
#   'хороший',
#   'армянский',
#   'интернет',
#   'портал'],
#  ['женщина', 'год', 'жить', 'единственный', 'партнёр', 'обнаружить', 'вич'],
#  ['робертс',
#   'нора',
#   'смерть',
#   'иметь',
#   'лицо',
#   'электронный',
#   'библиотека',
#   'libra',
#   'ru'],
#  ['знакомство',
#   'новосибирск',
#   'мужчина',
#   'возраст',
#   'год',
#   'нгс',
#   'знакомство'],
#  ['тётя', 'старательно', 'соснуть', 'молодой', 'племянник'],
#  ['воздушный',
#   'вентилятор',
#   'метр',
#   'час',
#   'тысяча',
#   'результат',
#   'поиск',
#   'mail',
#   'ru'],
#  ['hausgemachte',
#   'ffm',
#   'interracial',
#   'dreier',
#   'der',
#   'sauna',
#   'free',
#   'ebenholz',
#   'amateur',
#   'porn',
#   'cock',
#   'sharing',
#   'mp',
#   'video',
#   'justporno',
#   'sex'],
#  ['giorgiocasa', 'найти', 'запрос', 'мягкий', 'мебель'],
#  ['купить',
#   'инфинити',
#   'ку',
#   'россия',
#   'продажа',
#   'infiniti',
#   'q',
#   'пробег',
#   'новый',
#   'цена'],
#  ['продавать',
#   'двухкомнатную',
#   'квартира',
#   'метр',
#   'москва',
#   'нао',
#   'новомосковский',
#   'внуковский',
#   'поселение',
#   'внуково',
#   'посёлок',
#   'дск',
#   'московский',
#   'писатель',
#   'посёлок',
#   'метр'],
#  ['купить',
#   'бинокль',
#   'телескоп',
#   'больший',
#   'увеличение',
#   'интернет',
#   'магазин',
#   'метр',
#   'видео',
#   'низкий',
#   'цена',
#   'отзыв',
#   'владелец',
#   'большой',
#   'каталог',
#   'описание',
#   'ха'],
#  ['povd', 'порно', 'видео', 'страница'],
#  ['скачать', 'shahzoda', 'xalid', 'photo', 'смотреть', 'онлайн'],
#  ['самый',
#   'отвратительный',
#   'животное',
#   'вид',
#   'который',
#   'обязательно',
#   'сказать',
#   'фуу'],
#  ['николай', 'александр', 'радиодеталь', 'эхо', 'москва'],
#  ['скачать', 'книга', 'род', 'сергей', 'александр', 'давыдов'],
#  ['download',
#   'sharon',
#   'tate',
#   'tra',
#   'incubo',
#   'realtа',
#   'p',
#   'x',
#   'h',
#   'ilcorsaronero',
#   'noiveneto'],
#  ['скачать', 'фильм', 'дрожь', 'земля', 'mp', 'телефон', 'бесплатно'],
#  ['диван', 'прямая', 'ульяновск', 'цена', 'столплит', 'страница'],
#  ['самый',
#   'дело',
#   'сказать',
#   'задержать',
#   'украина',
#   'российский',
#   'десантник',
#   'видео'],
#  ['делать', 'модем', 'гореть', 'мигать', 'лампочка', 'dsl'],
#  ['купить', 'батут', 'дом', 'улица', 'ставрополь'],
#  ['саундтрек',
#   'диктатор',
#   'скачать',
#   'слушать',
#   'онлайн',
#   'всесаундтреки',
#   'рф'],
#  ['кукла',
#   'коллекционный',
#   'парочка',
#   'лена',
#   'семён',
#   'наряд',
#   'клеточка',
#   'набор',
#   'шт',
#   'сантиметр',
#   'микс',
#   'купить',
#   'цена',
#   'рубль',
#   'интернет',
#   'магазин',
#   'sima',
#   'lan'],
#  ['филиал',
#   'расписание',
#   'тренировка',
#   'ано',
#   'спортивный',
#   'клуб',
#   'гимнастика',
#   'школа',
#   'ольга',
#   'капрановой'],
#  ['бумага', 'высокий', 'печать', 'это', 'бумага', 'высокий', 'печать'],
#  ['добавление',
#   'рассылка',
#   'империя',
#   'коучей',
#   'коучинг',
#   'константин',
#   'опекун'],
#  ['потап', 'настя', 'свадьба', 'слушать', 'онлайн', 'бесплатно'],
#  ['результат', 'оплата'],
#  ['пятница', 'е'],
#  ['пышка', 'biqle', 'видео'],
#  ['программа', 'opportunity', 'портал', 'meet', 'usa'],
#  ['аренда',
#   'однокомнатный',
#   'студия',
#   'длительный',
#   'срок',
#   'екатеринбург',
#   'ленинский',
#   'район',
#   'фото',
#   'n',
#   'ru',
#   'екатеринбург'],
#  ['результат', 'поиск', 'маслёнка'],
#  ['скачать', 'свой', 'музлишко', 'красивый', 'сегодня', 'музыка', 'онлайн'],
#  ['watch',
#   'online',
#   'free',
#   'tv',
#   'shows',
#   'full',
#   'episodes',
#   'vd',
#   'kinogo',
#   'fr'],
#  ['читать',
#   'книга',
#   'удержать',
#   'окова',
#   'сердце',
#   'страница',
#   'библиотека',
#   'книга'],
#  ['html', 'заглушка', 'сайт', 'страница', 'web', 'exito', 'ru'],
#  ['anal', 'young', 'teens', 'xxx', 'nude', 'gallery', 'comments'],
#  ['корпоративный',
#   'сотовый',
#   'связь',
#   'интернет',
#   'официальный',
#   'сайт',
#   'мегафон',
#   'московский',
#   'регион'],
#  ['личный', 'кабинет'],
#  ['читать', 'манга', 'драгон', 'болл', 'глава', 'русский', 'онлайн'],
#  ['жк',
#   'династия',
#   'ул',
#   'василий',
#   'липковского',
#   'год',
#   'ковальский',
#   'страница',
#   'forum',
#   'domik',
#   'ua'],
#  ['троп',
#   'бог',
#   'вид',
#   'обсуждение',
#   'liveinternet',
#   'российский',
#   'сервис',
#   'онла'],
#  ['гжатский', 'улица', 'карта', 'гагарин', 'номер', 'дом', 'mapdata', 'ru'],
#  ['скачать',
#   'бесплатно',
#   'назар',
#   'страна',
#   'полынь',
#   'mp',
#   'слушать',
#   'музыка',
#   'онлайн',
#   'зайцев',
#   'регистрация'],
#  ['микро',
#   'джига',
#   'головка',
#   'gamakatsu',
#   'кр',
#   'гр',
#   'купить',
#   'харьков',
#   'хороший',
#   'цена'],
#  ['дисконт', 'минский', 'гум', 'gum'],
#  ['иосиф', 'кобзон', 'мгновение'],
#  ['nizami',
#   'stansiyas',
#   'nda',
#   'eskalatorun',
#   'sasl',
#   'miri',
#   'ba',
#   'зat',
#   'b',
#   'sahil'],
#  ['сервис', 'контекстный', 'реклама', 'поиск', 'mail', 'ru'],
#  ['тапочки', 'следок', 'спица'],
#  ['aurora',
#   'concert',
#   'hall',
#   'аврор',
#   'концертный',
#   'зал',
#   'санкт',
#   'петербург',
#   'клуб',
#   'аврор',
#   'санк'],
#  ['тендер',
#   'отрасль',
#   'ремонтный',
#   'строительный',
#   'работа',
#   'орехово',
#   'зуево',
#   'найти',
#   'тендер'],
#  ['жениться',
#   'казашка',
#   'шотландец',
#   'ваш',
#   'женщина',
#   'злой',
#   'новость',
#   'казахстан',
#   'tengrinews'],
#  ['купить',
#   'лексус',
#   'иса',
#   'ф',
#   'б',
#   'продажа',
#   'автомобиль',
#   'lexus',
#   'f',
#   'пробег',
#   'россия',
#   'цена',
#   'бу',
#   'авто'],
#  ['super', 'discoteka', 'cd', 'flac'],
#  ['год', 'сен', 'смотреть', 'видео', 'онлайн', 'мыть', 'мир'],
#  [],
#  ['porn',
#   'jem',
#   'stone',
#   'free',
#   'porn',
#   'sex',
#   'pics',
#   'pornsexer',
#   'xxx',
#   'movies',
#   'hd'],
#  ['диск', 'volkswagen', 'tiguan', 'n', 'tsi', 'motion', 'r'],
#  ['каталог', 'машина', 'разметка', 'дорога', 'компания', 'активатор'],
#  ['марьиногорская',
#   'городской',
#   'библиотека',
#   'результат',
#   'поиск',
#   'mail',
#   'ru'],
#  ['продавать',
#   'дом',
#   'метр',
#   'ул',
#   'профсоюзный',
#   'башкортостан',
#   'респ',
#   'белорецкий',
#   'район',
#   'азикеевский',
#   'сельсовет',
#   'буганак',
#   'сесть',
#   'база',
#   'циан',
#   'объявление'],
#  ['проверка',
#   'датчик',
#   'abs',
#   'личный',
#   'опыт',
#   'блог',
#   'датчик',
#   'abs',
#   'работать'],
#  ['володимир',
#   'год',
#   'украина',
#   'львов',
#   'познакомиться',
#   'девушка',
#   'возраст',
#   'год',
#   'сеть',
#   'знакомство',
#   'мамба'],
#  ['абаканец', 'показать', 'хороший', 'образец', 'боев', 'машина', 'пожарный'],
#  [],
#  ['lara', 'lvarez', 'estrena', 'novio', 'exfutbolista', 'modelo'],
#  ['ооо', 'гк', 'юстэкс', 'вистино', 'инна', 'огрн', 'телефон', 'реквиз'],
#  ['девка',
#   'обожать',
#   'киска',
#   'проникать',
#   'одновременно',
#   'член',
#   'luna',
#   'lovely',
#   'daft'],
#  ['робкий', 'неуверенный', 'это', 'робкий', 'неуверенный'],
#  ['объектив',
#   'canon',
#   'ef',
#   'mm',
#   'f',
#   'l',
#   'ii',
#   'usm',
#   'характеристика',
#   'технический',
#   'описание',
#   'интернет',
#   'магазин',
#   'метр',
#   'видео',
#   'москва'],
#  ['карпов', 'вадим', 'юрий', 'защитник', 'karpov', 'vadim', 'yurievich'],
#  ['фск', 'отказываться', 'лидер', 'газета', 'коммерсантъ'],
#  ['лариса', 'матвеев', 'видео', 'mail', 'ru'],
#  ['воскресенский', 'угличский', 'мужской', 'монастырь'],
#  ['ночь', 'рождество', 'спектакль', 'минск', 'afisha', 'tut'],
#  ['korolys', 'victorycraft', 'ru', 'игровой', 'сервис', 'игра', 'minecraft'],
#  ['мехрнигор', 'рустам', 'скачат', 'секс', 'таджичка', 'душанбе'],
#  [],
#  ['черничный', 'пирог', 'рецепт', 'фото', 'webspoon', 'ru'],
#  ['страница', 'кошка', 'старший', 'год', 'goods', 'ru'],
#  ['анатолий',
#   'могилевский',
#   'робик',
#   'чёрный',
#   'диалог',
#   'скачать',
#   'бесплатно',
#   'песня',
#   'mp'],
#  ['проект', 'росток', 'жизнь', 'беседа', 'oznobishino'],
#  ['диана', 'дубовик'],
#  ['visit', 'abroad', 'визит', 'граница'],
#  ['брать', 'сандра', 'женский', 'шапка', 'хлопок', 'лен'],
#  ['примета', 'лис', 'перебежать', 'дорога', 'примета'],
#  ['матрас',
#   'склад',
#   'наличие',
#   'новый',
#   'матрац',
#   'бесплатный',
#   'доставка',
#   'тг',
#   'мебель',
#   'спальня',
#   'алматы',
#   'olx'],
#  ['мощность', 'выбрать', 'лампочка', 'освещённость', 'лк'],
#  ['михаил', 'боярский', 'моцарт'],
#  ['радикал', 'фото', 'картинка'],
#  ['цена',
#   'монета',
#   'тенге',
#   'год',
#   'стоимость',
#   'аукцион',
#   'описание',
#   'фото'],
#  ['ssc',
#   'самый',
#   'дорогой',
#   'автомобиль',
#   'цена',
#   'рейтинг',
#   'стоимость',
#   'ssc'],
#  ['продать',
#   'швейный',
#   'машинка',
#   'сума',
#   'швейный',
#   'машина',
#   'оверлоки',
#   'ташкент',
#   'olx'],
#  ['курс',
#   'валюта',
#   'обменниках',
#   'нурсултан',
#   'сегодня',
#   'результат',
#   'поиск',
#   'mail',
#   'ru'],
#  ['двоевластие', 'интернет', 'газета', 'зонакз', 'казахстан'],
#  ['ах',
#   'свадьба',
#   'муслим',
#   'магомаев',
#   'скачать',
#   'бесплатно',
#   'mp',
#   'ах',
#   'свадьба',
#   'муслим',
#   'маг'],
#  ['сайт', 'крафтящих', 'значок', 'steam', 'форум', 'miped', 'ru'],
#  ['авто',
#   'опель',
#   'астр',
#   'год',
#   'барнаул',
#   'автомобиль',
#   'отс',
#   'седан',
#   'бензин',
#   'серебристый',
#   'акпп',
#   'литр'],
#  ['внешний', 'импульс', 'прогрессировать', 'сложный', 'система'],
#  ['piper',
#   'perri',
#   'переспать',
#   'двоюродный',
#   'брат',
#   'brazzers',
#   'sex',
#   'new',
#   'hd',
#   'tits',
#   'milf',
#   'anal',
#   'анал',
#   'новое',
#   'жёсткий',
#   'порн',
#   'biqle',
#   'видео'],
#  ['hyundai',
#   'экскаватор',
#   'улаанбаатар',
#   'далее',
#   'unegui',
#   'mn',
#   'нэг',
#   'й',
#   'зарууд',
#   'худалдаж',
#   'авна',
#   'зара'],
#  ['ростов', 'бавария', 'ноябрь', 'обзор', 'матч', 'чемпионат'],
#  ['gina',
#   'valentina',
#   'abella',
#   'danger',
#   'порно',
#   'porno',
#   'perfect',
#   'porn',
#   'movie'],
#  ['yuu',
#   'shinoda',
#   'rina',
#   'ishihara',
#   'rbd',
#   'yuu',
#   'shinoda',
#   'big',
#   'tits',
#   'rina',
#   'ishihara',
#   'slut',
#   'glasses',
#   'video',
#   'jav',
#   'net',
#   'jav',
#   'download'],
#  ['подбор',
#   'запчасть',
#   'vin',
#   'код',
#   'поиск',
#   'запчасть',
#   'вино',
#   'код',
#   'онлайн',
#   'заказать',
#   'автоз'],
#  ['интернет',
#   'провайдер',
#   'запорожский',
#   'приозерский',
#   'район',
#   'ленинградский',
#   'область',
#   'подключить',
#   'интернет',
#   'адрес',
#   'дом',
#   'запорожский',
#   'приозерс'],
#  ['вакансия',
#   'комплектовщик',
#   'склад',
#   'мегион',
#   'работа',
#   'компания',
#   'jobtime',
#   'работа',
#   'вахтовый',
#   'метод'],
#  ['взаимосвязь', 'постоянный', 'переменный', 'капиталь'],
#  ['эльза', 'альметьевск'],
#  ['учитель',
#   'медленно',
#   'оттрахал',
#   'студентка',
#   'юбка',
#   'курение',
#   'территория',
#   'университет',
#   'смотреть',
#   'скачать',
#   'порно',
#   'бесплатно'],
#  ['работа', 'нижний', 'тагил', 'сантехник'],
#  ['объявление',
#   'продажа',
#   'комнатный',
#   'квартира',
#   'новосибирск',
#   'ул',
#   'гоголь',
#   'нгс',
#   'жилой'],
#  ['фотография', 'отель', 'мирабель', 'фото', 'анапа'],
#  ['практикум', 'решение', 'задача', 'тема', 'quot', 'металл', 'quot'],
#  ['искать',
#   'работа',
#   'личный',
#   'авто',
#   'транспорт',
#   'логистика',
#   'нур',
#   'султан',
#   'астан',
#   'olx'],
#  ['спальный',
#   'мешок',
#   'carinthia',
#   'tropen',
#   'купить',
#   'москва',
#   'цена',
#   'рубль',
#   'дата',
#   'размещение',
#   'туризм',
#   'отдых',
#   'природа'],
#  ['mostbet', 'bahis', 'irketi', 'online', 'spor', 'bahisleri'],
#  ['supah', 'hot', 'step', 'mommy', 'stepson', 'sex', 'movies'],
#  ['снять',
#   'квартира',
#   'рабочий',
#   'посёлок',
#   'навле',
#   'навлинский',
#   'р',
#   'наш',
#   'посредник',
#   'аренда',
#   'квартира',
#   'рабочий',
#   'посёлок',
#   'навле',
#   'навлинский',
#   'р',
#   'наш',
#   'недорого',
#   'хозяин',
#   'агентство'],
#  ['annabel', 'alesana', 'official', 'video', 'sub', 'espaсol'],
#  ['алексей', 'михайличенко', 'новость', 'биография', 'фото', 'публикация'],
#  ['шуточный',
#   'фальшивый',
#   'деньга',
#   'доллар',
#   'штука',
#   'деньга',
#   'выкуп',
#   'невеста',
#   'продажа',
#   'цена',
#   'алматы',
#   'сувенирный',
#   'деньга',
#   'интернет',
#   'магазин',
#   'полезный',
#   'товар',
#   'landuken',
#   'kz'],
#  ['рифма', 'слово', 'трещать'],
#  ['архив', 'дисней'],
#  ['sunlight', 'brilliant', 'карта', 'сайт'],
#  ['коломна', 'тепло', 'сервис'],
#  ['правило', 'русский', 'язык', 'класс', 'комплект', 'карточка'],
#  ['акция',
#   'качественный',
#   'набор',
#   'инструмент',
#   'головка',
#   'отвёртка',
#   'грн',
#   'ручной',
#   'инструмент',
#   'винница',
#   'olx'],
#  ['indian',
#   'virgin',
#   'moaning',
#   'porn',
#   'videos',
#   'free',
#   'new',
#   'porn',
#   'sex',
#   'videos',
#   'xxx',
#   'movies'],
#  ['песок', 'доставка', 'гродно', 'район', 'гродно', 'slanet'],
#  ['сергей', 'савельев', 'рига', 'латвия', 'год', 'мир', 'mail', 'ru'],
#  ['тест',
#   'самоконтроль',
#   'введение',
#   'психолого',
#   'педагогический',
#   'деятельность',
#   'учебн'],
#  ['подборка', 'тендер', 'почта', 'mail', 'ru'],
#  ['обои', 'тема', 'американский', 'модель', 'актриса'],
#  ['arxiv', 'ьzr', 'axtar', 'ejob'],
#  ['gismeteo',
#   'погода',
#   'горка',
#   'завтра',
#   'прогноз',
#   'погода',
#   'завтра',
#   'краснопольский',
#   'район',
#   'могилёвская',
#   'область',
#   'беларусь'],
#  ['девственник', 'гэблдон', 'диана', 'читать', 'онлайн', 'knigger'],
#  ['nyomi', 'banxxx', 'porn', 'videos', 'perfect', 'girls'],
#  ['слуга',
#   'дьявол',
#   'скупщик',
#   'людская',
#   'душа',
#   'история',
#   'продажа',
#   'душа',
#   'мир',
#   'тайна'],
#  ['сумеречный',
#   'дева',
#   'амнезия',
#   'dusk',
#   'maiden',
#   'amnesia',
#   'tasogare',
#   'otome',
#   'x',
#   'amnesia',
#   'смотреть',
#   'онлайн',
#   'бесплатно',
#   'gidfilm',
#   'ru',
#   'красвью'],
#  ['cent',
#   'suid',
#   'afrika',
#   'afryka',
#   'po',
#   'udniowa',
#   'cena',
#   'monety',
#   'ucoin',
#   'net'],
#  ['результат', 'поиск', 'originalam', 'net'],
#  ['профиль',
#   'ёжкин',
#   'кот',
#   'персональный',
#   'страница',
#   'пользователь',
#   'liveinternet',
#   'ru'],
#  ['оксана',
#   'год',
#   'россия',
#   'курск',
#   'познакомиться',
#   'парень',
#   'познакомиться',
#   'парень',
#   'це'],
#  ['отличаться',
#   'антуриум',
#   'спатифиллума',
#   'дача',
#   'сад',
#   'огород',
#   'комнатный',
#   'растение'],
#  ['почему', 'скрипеть', 'кровать', 'это', 'делать'],
#  ['объектив',
#   'гелиос',
#   'легендарный',
#   'закрутить',
#   'бок',
#   'супермакро',
#   'просто',
#   'отличн'],
#  ['репетитор',
#   'корейский',
#   'язык',
#   'грозный',
#   'ассоциация',
#   'репетитор',
#   'грозный'],
#  ['bj', 'torrent', 'videolike'],
#  ['застрелить',
#   'квартира',
#   'воронежец',
#   'оказаться',
#   'знакомый',
#   'обвинять',
#   'сутенёрство',
#   'адвокат',
#   'риа',
#   'воронеж'],
#  ['людмила',
#   'год',
#   'марьин',
#   'горка',
#   'фотография',
#   'сайт',
#   'знакомство',
#   'tabor',
#   'ru'],
#  ['фильм',
#   'похожий',
#   'сериал',
#   'стандарт',
#   'красота',
#   'сезон',
#   'скачать',
#   'смотреть',
#   'онлайн'],
#  ['охота',
#   'jagten',
#   'смотреть',
#   'онлайн',
#   'hd',
#   'качество',
#   'отзыв',
#   'кадр',
#   'фильм',
#   'актёр',
#   'кино',
#   'mail',
#   'ru'],
#  ['reflex',
#   'polska',
#   'w',
#   'w',
#   'brze',
#   'sklep',
#   'internetowy',
#   'reflex',
#   'polska',
#   'w',
#   'brze',
#   'polska'],
#  ['гленн',
#   'клоуз',
#   'glenn',
#   'close',
#   'фотография',
#   'голливудский',
#   'актриса',
#   'кино',
#   'театр',
#   'ру'],
#  ['саженец',
#   'голубика',
#   'высокорослый',
#   'цена',
#   'рубль',
#   'купить',
#   'берёза',
#   'deal',
#   'id'],
#  ['история',
#   'фамилия',
#   'свидрак',
#   'значение',
#   'происхождение',
#   'фамилия',
#   'свидрак'],
#  ['john', 'ch', 'коллекция', 'монета', 'ucoin', 'net'],
#  ['вакансия',
#   'специалист',
#   'охрана',
#   'труд',
#   'техника',
#   'безопасность',
#   'улан',
#   'удэ',
#   'работа'],
#  ['вакансия',
#   'фотограф',
#   'автомобиль',
#   'москва',
#   'работа',
#   'фотограф',
#   'автомобиль'],
#  ['создатель',
#   'острый',
#   'козырёк',
#   'снять',
#   'харди',
#   'минь',
#   'сериал',
#   'кино',
#   'mail',
#   'ru'],
#  ['рамблер', 'касса'],
#  ['private',
#   'holidays',
#   'make',
#   'blanche',
#   'bradburry',
#   'blanche',
#   'bradburry',
#   'blowjob',
#   'free',
#   'adult',
#   'videos'],
#  ['мужской',
#   'кроссовок',
#   'nike',
#   'air',
#   'max',
#   'react',
#   'phantom',
#   'university',
#   'gold',
#   'university',
#   'red'],
#  ['тайна', 'муж'],
#  ['купить',
#   'умный',
#   'колонка',
#   'яндекс',
#   'станция',
#   'интернет',
#   'магазин',
#   'ситилинк',
#   'цена',
#   'умный',
#   'колонка',
#   'яндекс',
#   'станция',
#   'тверь'],
#  ['столото', 'квитанция'],
#  ['купить',
#   'рено',
#   'логан',
#   'донецк',
#   'продажа',
#   'renault',
#   'logan',
#   'пробег',
#   'новый',
#   'цена'],
#  ['купить',
#   'грузовик',
#   'маз',
#   'x',
#   'грузоподъёмность',
#   'килограмм',
#   'барнаул',
#   'цена',
#   'грузовик',
#   'тонна',
#   'фото'],
#  ['бижутерия', 'брошь', 'страница'],
#  ['скачать', 'модель', 'benelli', 'cs', 'бесплатно', 'страница'],
#  ['realt', 'ошибка', 'страница', 'найти', 'new'],
#  ['купить',
#   'круг',
#   'отрезной',
#   'абразивный',
#   'металл',
#   'луга',
#   'х',
#   'х',
#   'мм',
#   'луга',
#   'абразив',
#   'ярославль',
#   'цена',
#   'отзыв',
#   'характеристика',
#   'доставка',
#   'гаран'],
#  ['товар',
#   'услуга',
#   'компания',
#   'спутниковый',
#   'комплект',
#   'триколор',
#   'нтв',
#   'телекарта',
#   'мтс'],
#  ['фото', 'альбом', 'портфолио', 'свадьба', 'константин', 'ягодзинский'],
#  ['порно', 'zazie', 'skymm', 'скачать', 'смотреть', 'бесплатно'],
#  ['результат',
#   'поиск',
#   'мм',
#   'килограмм',
#   'sn',
#   'pb',
#   'cf',
#   'флюса',
#   'ra',
#   'припой',
#   'asahi'],
#  ['резюме', 'сварщик', 'канск', 'иван', 'концеренко', 'год', 'обновить'],
#  ['patalp',
#   'valymas',
#   'kaune',
#   'veiveri',
#   'gatv',
#   'je',
#   'ainava',
#   'kauno',
#   'padalinys',
#   'uab'],
#  ['контент',
#   'план',
#   'реализация',
#   'тв',
#   'контент',
#   'менеджер',
#   'удалённый',
#   'фриланс',
#   'fl',
#   'ru'],
#  ['порно', 'фото', 'смотреть', 'бесплатно', 'hotelki', 'net'],
#  ['знакомство',
#   'минск',
#   'анна',
#   'год',
#   'страна',
#   'встреча',
#   'сайт',
#   'знакомство',
#   'серьёзный',
#   'отношение',
#   'общение'],
#  ['materials',
#   'page',
#   'legalporno',
#   'k',
#   'download',
#   'exclusive',
#   'porn',
#   'flashbit'],
#  ['sapa', 'electro', 'тоо', 'талдыкорган', 'сайт', 'флагма', 'казахстан'],
#  ['детский',
#   'блуза',
#   'декоративный',
#   'воротник',
#   'monnalisa',
#   'голубой',
#   'цвет',
#   'купить',
#   'рубль',
#   'интернет',
#   'магазин',
#   'цум',
#   'арт'],
#  ['педагогика',
#   'конспект',
#   'лекция',
#   'лекция',
#   'понятие',
#   'методология',
#   'педагогический',
#   'наука',
#   'е',
#   'шарохина'],
#  ['bb', 'dьnyasi', 'sizin', 'tibb', 'sl', 'h', 'tзiniz'],
#  ['фото', 'альбом', 'фото', 'фото', 'фотография', 'александр', 'шанцев'],
#  ['виктор',
#   'год',
#   'город',
#   'москва',
#   'россия',
#   'cайт',
#   'знакомство',
#   'bimeon',
#   'ru'],
#  ['пошло'],
#  ['kevin',
#   'taylor',
#   'carmen',
#   'cousins',
#   'cartoon',
#   'porn',
#   'romcomics',
#   'popular',
#   'xxx',
#   'comics',
#   'cartoon',
#   'porn',
#   'pics',
#   'incest',
#   'porn',
#   'games'],
#  ['конструктор',
#   'предложить',
#   'заменить',
#   'ан',
#   'однодвигательным',
#   'моноплан',
#   'военный',
#   'обозрение'],
#  ['opel',
#   'mokka',
#   'manuell',
#   'modus',
#   'automatikgetriebe',
#   'fahren',
#   'und',
#   'bedienung',
#   'opel',
#   'mokk'],
#  ['скачать',
#   'ева',
#   'кэссиди',
#   'autumn',
#   'leaves',
#   'mp',
#   'слушать',
#   'песня',
#   'онлайн',
#   'music',
#   'band',
#   'ru'],
#  ['имбирь', 'сахара', 'польза', 'рецепт'],
#  ['готовый',
#   'перевод',
#   'reincarnated',
#   'piggy',
#   'duke',
#   'time',
#   'say',
#   'like',
#   'переродиться',
#   'свиногерцога',
#   'сказать',
#   'любить',
#   'глава',
#   'жить',
#   'хотеть',
#   'tl',
#   'rulate',
#   'ru'],
#  ['dr', 'k', 'soap', 'company', 'parfumdreams'],
#  ['знак'],
#  ['компьютерный',
#   'гарнитур',
#   'razer',
#   'kraken',
#   'tournament',
#   'edition',
#   'интернет',
#   'магазин',
#   'гиганти',
#   'петербург'],
#  ['объявление',
#   'новостройка',
#   'стадия',
#   'котлован',
#   'пятигорск',
#   'жилой',
#   'комплекс',
#   'жк',
#   'этап',
#   'котлован',
#   'пятигорск',
#   'циан'],
#  ['клава', 'кок', 'тиша'],
#  ['нок', 'нод'],
#  ['парень',
#   'искать',
#   'девушка',
#   'томский',
#   'область',
#   'парабель',
#   'результат',
#   'поиск',
#   'сеть',
#   'знакомство',
#   'мамба'],
#  ['риэлтор', 'мишин', 'елена', 'вениамин', 'гдеэтотдом', 'ру'],
#  ['псковский',
#   'медицинский',
#   'училище',
#   'колледж',
#   'псков',
#   'сайт',
#   'всеколледжи',
#   'рф'],
#  ['читать',
#   'книга',
#   'русский',
#   'свой',
#   'бросать',
#   'автор',
#   'большак',
#   'валерий',
#   'онлайн',
#   'страница',
#   'сайт',
#   'booksonline',
#   'ua'],
#  ['алексей', 'мерчин', 'год', 'мир', 'mail', 'ru'],
#  ['компланарный', 'вектор', 'презентация', 'геометрия'],
#  ['результат',
#   'скрининг',
#   'запись',
#   'пользователь',
#   'anastasia',
#   'nastyaserik',
#   'сообщество',
#   'клуб',
#   'беременный',
#   'категория',
#   'анализ',
#   'babyblog',
#   'ru'],
#  ['магазин', 'мир', 'инструмент', 'ооо', 'дровосек', 'чебоксары'],
#  ['фото', 'штора', 'капля', 'красота'],
#  ['натуральный', 'обезводить', 'ломтик', 'манго', 'марка', 'доить', 'кхам'],
#  ['hors',
#   'datteinte',
#   'cast',
#   'ariel',
#   'rebel',
#   'lola',
#   'reve',
#   'studio',
#   'sexart',
#   'met',
#   'art',
#   'download',
#   'erotic',
#   'porn',
#   'video',
#   'eroticax'],
#  ['центральный',
#   'улица',
#   'карта',
#   'кварцитного',
#   'посёлок',
#   'карелия',
#   'номер',
#   'дом',
#   'mapdat'],
#  ['hemodializ',
#   'v',
#   'bцyr',
#   'k',
#   'kцзьrьlmь',
#   'x',
#   'st',
#   'l',
#   'rin',
#   'ictimai',
#   'birliyi'],
#  ['статус', 'смысл', 'любовь', 'страница'],
#  ['импровизация',
#   'вечеринка',
#   'выпуск',
#   'фрагмент',
#   'импровизация',
#   'смотреть',
#   'онлайн',
#   'видео',
#   'бесплатно',
#   'видеохостинг',
#   'rutube'],
#  ['тетрадь',
#   'лист',
#   'клетка',
#   'calligrata',
#   'котёнок',
#   'белизна',
#   'картонный',
#   'обложка',
#   'микс',
#   'купить',
#   'цена',
#   'рубль',
#   'интернет',
#   'магазин',
#   'sima',
#   'land',
#   'ru'],
#  ['зимний',
#   'комбинезон',
#   'reima',
#   'tec',
#   'купить',
#   'рубль',
#   'москва',
#   'объявление'],
#  ['daftsex'],
#  ['глава',
#   'вак',
#   'прокомментировать',
#   'предложение',
#   'бессрочный',
#   'лишение',
#   'учёный',
#   'степень',
#   'риа',
#   'новость'],
#  ['new',
#   'rutor',
#   'org',
#   'интерн',
#   'бесплатный',
#   'торрент',
#   'скачать',
#   'бесплатно',
#   'rutor',
#   'org'],
#  ['поиск', 'картридж', 'сf'],
#  ['купить',
#   'серьга',
#   'золотой',
#   'проба',
#   'камень',
#   'интернет',
#   'магазин',
#   'московский',
#   'ювелирный',
#   'завод'],
#  ['кейптаун', 'смотреть', 'онлайн', 'сезон'],
#  ['кольцо',
#   'чёрный',
#   'жемчуг',
#   'классика',
#   'плата',
#   'чёрный',
#   'золотой',
#   'чёрный',
#   'золотой'],
#  ['приём',
#   'который',
#   'помочь',
#   'вырваться',
#   'замкнутый',
#   'круг',
#   'начать',
#   'жить'],
#  ['найти', 'судебный', 'решение', 'совет', 'адвокат', 'юрист'],
#  ['поэнг',
#   'подушка',
#   'сидение',
#   'табурет',
#   'нога',
#   'шифтебу',
#   'коричневый',
#   'ikea'],
#  ['дорога', 'попутчик', 'хлопоты', 'blablacar', 'ru'],
#  ['brandi',
#   'love',
#   'drinks',
#   'big',
#   'tits',
#   'milf',
#   'sd',
#   'p',
#   'puremature',
#   'pornuploaded',
#   'net',
#   'download',
#   'free',
#   'ul',
#   'porn',
#   'videos'],
#  ['download',
#   'x',
#   'red',
#   'panties',
#   'topless',
#   'boobs',
#   'big',
#   'tits',
#   'handbra',
#   'brunette',
#   'sofa',
#   'hot',
#   'boots',
#   'porno',
#   'photos',
#   'erotic',
#   'wallpapers'],
#  ['download',
#   'uyire',
#   'uyire',
#   'ennai',
#   'pirinthu',
#   'nee',
#   'pogathey',
#   'full',
#   'album',
#   'song',
#   'mp',
#   'free',
#   'mp'],
#  ['продажа',
#   'дом',
#   'метр',
#   'аргаяшский',
#   'ул',
#   'челябинск',
#   'челябинский',
#   'область',
#   'база',
#   'циан',
#   'объявление'],
#  ['новое',
#   'страница',
#   'free',
#   'porn',
#   'videos',
#   'смотреть',
#   'бесплатный',
#   'порно',
#   'видео',
#   'hd'],
#  ['презентация',
#   'тема',
#   'учиться',
#   'читать',
#   'тренажёр',
#   'чтение',
#   'учитель',
#   'начальный',
#   'класс'],
#  ['город', 'качканар', 'фото'],
#  ['чужое',
#   'звезда',
#   'каменеть',
#   'алекс',
#   'страница',
#   'чтение',
#   'книга',
#   'бесплатно'],
#  ['относительный', 'удлинение', 'весь', 'формула'],
#  ['ginger',
#   'frost',
#   'страница',
#   'форум',
#   'антивирус',
#   'софт',
#   'norton',
#   'касперский',
#   'eset',
#   'windows'],
#  ['василий',
#   'гайдук',
#   'слуцк',
#   'минский',
#   'область',
#   'беларусь',
#   'год',
#   'мир',
#   'mail',
#   'ru'],
#  ['метод', 'подсказка', 'выбор', 'твердотопливный', 'котёл', 'pereko'],
#  ['екатеринбург', 'новосибирск', 'ноябрь', 'туда', 'ноябрь', 'обратно'],
#  ['куртка',
#   'трекинговая',
#   'haglofs',
#   'gore',
#   'tex',
#   'грн',
#   'туризм',
#   'вано',
#   'франк',
#   'вськ',
#   'olx'],
#  ['гильермо',
#   'дель',
#   'торо',
#   'штамм',
#   'комикс',
#   'комикс',
#   'мир',
#   'фантастика',
#   'фэнтези'],
#  ['результат', 'поиск'],
#  ['плитка', 'тротуарный', 'барнаул', 'компания', 'ооо', 'строить'],
#  ['новость',
#   'сообщение',
#   'официальный',
#   'группа',
#   'вконтакте',
#   'магазин',
#   'вольный',
#   'стиль',
#   'тц',
#   'спорт',
#   'хит',
#   'одежда',
#   'обувь',
#   'москва'],
#  ['оттенок',
#   'syoss',
#   'oleo',
#   'intense',
#   'золотистый',
#   'каштановый',
#   'хороший',
#   'краска',
#   'волос'],
#  ['слесарить',
#   'ремонт',
#   'автомобиль',
#   'аппаратчик',
#   'вакансия',
#   'компания',
#   'автоколонна'],
#  ['биография', 'малка', 'лоренц', 'софья', 'кочетовой'],
#  ['demi', 'lovato', 'nude', 'photos', 'videos', 'thefappening'],
#  ['бальзам',
#   'хамелеон',
#   'губа',
#   'oriflame',
#   'оттеночный',
#   'one',
#   'colour',
#   'adapt',
#   'прикольный'],
#  ['специалист',
#   'оплата',
#   'нормирование',
#   'труд',
#   'присвоение',
#   'квалификация',
#   'специалист',
#   'персонал',
#   'число'],
#  ['картинка',
#   'фантазия',
#   'рабочий',
#   'стол',
#   'скачать',
#   'обои',
#   'фэнтези',
#   'страница'],
#  ['минь',
#   'велотренажер',
#   'dfc',
#   'b',
#   'велотренажер',
#   'велоэргометр',
#   'домашний',
#   'занятие',
#   'спортдоставка',
#   'екатеринбург'],
#  ['решение',
#   'выпуск',
#   'страница',
#   'математика',
#   'самостоятельный',
#   'контрольный',
#   'рабо'],
#  ['входной', 'дверь', 'сенатор', 'венге'],
#  ['tutu', 'ru', 'выписка', 'билет'],
#  ['объявление',
#   'снять',
#   'квартира',
#   'недорого',
#   'пятигорск',
#   'дешёвый',
#   'жильё',
#   'циан'],
#  ['предполагать',
#   'дочь',
#   'путин',
#   'катерина',
#   'тихонов',
#   'развестись',
#   'муж',
#   'snatchnews',
#   'новостной',
#   'портал'],
#  ['установление',
#   'причастность',
#   'тлеть',
#   'табачный',
#   'изделие',
#   'тти',
#   'возникновение',
#   'пожар'],
#  ['world',
#   'tanks',
#   'mmo',
#   'free',
#   'play',
#   'acci',
#   'n',
#   'carros',
#   'combate',
#   'desc',
#   'rgalo',
#   'ahora',
#   'juega',
#   'gratis'],
#  ['сексапильный',
#   'молодуха',
#   'широко',
#   'раскрыть',
#   'свой',
#   'волосатый',
#   'бутон',
#   'порно',
#   'фото',
#   'секс'],
#  ['пальто',
#   'юрс',
#   'красный',
#   'модель',
#   'белорусский',
#   'трикотаж',
#   'интернет',
#   'магазин',
#   'швейный',
#   'традиция'],
#  ['кроссовок', 'мужской', 'кожа', 'чёрный', 'зимний', 'москва'],
#  ['маска', 'хамелеон', 'миллион', 'результат', 'поиск', 'mail', 'ru'],
#  ['b',
#   'натуральный',
#   'вкус',
#   'малин',
#   'мкг',
#   'жевательный',
#   'таблетка',
#   'iherb'],
#  ['marriott',
#   'sharm',
#   'mountain',
#   'шарм',
#   'эль',
#   'шейх',
#   'египет',
#   'описание',
#   'фотогалерея',
#   'тур',
#   'отель',
#   'tez',
#   'tour'],
#  ['архив', 'допотопный', 'технология', 'жёлтый', 'роза'],
#  ['константин',
#   'муравей',
#   'нейтральный',
#   'мир',
#   'страница',
#   'читать',
#   'topreading',
#   'ru'],
#  ['роскачество',
#   'предложить',
#   'приравнять',
#   'вино',
#   'сельскохозяйственный',
#   'продукт'],
#  ['gold', 'digger', 'daftsex'],
#  ['сениченко', 'ольга', 'сергей', 'страница'],
#  ['гардеробный', 'larvij', 'ларвидж'],
#  ['скачать',
#   'песня',
#   'рассказать',
#   'каков',
#   'бросить',
#   'самый',
#   'хороший',
#   'любимый',
#   'предать',
#   'засыпать',
#   'вспоминать',
#   'прошлое',
#   'свой',
#   'сердце',
#   'хранить',
#   'вселенная',
#   'рассказать',
#   'каков',
#   'девочка',
#   'рассказать',
#   'каков',
#   'бросить',
#   'бесплатно',
#   'mp',
#   'слушать',
#   'онлайн'],
#  ['правильно',
#   'писаться',
#   'слово',
#   'туманный',
#   'ударение',
#   'слово',
#   'туманный'],
#  ['puff', 'adressen', 'bielefeld', 'dicke', 'slut', 'nordrhein', 'westfalen'],
#  ['кейс',
#   'deliver',
#   'уберизировать',
#   'дальнобойщик',
#   'выйти',
#   'оборот',
#   'сотня',
#   'миллион',
#   'inc',
#   'russia'],
#  ['купить',
#   'женский',
#   'обувь',
#   'больший',
#   'размер',
#   'купить',
#   'обувь',
#   'полный',
#   'нога',
#   'купить',
#   'колготки',
#   'большой',
#   'размер',
#   'страница'],
#  ['голый',
#   'азиатка',
#   'супер',
#   'сексуальный',
#   'тайка',
#   'делать',
#   'фото',
#   'эротика',
#   'пляж'],
#  ['семейный',
#   'история',
#   'часть',
#   'вера',
#   'хороший',
#   'коллекция',
#   'порно',
#   'рассказ'],
#  ['largest', 'ebook', 'library'],
#  ['тюнинг', 'nissan', 'march', 'k', 'отзыв', 'личный', 'опыт', 'drive'],
#  ['пайка',
#   'металл',
#   'отличие',
#   'сварка',
#   'особенность',
#   'подготовка',
#   'поверхность'],
#  ['сородич',
#   'журавль',
#   'сканворд',
#   'буква',
#   'тысяча',
#   'результат',
#   'поиск',
#   'mail',
#   'ru'],
#  ['нигер', 'нефть', 'газ', 'уголь'],
#  ['n', 'daftsex'],
#  ['поиск', 'табель', 'почта', 'mail', 'ru'],
#  ['aliphotos', 'деталь', 'фото'],
#  ['карамельный', 'булочка', 'литр', 'наш'],
#  ['урок',
#   'стандартный',
#   'плагину',
#   'multiplayer',
#   'сообщество',
#   'разработчик',
#   'игра'],
#  ['зрелый',
#   'подруга',
#   'решить',
#   'полизать',
#   'киска',
#   'работать',
#   'самотыками'],
#  ['mill', 'v', 'kili', 'bьtьn', 'ev', 'l', 'rini', 'цzьm', 'gцrьr'],
#  ['маршрут', 'анапа', 'сесть', 'витязево', 'расстояние', 'карта'],
#  ['буcина',
#   'нефрит',
#   'чёрный',
#   'мм',
#   'круглый',
#   'каменный',
#   'бусина',
#   'нефрит',
#   'диаметр',
#   'бисер',
#   'бусина',
#   'творчество',
#   'рукоделие'],
#  ['продать',
#   'участок',
#   'ленинградский',
#   'область',
#   'база',
#   'циан',
#   'объявление'],
#  ['бизнес', 'план', 'выращивание', 'фазан', 'хороший', 'бизнес', 'идея'],
#  ['такси', 'ижевск', 'алнашей', 'предзаказу', 'россия', 'кросстакси'],
#  ['порно',
#   'групповуха',
#   'смотреть',
#   'онлайн',
#   'порно',
#   'мама',
#   'ххх',
#   'бесплатно',
#   'hd',
#   'качество',
#   'страница'],
#  ['essens', 'чп', 'ташкент', 'сайт', 'флагма', 'узбекистан'],
#  ['сериал', 'монтекристо', 'серия', 'смотреть', 'онлайн'],
#  ['блузка', 'женщина', 'dry', 'lake', 'yoox', 'россия'],
#  ['литр',
#   'харабали',
#   'астраханский',
#   'область',
#   'россия',
#   'мир',
#   'mail',
#   'ru'],
#  ['maxvi', 'объявление', 'таджикистан', 'somon', 'tj'],
#  ['часто', 'задавать', 'вопрос', 'возврат', 'деньга', 'телефон'],
#  ['бесплатный',
#   'скрипт',
#   'хайпов',
#   'метод',
#   'заработок',
#   'вложение',
#   'заработок',
#   'интернет',
#   'страница'],
#  ['homo', 'sik', 'directory', 'adult', 'video', 'xxx', 'sxs', 'mob'],
#  ['скачать',
#   'фильм',
#   'скелет',
#   'железный',
#   'остров',
#   'бесплатно',
#   'скачать',
#   'фильм',
#   'бесплатно',
#   'регистрация',
#   'смс',
#   'отличный',
#   'качество',
#   'dvd',
#   'hd'],
#  ['порно', 'фильм', 'результат', 'поиск', 'mail', 'ru'],
#  ['светлана', 'нарчук'],
#  ['kids', 'magazine', 'журнал', 'год', 'ростов', 'дон', 'отзыв'],
#  ['гостиница', 'чувашия', 'звезда', 'чебоксары'],
#  ['анютик', 'год', 'брест', 'фотография', 'сайт', 'знакомство', 'tabor', 'ru'],
#  ['яуехал',
#   'год',
#   'россия',
#   'анапа',
#   'фото',
#   'познакомиться',
#   'парень',
#   'познакомиться',
#   'парень',
#   'цель',
#   'знакомство',
#   'дружба',
#   'общение',
#   'любовь',
#   'романтический',
#   'отноше'],
#  ['смотреть',
#   'онлайн',
#   'мультсериал',
#   'свинка',
#   'пеппа',
#   'сезон',
#   'реальный',
#   'новое',
#   'серия',
#   'specials',
#   'mp',
#   'video',
#   'mail',
#   'ru'],
#  ['форма', 'моделирование', 'clear', 'pro', 'nail', 'forms', 'pnb'],
#  ['читать',
#   'онлайн',
#   'лисиный',
#   'александр',
#   'магиня',
#   'электронный',
#   'библиотека',
#   'libra',
#   'ru'],
#  ['секс', 'трио', 'жена', 'сосед', 'mega', 'porno'],
#  ['video',
#   'lesbians',
#   'babes',
#   'watch',
#   'download',
#   'free',
#   'xxx',
#   'porn',
#   'hd',
#   'videos',
#   'online'],
#  ['поиск', 'рюкзак', 'nike', 'страница', 'asos'],
#  ['лерканидипин', 'инструкция', 'применение', 'лекарство', 'аналог', 'отзыв'],
#  ['дмитрий',
#   'демин',
#   'mail',
#   'маркетинг',
#   'привлечь',
#   'удержать',
#   'клиент',
#   'скачать',
#   'fb',
#   'epub',
#   'pdf',
#   'литрес'],
#  ['тепловизионный',
#   'обследование',
#   'цена',
#   'рубль',
#   'услуга',
#   'заказать',
#   'могилев',
#   'deal',
#   'id'],
#  ['социально', 'экономический', 'развитие', 'россия', 'xix', 'студопедия'],
#  ['tцltse',
#   'merevlemez',
#   'tisztнtуt',
#   'lemezkarbantartбs',
#   'letцltйsi',
#   'program'],
#  ['dmitri', 'gorobic', 'тысяча', 'результат', 'поиск', 'mail', 'ru'],
#  ['ландыш', 'прекрасный', 'сургут', 'фото', 'страница'],
#  ['алексей'],
#  ['дневник', 'асоциальный', 'сеть'],
#  ['контакт'],
#  ['иллюстрация',
#   'русский',
#   'язык',
#   'класс',
#   'проверочный',
#   'контрольный',
#   'работа',
#   'фгос',
#   'лабиринт',
#   'книга'],
#  ['социалка', 'r', 'c', 'h', 'c', 'h', 'r'],
#  ['ctroi', 'yandex', 'ru', 'почта', 'mail', 'ru'],
#  [],
#  ['счётчик',
#   'моточасов',
#   'поднебесный',
#   'renault',
#   'sandero',
#   'stepway',
#   'литр',
#   'год',
#   'drive'],
#  ['директор',
#   'вакансия',
#   'компания',
#   'магнит',
#   'астрахань',
#   'astrakhan',
#   'zarplata',
#   'ru'],
#  ['репс', 'однотонный', 'мм'],
#  ['алексей',
#   'остаев',
#   'изба',
#   'читальня',
#   'литературно',
#   'художественный',
#   'портал'],
#  ['иммунный', 'система', 'весь', 'документальный', 'фильм', 'онлайн'],
#  ['трахнуть', 'раздевалка', 'жена', 'босс', 'корпоративе', 'nightofideasla'],
#  ['фото', 'пользователь', 'наталья', 'красноярск', 'год'],
#  ['супер',
#   'zings',
#   'фигурка',
#   'серия',
#   'золото',
#   'superzings',
#   'ребёнок',
#   'игрушка',
#   'фигурка'],
#  ['отзыв', 'противогрибковый', 'средство', 'флуконазол', 'страница'],
#  ['olx'],
#  ['решение', 'эксперт'],
#  ['real',
#   'estate',
#   'property',
#   'egkomi',
#   'lefkosia',
#   'nicosia',
#   'district',
#   'sell',
#   'buy',
#   'rent'],
#  ['плюс', 'минус', 'учёба', 'заочный'],
#  ['бюро', 'чистота', 'брат', 'чистовой'],
#  ['сша', 'объявить', 'лауреат', 'пулитцеровский', 'премия', 'год'],
#  ['аренда',
#   'фрезеровочный',
#   'машина',
#   'бетон',
#   'schwamborn',
#   'bef',
#   'купить',
#   'нижний',
#   'новгород',
#   'договорный',
#   'цена',
#   'компания',
#   'ооо',
#   'fortrent'],
#  ['экологический',
#   'воздействие',
#   'смога',
#   'здоровье',
#   'человек',
#   'тысяча',
#   'результат',
#   'поиск',
#   'mail',
#   'ru'],
#  ['фотосклад', 'казань', 'результат', 'поиск', 'mail', 'ru'],
#  ['vнdeo',
#   'acercamientos',
#   'anal',
#   'punto',
#   'vista',
#   'sexo',
#   'duro',
#   'mira',
#   'descarga'],
#  ['дилижанс', 'шоу', 'прокат', 'аренда', 'костюм'],
#  ['поздравление', 'день', 'ростехнадзора', 'проза'],
#  ['голый', 'жанна', 'фриске', 'максим', 'фото', 'maxim', 'июнь'],
#  ['oneamour'],
#  ['braces', 'teen', 'shaking', 'squirting'],
#  ['капот',
#   'mitsubishi',
#   'montero',
#   'pajero',
#   'купить',
#   'владивосток',
#   'цена',
#   'объявл'],
#  ['мёртвый',
#   'земля',
#   'чужое',
#   'рад',
#   'миллион',
#   'результат',
#   'поиск',
#   'mail',
#   'ru'],
#  ['парфюмерия', 'art', 'parfum', 'отзыв', 'покупатель'],
#  ['гей', 'чат', 'знакомство', 'барнаул'],
#  ['совместный',
#   'покупка',
#   'омск',
#   'брюки',
#   'свитшот',
#   'старый',
#   'цена',
#   'рубль'],
#  ['десна',
#   'свой',
#   'исток',
#   'смоленский',
#   'область',
#   'необычайно',
#   'красивый',
#   'тихий',
#   'брянский',
#   'новость'],
#  ['правильно', 'писаться', 'слово', 'челюсть', 'ударение', 'слово', 'челюсть'],
#  ['видео', 'свет', 'огонь', 'видео', 'смотреть', 'онлайн', 'мыть', 'мир'],
#  ['торрент',
#   'порно',
#   'скачать',
#   'torrent',
#   'скачать',
#   'bigtitsatschool',
#   'brazzers',
#   'katie',
#   'kox',
#   'smokin',
#   'girls',
#   'room',
#   'курение',
#   'женский',
#   'туалет',
#   'год',
#   'big',
#   'tits',
#   'teen',
#   'uniform',
#   'school',
#   'girl',
#   'cum',
#   'tits',
#   'порно',
#   'сайтрип',
#   'торрент',
#   'бесплатно',
#   'р'],
#  ['результат',
#   'поиск',
#   'запрос',
#   'казаться',
#   'размышление',
#   'истинный',
#   'успех',
#   'интернет',
#   'магазин',
#   'читать',
#   'город'],
#  ['вакансия',
#   'менеджер',
#   'работа',
#   'торговый',
#   'сеть',
#   'пятигорск',
#   'работа',
#   'милагра'],
#  ['здравый',
#   'биз',
#   'решение',
#   'ваш',
#   'медицинский',
#   'бизнес',
#   'пример',
#   'отчёт',
#   'внутренний',
#   'контроль',
#   'качество'],
#  ['реквизит', 'ооо'],
#  ['чамьюва', 'бич', 'отель', 'турция', 'поиск', 'mail', 'ru'],
#  ['подождать', 'страница', 'загружаться'],
#  ['naruto', 'hentai', 'nhentai', 'naruto', 'hentai', 'aliciante'],
#  ['определение',
#   'судебный',
#   'коллегия',
#   'гражданский',
#   'дело',
#   'вс',
#   'рф',
#   'n',
#   'килограмм'],
#  ['купон', 'эльдорадо', 'скидка', 'следующий', 'покупка', 'февраль', 'март'],
#  ['радикал', 'фото', 'картинка'],
#  ['путешествие', 'украина', 'посмотреть', 'крым', 'ubr', 'ua'],
#  ['читать',
#   'книга',
#   'работать',
#   'контраст',
#   'подруга',
#   'люба',
#   'вкус',
#   'автор',
#   'мазуркевич',
#   'наталья',
#   'онлайн',
#   'сайт',
#   'booksonline',
#   'ua'],
#  ['купить',
#   'шатура',
#   'camilla',
#   'светлый',
#   'кредит',
#   'актобе',
#   'kaspi',
#   'магазин'],
#  ['прогноз',
#   'погода',
#   'северный',
#   'день',
#   'неделя',
#   'погода',
#   'северный',
#   'северный',
#   'свердловский',
#   'область',
#   'sinoptik',
#   'ru'],
#  ['ислам', 'итляшев', 'водка', 'пить', 'кальян', 'курить'],
#  ['тест',
#   'день',
#   'днёвка',
#   'хэтчинг',
#   'запись',
#   'пользователь',
#   'serafima',
#   'id',
#   'сообщество',
#   'эко',
#   'мама',
#   'категория',
#   'образ',
#   'жизнь',
#   'время',
#   'эко',
#   'babyblog',
#   'ru'],
#  ['сравнить',
#   'sony',
#   'xperia',
#   'z',
#   'dual',
#   'graphite',
#   'black',
#   'sony',
#   'xperia',
#   'xz',
#   'dual',
#   'чёрный',
#   'oneplus',
#   'gb',
#   'чёрный',
#   'google',
#   'pixel',
#   'xl',
#   'фиолетовый'],
#  ['купить', 'корпоративный', 'подарок', 'владимир', 'доставка', 'россия'],
#  ['укра', 'нська', 'литр', 'тература', 'клас', 'авраменко', 'метр', 'гдз'],
#  ['результат',
#   'поиск',
#   'запрос',
#   'английский',
#   'фокус',
#   'класс',
#   'интернет',
#   'магазин',
#   'читать',
#   'город'],
#  ['социальный',
#   'дифференциация',
#   'язык',
#   'понятие',
#   'литературный',
#   'язык',
#   'студопедия'],
#  ['метаданные', 'статья', 'студопедия'],
#  ['самир', 'артист', 'краснодар'],
#  ['обманка',
#   'лямбда',
#   'зонд',
#   'грн',
#   'прочий',
#   'запчасть',
#   'мелитополь',
#   'olx'],
#  ['комплектовать',
#   'батут',
#   'укра',
#   'наш',
#   'пора',
#   'вняти',
#   'ц',
#   'придбати',
#   'споживч',
#   'товари',
#   'маркетплейс',
#   'prom',
#   'ua'],
#  ['букет', 'гортензия', 'микс', 'голубой', 'фиолетовый'],
#  ['тест',
#   'окружающий',
#   'мир',
#   'класс',
#   'весь',
#   'учитель',
#   'тест',
#   'окружающий',
#   'мир',
#   'класс',
#   'окружающий',
#   'мир',
#   'задание',
#   'тест',
#   'викторин'],
#  ['шапочка',
#   'лето',
#   'осень',
#   'зима',
#   'весна',
#   'макушка',
#   'пяточек',
#   'платок',
#   'шарф',
#   'шаль',
#   'ребёнок'],
#  ['yua', 'mikami', 'nude', 'oae', 'perfect', 'porn', 'movie'],
#  ['lada', 'vesta', 'sw', 'cross', 'review', 'lada', 'official', 'website'],
#  ['bbsauto', 'ru', 'моторный', 'масло', 'neste', 'pro', 'c', 'w', 'литр'],
#  ['priscylla', 'modella', 'biqle', 'видео'],
#  ['listinny', 'чешский', 'русский'],
#  ['купить',
#   'ондулин',
#   'петропавловск',
#   'камчатский',
#   'предложение',
#   'весь',
#   'предложение',
#   'це'],
#  ['сетевой',
#   'контроллер',
#   'sigur',
#   'sphinx',
#   'h',
#   'нижний',
#   'новгород',
#   'низкий',
#   'цена'],
# ...
#   'адаптация',
#   'ребёнок',
#   'мигрант',
#   'новый',
#   'социокультурный'],
#  ['ремонт',
#   'стационарный',
#   'телефон',
#   'сочи',
#   'altdir',
#   'ru',
#   'справочник',
#   'организация'],
#  ['барахолка', 'услуга', 'большой', 'воронежский', 'форум'],
#  ['jade', 'victoria', 'free', 'porn', 'clips'],
#  ['администрация',
#   'муниципальный',
#   'образование',
#   'вистинское',
#   'сельский',
#   'поселение',
#   'утверждение',
#   'кодекс',
#   'этика',
#   'служебный',
#   'поведение',
#   'муниципальный',
#   'служащий'],
#  ['саша',
#   'сигуев',
#   'сев',
#   'николаев',
#   'фильм',
#   'осторожно',
#   'ребёнок',
#   'фотография'],
#  ['saints', 'row', 'скачать', 'торрент', 'бесплатно', 'pc'],
#  ['круча', 'ideal', 'nina', 'hagen', 'ideal'],
#  ['bedbox',
#   'guesthouse',
#   'hostel',
#   'таиланд',
#   'пхукет',
#   'отзыв',
#   'отель',
#   'цена',
#   'фото',
#   'номер',
#   'забронировать',
#   'отель',
#   'bedbox',
#   'guesthouse',
#   'hostel',
#   'онлайн'],
#  ['кукла',
#   'младенец',
#   'jc',
#   'toys',
#   'пупс',
#   'близняшки',
#   'коляска',
#   'купить',
#   'рассрочка',
#   'минск',
#   'низкий',
#   'цена',
#   'multimart'],
#  ['любвеобильный', 'девушка', 'друг'],
#  ['запешите',
#   'слово',
#   'распредиляя',
#   'группа',
#   'орфограмма',
#   'корень',
#   'ленивый',
#   'честный'],
#  [],
#  ['свадебный',
#   'набор',
#   'свадебный',
#   'бижутерия',
#   'оптом',
#   'хороший',
#   'цена',
#   'компания',
#   'бижутерия',
#   'оптом',
#   'r',
#   'r',
#   'r',
#   'одесса',
#   'украина',
#   'страница'],
#  ['снять',
#   'комнатный',
#   'квартира',
#   'посредник',
#   'новороссийск',
#   'объявление',
#   'аренда',
#   'однокомнатный',
#   'квартира',
#   'собственник',
#   'длительный'],
#  ['несладкий', 'начинка', 'блин', 'хороший', 'рецепт', 'фото', 'сегодня'],
#  ['выбирать',
#   'оптимальный',
#   'видеокарта',
#   'процессор',
#   'amd',
#   'ryzen',
#   'ryzen',
#   'страница'],
#  ['спам', 'почта', 'mail', 'ru'],
#  ['читать',
#   'манга',
#   'расколоть',
#   'битва',
#   'синева',
#   'небо',
#   'глава',
#   'русский',
#   'онлайн'],
#  ['tidal', 'trek'],
#  ['зона', 'особый', 'скачать', 'бесплатно', 'mp', 'зона', 'особый'],
#  ['большой',
#   'гея',
#   'отдохнуть',
#   'сеновал',
#   'отменно',
#   'потрахались',
#   'втроём',
#   'порно',
#   'онлайн',
#   'хороший',
#   'качество'],
#  ['субтитр',
#   'страница',
#   'хентай',
#   'онлайн',
#   'смотреть',
#   'бесплатно',
#   'hentai',
#   'share',
#   'ru'],
#  ['толстовка',
#   'толстовка',
#   'воротник',
#   'тип',
#   'рубашка',
#   'принтом',
#   'сезон',
#   'осень',
#   'зима',
#   'женский',
#   'толстовка',
#   'свитшоты'],
#  ['drivers', 'lenovo', 'thinkpad', 'descargar', 'windows', 'xp'],
#  ['клубневой',
#   'бегония',
#   'любимый',
#   'сорт',
#   'страница',
#   'форум',
#   'цветовод',
#   'фрау',
#   'флор'],
#  ['haenel', 'jaeger', 'страница', 'guns', 'ru', 'talks'],
#  ['застукать',
#   'дочь',
#   'трахаться',
#   'кухонный',
#   'стол',
#   'monique',
#   'alexander',
#   'jordi',
#   'niсo',
#   'po'],
#  ['измельчать',
#   'юбилей',
#   'донецк',
#   'приехать',
#   'сбить',
#   'лётчик',
#   'российский',
#   'эстрада'],
#  ['ярославль',
#   'сгореть',
#   'дзержинский',
#   'рынок',
#   'сентябрь',
#   'год',
#   'остаться'],
#  ['фестал', 'др', 'цена', 'москва', 'рубль'],
#  ['софья', 'апфельбаум', 'биография', 'карьер', 'семья', 'фото'],
#  ['антоним', 'слово', 'духовность'],
#  ['владимир', 'тучковский', 'вильнюс', 'литва', 'год', 'мир', 'mail', 'ru'],
#  ['шрус',
#   'внеш',
#   'renault',
#   'clio',
#   'iii',
#   'clio',
#   'grandtour',
#   'iii',
#   'modus',
#   'twingo'],
#  ['миниборд',
#   'atemi',
#   'apb',
#   'пенни',
#   'минь',
#   'борд',
#   'скейтборд',
#   'спортдоставке',
#   'спортдоставка',
#   'белгород'],
#  ['покраснеть', 'десна', 'бэбиблог'],
#  ['декоративный',
#   'карниз',
#   'штора',
#   'витязь',
#   'однорядный',
#   'мм',
#   'золото',
#   'патина',
#   'длина',
#   'сантиметр',
#   'широкий',
#   'выбор',
#   'товар',
#   'магазин',
#   'сравнить',
#   'цена'],
#  ['настройка', 'лаитб', 'з', 'youdo'],
#  ['lusty',
#   'ladies',
#   'group',
#   'sex',
#   'super',
#   'lucky',
#   'guy',
#   'late',
#   'afternoon',
#   'perfect',
#   'girls'],
#  ['newsensations',
#   'katrina',
#   'missy',
#   'girl',
#   'crazy',
#   'katrina',
#   'kraven',
#   'missy',
#   'monroe',
#   'big',
#   'tits',
#   'xxx',
#   'online'],
#  ['летний', 'итальянка', 'родить', 'ребёнок', 'новое', 'известие'],
#  ['штукатурка', 'потолок', 'цена', 'метр', 'москва', 'youdo'],
#  ['asian',
#   'milf',
#   'pussy',
#   'licking',
#   'fucking',
#   'free',
#   'mobile',
#   'porn',
#   'video'],
#  ['куркума',
#   'молотый',
#   'добавка',
#   'полезный',
#   'лечебный',
#   'свойство',
#   'специя',
#   'применение',
#   'кулинария',
#   'купить',
#   'москва',
#   'цена',
#   'отзыв',
#   'полезный',
#   'свойство'],
#  ['поиск', 'названый', 'брат'],
#  ['sony',
#   'channel',
#   'hd',
#   'отчаянный',
#   'домохозяйка',
#   'серия',
#   'муж',
#   'свинья',
#   'й',
#   'сезон',
#   'мегафон',
#   'тв'],
#  ['мир', 'mail', 'ru'],
#  ['vek', 'суперскидки'],
#  ['descargar',
#   'drivers',
#   'marvell',
#   'yukon',
#   'pci',
#   'gigabit',
#   'ethernet',
#   'controller',
#   'windows',
#   'x'],
#  ['облако', 'милоты'],
#  ['дарынды',
#   'балалар',
#   'арнал',
#   'ан',
#   'абай',
#   'атында',
#   'ы',
#   'лицей',
#   'мектеб',
#   'абай',
#   'атында',
#   'ы',
#   'лицей',
#   'мектеб',
#   'ма',
#   'ала',
#   'зд',
#   'ы'],
#  ['поиск', 'запрос', 'смарт', 'браслет', 'huawei', 'talkband', 'b', 'classic'],
#  ['скачать',
#   'обои',
#   'земля',
#   'мир',
#   'earth',
#   'карбон',
#   'carbon',
#   'раздел',
#   'текстура',
#   'разрешение',
#   'x'],
#  ['rbaycanl', 'qarda', 'lar', 'g', 'rc', 'stan', 'n', 'hur', 'yar', 'nda'],
#  ['писать',
#   'требование',
#   'письменно',
#   'объяснительный',
#   'ь',
#   'миллион',
#   'результат',
#   'поиск',
#   'mail',
#   'ru'],
#  ['татьяна',
#   'назаров',
#   'биография',
#   'фото',
#   'фильм',
#   'личный',
#   'жизнь',
#   'новость',
#   'сми'],
#  ['general', 'information'],
#  ['комплекс',
#   'утренний',
#   'гимнастика',
#   'весёлый',
#   'платочек',
#   'младший',
#   'группа',
#   'воспитатель',
#   'детский',
#   'сад',
#   'школьный',
#   'учитель',
#   'педагог',
#   'маам',
#   'ру'],
#  ['постановление', 'февраль', 'год', 'дело', 'судакт', 'ру'],
#  ['всяко',
#   'разный',
#   'брызговик',
#   'opel',
#   'insignia',
#   'hatchback',
#   'литр',
#   'год',
#   'drive'],
#  ['крепкий',
#   'лысый',
#   'трахарь',
#   'жарить',
#   'молодая',
#   'шалавый',
#   'больший',
#   'пенис'],
#  ['салат', 'копчёный', 'колбаса', 'огурец', 'простой', 'рецепт', 'фото'],
#  ['юрий',
#   'семин',
#   'пусть',
#   'уткин',
#   'продолжать',
#   'оригинальничать',
#   'случайный',
#   'победа',
#   'новость',
#   'еврокубков',
#   'футбол',
#   'спорт',
#   'mail',
#   'ru'],
#  ['new',
#   'rutor',
#   'org',
#   'рассекать',
#   'волна',
#   'breaking',
#   'waves',
#   'bdrip',
#   'koenig',
#   'p'],
#  ['asia', 'pacific', 'strategic', 'culture'],
#  ['мойка',
#   'мотор',
#   'снятие',
#   'передний',
#   'бампер',
#   'крыло',
#   'подкрыльев',
#   'renault',
#   'scenic',
#   'литр',
#   'год',
#   'drive'],
#  ['https',
#   'mega',
#   'nz',
#   'f',
#   'pskn',
#   'qdk',
#   'cwqovwj',
#   'buky',
#   'limcknw',
#   'mega'],
#  ['твой',
#   'имя',
#   'апрель',
#   'группа',
#   'пацанок',
#   'скачать',
#   'бесплатно',
#   'mp',
#   'слушать',
#   'онлайн'],
#  ['шутка', 'погода', 'погода', 'дождь', 'снег', 'жара', 'жарко'],
#  ['adidas', 'shop', 'страница', 'slon', 'sneakers'],
#  ['фото', 'альбом', 'свадебный', 'ванда', 'боголепов'],
#  ['мода', 'gta', 'san', 'andreas', 'страница'],
#  ['akanti'],
#  ['teen',
#   'best',
#   'natural',
#   'tits',
#   'tube',
#   'teen',
#   'cam',
#   'webcam',
#   'girls',
#   'porn',
#   'video'],
#  ['принтер', 'этикетка', 'printronix', 'x', 'r', 'сервис', 'ккт'],
#  ['деревянный',
#   'кровать',
#   'массив',
#   'ясень',
#   'дуб',
#   'предоплата',
#   'грн',
#   'мебель',
#   'спальня',
#   'белый',
#   'церковь',
#   'olx'],
#  ['секс', 'ролик', 'hd', 'качество', 'p', 'смотреть', 'онлайн'],
#  ['анкетка', 'ру', 'личный', 'кабинет'],
#  ['hannah',
#   'hays',
#   'slutty',
#   'stepsister',
#   'hannah',
#   'hays',
#   'gets',
#   'drenched',
#   'stepbrother',
#   'cum',
#   'sd',
#   'p',
#   'slutstepsister',
#   'naughtyamerica',
#   'mb',
#   'legalporno'],
#  ['скачать', 'музыка', 'бесплатно', 'mp'],
#  ['порно',
#   'модель',
#   'популярный',
#   'порно',
#   'видео',
#   'актриса',
#   'kortney',
#   'kane',
#   'мир',
#   'адалта'],
#  ['решение', 'январь', 'год', 'дело', 'судакт', 'ру'],
#  ['срочно',
#   'неделя',
#   'очень',
#   'низкий',
#   'хгч',
#   'дикий',
#   'koshka',
#   'babyplan',
#   'ru'],
#  ['камаз', 'новый', 'заводский', 'седельный', 'тягач', 'набережная', 'челны'],
#  ['режим',
#   'график',
#   'работа',
#   'страховой',
#   'компания',
#   'ресо',
#   'гарантия',
#   'волгодонск'],
#  ['сервис', 'международный', 'перевод'],
#  ['модель', 'принтер', 'принтер'],
#  ['главный',
#   'инженер',
#   'газовый',
#   'труба',
#   'замуровать',
#   'опор',
#   'строиться',
#   'здание',
#   'никакой',
#   'угроза'],
#  ['читать',
#   'книга',
#   'ком',
#   'звенеть',
#   'бубен',
#   'страница',
#   'библиотека',
#   'книга'],
#  ['альбом',
#   'оксана',
#   'дупик',
#   'скорпион',
#   'чита',
#   'dfhhhgdgh',
#   'love',
#   'tvoy',
#   'bor',
#   'ru'],
#  ['кредит', 'залог', 'недвижимость', 'тинькофф', 'помощь'],
#  ['электромясорубка',
#   'moulinex',
#   'hv',
#   'характеристика',
#   'технический',
#   'описание',
#   'интернет',
#   'магазин',
#   'метр',
#   'видео',
#   'ульяновск',
#   'ульяновск'],
#  ['комбинезон', 'пижама', 'молния', 'лёгкий', 'верблюд', 'лкм', 'бк', 'верба'],
#  ['поиск', 'продукт', 'хонда', 'дио', 'qmb', 'ru'],
#  ['презентация',
#   'тема',
#   'исследователь',
#   'внеурочный',
#   'деятельность',
#   'руководитель',
#   'кр'],
#  ['игра', 'престол', 'сезон', 'серия', 'смотреть', 'онлайн', 'реклама'],
#  ['тележка',
#   'инструментальный',
#   'откидной',
#   'верхом',
#   'двухстворчатым',
#   'шкаф',
#   'боковой',
#   'перфорация',
#   'х',
#   'х',
#   'мм',
#   'полка',
#   'х',
#   'х',
#   'мм',
#   'шкаф',
#   'х',
#   'х',
#   'мм',
#   'цена',
#   'рубль',
#   'купить',
#   'минск',
#   'deal',
#   'id'],
#  ['скачать',
#   'самп',
#   'последний',
#   'версия',
#   'результат',
#   'поиск',
#   'mail',
#   'ru'],
#  ['просмотр', 'резюме'],
#  ['webinar', 'ru'],
#  ['мортал', 'комбат', 'порно', 'поиск', 'mail', 'ru'],
#  ['бритва',
#   'fusion',
#   'proshield',
#   'смена',
#   'кассета',
#   'купить',
#   'сеть',
#   'магазин',
#   'лента'],
#  ['заказ',
#   'успешно',
#   'добавить',
#   'спкубани',
#   'совместный',
#   'покупка',
#   'краснодар',
#   'краснодарский',
#   'край',
#   'крым'],
#  ['туника',
#   'вуаль',
#   'ажурный',
#   'завязка',
#   'продажа',
#   'цена',
#   'киев',
#   'пляжный',
#   'одежда',
#   'парео',
#   'тд',
#   'vivaldi'],
#  ['кормление',
#   'коза',
#   'кукурузный',
#   'силос',
#   'fermer',
#   'ru',
#   'фермер',
#   'ру',
#   'главный',
#   'фермерский',
#   'портал',
#   'весь',
#   'бизнес',
#   'сельский',
#   'хозяйство',
#   'форум',
#   'фермер'],
#  ['продажа', 'участок', 'московский', 'область', 'база', 'циан', 'объявление'],
#  ['прдам',
#   'газель',
#   'категория',
#   'b',
#   'газ',
#   'газель',
#   'бортовый',
#   'грузовик',
#   'симферополь'],
#  ['далее',
#   'билет',
#   'сентябрь',
#   'ноглики',
#   'южный',
#   'сахалинск',
#   'выбор',
#   'поезд'],
#  ['milf', 'sucks', 'fat', 'dick', 'phone'],
#  ['блок', 'преобразователь', 'импульсный', 'бпи', 'иссан', 'охра', 'далее'],
#  ['ремонт',
#   'люба',
#   'сложность',
#   'монтаж',
#   'окно',
#   'откос',
#   'ключ',
#   'cтроительные',
#   'услуга',
#   'запорожье',
#   'olx'],
#  ['lilou',
#   'gang',
#   'bang',
#   'bukkake',
#   'fran',
#   'ais',
#   'free',
#   'bang',
#   'porn',
#   'fran',
#   'ais',
#   'mp',
#   'video',
#   'fr',
#   'justporno',
#   'sex'],
#  ['интернет',
#   'провайдер',
#   'красково',
#   'люберецкий',
#   'район',
#   'московский',
#   'область',
#   'подключить',
#   'интернет',
#   'адрес',
#   'дом',
#   'красково',
#   'люберецкий',
#   'район',
#   'мо'],
#  ['сапог', 'женщина', 'casadei', 'yoox', 'россия'],
#  ['вакансия',
#   'операционный',
#   'директор',
#   'симферополь',
#   'продукт',
#   'ермолино',
#   'сайт',
#   'электро'],
#  ['конспект',
#   'урок',
#   'русский',
#   'язык',
#   'тема',
#   'комплексный',
#   'работа',
#   'текст',
#   'кла'],
#  ['jenner', 'kris', 'analysys', 'chart'],
#  ['биксеноновые',
#   'линза',
#   'aes',
#   'g',
#   'c',
#   'ангельский',
#   'глазок',
#   'акционной',
#   'цена'],
#  ['знакомство',
#   'love',
#   'novokubanka',
#   'ru',
#   'найти',
#   'свой',
#   'половинка',
#   'ольга',
#   'россия',
#   'омск',
#   'познакомиться',
#   'парень',
#   'возраст',
#   'год'],
#  ['миньон', 'банан', 'слушать', 'скачать', 'mixmuz'],
#  ['cock', 'legs', 'position', 'random', 'photo', 'gallery', 'comments'],
#  ['звезда',
#   'высокий',
#   'кухня',
#   'jewish',
#   'ru',
#   'глобальный',
#   'еврейский',
#   'онлайн',
#   'центр'],
#  ['itlalian', 'sex', 'dildo', 'porn', 'speculum', 'wife'],
#  ['album', 'art', 'panel', 'foo', 'uie', 'albumart', 'foobar'],
#  ['slb',
#   'запчасть',
#   'легковой',
#   'авто',
#   'грузовик',
#   'спецтехник',
#   'красноярск'],
#  ['вакансия',
#   'работа',
#   'промоутер',
#   'раздача',
#   'листовка',
#   'сочи',
#   'поиск',
#   'работа',
#   'городработ',
#   'ру'],
#  ['alexis', 'texas', 'hardcore', 'biqle', 'video'],
#  ['лента', 'новость', 'konyushasvetlana', 'babyblog', 'ru'],
#  ['город',
#   'атырау',
#   'тоо',
#   'конус',
#   'строить',
#   'миллион',
#   'результат',
#   'поиск',
#   'mail',
#   'ru'],
#  ['секс',
#   'скачать',
#   'бесплатно',
#   'голый',
#   'японский',
#   'девушка',
#   'иметь',
#   'большой',
#   'удовольствие',
#   'группа',
#   'озаботить',
#   'парный',
#   'время',
#   'открытый',
#   'воздух'],
#  ['девушка',
#   'красный',
#   'платье',
#   'леса',
#   'аватар',
#   'ярка',
#   'девушка',
#   'платье',
#   'фотография',
#   'ава'],
#  ['написать',
#   'музыка',
#   'маэстро',
#   'обсуждение',
#   'liveinternet',
#   'российский',
#   'сервис'],
#  ['red',
#   'heart',
#   'flat',
#   'clip',
#   'art',
#   'vector',
#   'clip',
#   'art',
#   'online',
#   'royalty',
#   'free',
#   'clip',
#   'art',
#   'library'],
#  ['ип', 'князев', 'дмитрий', 'александр', 'инна', 'огрн'],
#  ['майстер',
#   'клас',
#   'кв',
#   'ти',
#   'з',
#   'фольга',
#   'грудня',
#   'ньковецький',
#   'бдют'],
#  ['нота',
#   'родион',
#   'щедрин',
#   'играть',
#   'балалайка',
#   'нота',
#   'фортепиано',
#   'pianokafe'],
#  ['извращенец', 'играть', 'больший', 'сиська', 'связанный', 'дамочка'],
#  ['открытка', 'вытынанки', 'новый', 'год', 'свой', 'рука'],
#  ['ленинградский', 'метрополитен'],
#  ['приказ',
#   'генпрокуратура',
#   'рф',
#   'n',
#   'обеспечение',
#   'участие',
#   'прокурор',
#   'гражданский',
#   'судопроизводство'],
#  ['подробность', 'убийство', 'денис', 'тен', 'рассказать', 'мать'],
#  ['отзыв', 'обойный', 'клеить', 'verol', 'весь', 'вид', 'виниловый', 'обои'],
#  ['автосканер', 'мультимарочный', 'сканматик'],
#  ['фильм',
#   'скорость',
#   'год',
#   'выпуск',
#   'дата',
#   'выход',
#   'рейтинг',
#   'продолжительность',
#   'похожий',
#   'фильм'],
#  ['гвинея', 'природа', 'авторский', 'платформа', 'pandia', 'ru'],
#  ['jailbait', 'webcam', 'page', 'teen', 'sex', 'site'],
#  ['подготовить', 'подросток', 'взрослый', 'жизнь', 'папамамам', 'миф'],
#  ['ауди', 'тысяча', 'результат', 'поиск', 'mail', 'ru'],
#  ['крещение',
#   'русь',
#   'урок',
#   'учебный',
#   'пособие',
#   'основа',
#   'православный',
#   'культура',
#   'учащи'],
#  ['брюнетка', 'порно', 'скачать', 'бесплатно', 'отличный', 'качество'],
#  ['люся', 'кретова', 'видео', 'mail', 'ru'],
#  ['сказочный',
#   'русалка',
#   'предлагать',
#   'погрузиться',
#   'пучина',
#   'страсть',
#   'картинка'],
#  ['moment'],
#  ['комнатный',
#   'квартира',
#   'посуточно',
#   'бишкек',
#   'логвиненко',
#   'улица',
#   'объявление',
#   'суточный',
#   'ру'],
#  ['moment'],
#  ['обзор',
#   'матч',
#   'уралмаш',
#   'цска',
#   'федерация',
#   'баскетбол',
#   'свердловский',
#   'область'],
#  ['подруга', 'ебутся', 'мужик', 'сквиртуют', 'лить', 'сперма', 'рот', 'рота'],
#  ['презентация',
#   'тема',
#   'криминалистический',
#   'методика',
#   'скачать',
#   'бесплатно'],
#  ['ультрамодный', 'свадебный', 'причёска'],
#  ['список',
#   'использовать',
#   'литература',
#   'формирование',
#   'устный',
#   'речь',
#   'ребёнок',
#   'нарушение',
#   'слух'],
#  ['читать', 'манга', 'день', 'глава', 'русский', 'онлайн'],
#  ['купить',
#   'honda',
#   'civic',
#   'москва',
#   'рольф',
#   'центр',
#   'расположить',
#   'центр',
#   'москва',
#   'минута',
#   'ттк',
#   'ряд',
#   'москва',
#   'сити',
#   'литр',
#   'бензин',
#   'левый',
#   'руль',
#   'бу'],
#  ['венеролог',
#   'прайс',
#   'лист',
#   'город',
#   'слюдянка',
#   'расценка',
#   'цена',
#   'прейскурант'],
#  ['свитшот',
#   'мужской',
#   'кофта',
#   'весенний',
#   'осенний',
#   'netflix',
#   'цена',
#   'грн',
#   'купить',
#   'киев',
#   'prom',
#   'ua',
#   'id'],
#  ['компания', 'blizzard', 'фильм', 'вселенная', 'world', 'warcraft'],
#  ['mp', 'порно', 'страница'],
#  ['рассчитать',
#   'оптический',
#   'сила',
#   'система',
#   'рассеивать',
#   'собирать',
#   'линза',
#   'иметь',
#   'фокусный',
#   'расстояние',
#   'сантиметр',
#   'сантиметр'],
#  ['знать', 'новый', 'глава', 'администрация', 'президент', 'антон', 'вайно'],
#  ['минусовки', 'zivert', 'зиверт', 'юлий', 'парус'],
#  ...]

# %%
cleared_docs_test_sentence = [' '.join(text) for text in cleared_docs_test]

# %%
docs_test_url_sentence = [' '.join(text) for text in docs_test_url]

# %%
data_test = {'url':docs_test_url_sentence, 'title': cleared_docs_test_sentence}

# %%
test_dataset = pd.DataFrame(data=data_test)
test_dataset
# Out:
#                                       url
# 0                       www kommersant ru  \
# 1                         urexpert online
# 2                           imperimeha ru
# 3                       national porn com
# 4                                  gis ru
# ...                                   ...
# 165373                      etp armtek ru
# 165374                            mail ru
# 165375            xn sbnqchpeeeth xn p ai
# 165376  www sunhome ru cdn ampproject org
# 165377                 virtual hockey org
#
#                                                     title
# 0       шесть кассационный суд самар начать работа раз...
# 1       индексация алименты случай производиться каков...
# 2                                женщина империя мех part
# 3       небритый волосатый киска порно весь страна нац...
# 4
# ...                                                   ...
# 165373  armtek запчасть грузовой легковой автомобиль о...
# 165374  лилия якупова караганда карагандинский область...
# 165375  администрация лесной район тверская область го...
# 165376  сонник изменение сознание сниться изменение со...
# 165377  строительство база команда гранд рапидс гриффи...
#
# [165378 rows x 2 columns]

# %%
ans = pipeline.predict(test_dataset).astype(bool)

# %%
data = {'id': test_df['id'], 'target': ans}

# %%
pd_ans = pd.DataFrame(data=data)

# %%
pd_ans
# Out:
#             id  target
# 0       135309   False
# 1       135310   False
# 2       135311   False
# 3       135312    True
# 4       135313   False
# ...        ...     ...
# 165373  300682   False
# 165374  300683   False
# 165375  300684   False
# 165376  300685   False
# 165377  300686   False
#
# [165378 rows x 2 columns]

# %%
pd_ans[["id", "target"]].to_csv("ml_baseline.csv", index=False)

# %%
pd_ans.shape
# Out:
# (165378, 2)
